# %% [markdown]
# # Format Spanish data to word lists
# format Spanish in the following formats:
#
# * all data text spanish: "word", "type", "english", "frequency_rank"
# * 2 column: word, type, definiton

# %%
import pandas as pd
import os
import re

# %%
DATASET = 'spanish_5000'
df = pd.read_pickle(f"./data/spanish2.pkl")
df.head()
# Out:
#   word  type      english frequency_rank  \
# 0   el   art        the (              1
# 0   de  prep     of, from              2
# 0  que  conj  that, which              3
# 0    y  conj          and              4
# 0   en  prep       in, on              5
#
#                               example_spanish  \
# 0  el diccionario tenía también frases útiles
# 0                  es el hijo de un amigo mío
# 0                 dice que no quiere estudiar
# 0                       saben leer y escribir
# 0                     vivo en el segundo piso
#
#                           example_english
# 0  the dictionary also had useful phrases
# 0       he is the son of a friend of mine
# 0   he says that he doesn’t want to study
# 0         they know how to read and write
# 0              I live on the second floor

# %%
df2 = pd.read_pickle(f"./data/spanish2.pkl")
df2.head()
# Out:
#   word  type      english frequency_rank  \
# 0   el   art        the (              1
# 0   de  prep     of, from              2
# 0  que  conj  that, which              3
# 0    y  conj          and              4
# 0   en  prep       in, on              5
#
#                               example_spanish  \
# 0  el diccionario tenía también frases útiles
# 0                  es el hijo de un amigo mío
# 0                 dice que no quiere estudiar
# 0                       saben leer y escribir
# 0                     vivo en el segundo piso
#
#                           example_english
# 0  the dictionary also had useful phrases
# 0       he is the son of a friend of mine
# 0   he says that he doesn’t want to study
# 0         they know how to read and write
# 0              I live on the second floor

# %%
# "word": word, "type": type, "english": english, "frequency_rank": frequency_rank
def load_data():
    data = df[["word", "type", "english", "frequency_rank"]]
    #data = data.rename(columns={'english' : 'English'})
    #data = data.rename(columns={'frequency_rank' : 'frequency rank'})
    return data

# "word": word, "type": type, "english": english, "frequency_rank": frequency_rank, "example_spanish": example_spanish, "example_english": example_english
def load_data2():
    data = df2[["word", "type", "english", "example_spanish", "example_english", "frequency_rank"]]
    #data = data.rename(columns={'english' : 'English'})
    #data = data.rename(columns={'spanish' : 'Spanish'})
    #data = data.rename(columns={'frequency_rank' : 'frequency rank'})
    return data

# %%
# Replaces given word in field with '_'
def replace_word_in_field_with_underscore(word, field):
    field_split = field.split(' ')
    def _replace(e):
        if word not in e:
           return e
        if not re.match(f"^{word}.*?$", e):
            return e
        return e.replace(word, '_')
    field_split_replaced = list(map(lambda e: _replace(e), field_split))
    return ' '.join(field_split_replaced)

# %% [markdown]
# ## HTML+PDF all columns

# %%
# HTML, Underscore, Shuffled and Alphabetical
data = load_data2()

data["example_spanish"] = data.apply(lambda row: replace_word_in_field_with_underscore(row.word, row.example_spanish) , axis=1)
data = data.drop(['frequency_rank'], axis=1)
data = data.rename(columns={'example_english' : 'example (English)'})
data = data.rename(columns={'example_spanish' : 'example (Spanish)'})

data = data.sample(frac=1) # shuffle

style = data.style.format(
    escape="html",
    )
style = style.hide(axis='index')

html = style.to_html()
filename = DATASET+'_underscore_shuffled'
with open(f'output/{filename}.html', 'w') as f:
    f.write(html)

cmd = f'pandoc -f html -t pdf output/{filename}.html -t html5 -o output/{filename}.pdf --metadata pagetitle="{filename}" -V margin-top=1cm -V margin-bottom=1cm -V margin-left=1cm -V margin-right=1cm -c format/table.css --pdf-engine-opt=--enable-local-file-access'
os.system(cmd)

####### Sort Alphabetical

data.sort_values('word') # alphabetical
filename = DATASET + '_underscore_alphabetical'
with open(f'output/{filename}.html', 'w') as f:
    f.write(html)
cmd = f'pandoc -f html -t pdf output/{filename}.html -t html5 -o output/{filename}.pdf --metadata pagetitle="{filename}" -V margin-top=1cm -V margin-bottom=1cm -V margin-left=1cm -V margin-right=1cm -c format/table.css --pdf-engine-opt=--enable-local-file-access'
os.system(cmd)
# Out:
# /tmp/ipykernel_63091/1344345340.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["example_spanish"] = data.apply(lambda row: replace_word_in_field_with_underscore(row.word, row.example_spanish) , axis=1)
# Loading pages (1/6)
# Counting pages (2/6)
# Resolving links (4/6)
# Loading headers and footers (5/6)
# Printing pages (6/6)
# Done

# %%
# HTML, Shuffled and Alphabetical, without underscore
data = load_data2()

# data["example_spanish"] = data.apply(lambda row: replace_word_in_field_with_underscore(row.word, row.example_spanish) , axis=1)
data = data.drop(['frequency_rank'], axis=1)
data = data.rename(columns={'example_english' : 'example (English)'})
data = data.rename(columns={'example_spanish' : 'example (Spanish)'})

data = data.sample(frac=1) # shuffle

style = data.style.format(
    escape="html",
    )
style = style.hide(axis='index')

html = style.to_html()
filename = DATASET+'_shuffled'
with open(f'output/{filename}.html', 'w') as f:
    f.write(html)

cmd = f'pandoc -f html -t pdf output/{filename}.html -t html5 -o output/{filename}.pdf --metadata pagetitle="{filename}" -V margin-top=1cm -V margin-bottom=1cm -V margin-left=1cm -V margin-right=1cm -c format/table.css --pdf-engine-opt=--enable-local-file-access'
os.system(cmd)

####### Sort Alphabetical

data.sort_values('word') # alphabetical
filename = DATASET + '_alphabetical'
with open(f'output/{filename}.html', 'w') as f:
    f.write(html)
cmd = f'pandoc -f html -t pdf output/{filename}.html -t html5 -o output/{filename}.pdf --metadata pagetitle="{filename}" -V margin-top=1cm -V margin-bottom=1cm -V margin-left=1cm -V margin-right=1cm -c format/table.css --pdf-engine-opt=--enable-local-file-access'
os.system(cmd)
# Out:
# Loading pages (1/6)
# Counting pages (2/6)
# Resolving links (4/6)
# Loading headers and footers (5/6)
# Printing pages (6/6)
# Done
# Loading pages (1/6)
# Counting pages (2/6)
# Resolving links (4/6)
# Loading headers and footers (5/6)
# Printing pages (6/6)
# Done
# 0

# %% [markdown]
# ## HTML+PDF all columns grouped by CEFR

# %%
# By Ranking / pseudo-cefr. Shuffled
data = load_data2()
data["example_spanish"] = data.apply(lambda row: replace_word_in_field_with_underscore(row.word, row.example_spanish) , axis=1)
data.head()

data_by_cefr = [
    data.iloc[:1000],
    data.iloc[1000:2000],
    data.iloc[2000:3000],
    data.iloc[3000:4000],
    data.iloc[4000:],
    ]

data_by_cefr[1].head()
cefrs = ['A1', 'A2', 'B1', 'B2', 'C1']

# Complete to HTML
html_out = ''
for i, data_slice in enumerate(data_by_cefr):
    if data_slice.empty:
        continue
    #cefr = data_slice['cefr'].iloc[0]
    cefr = cefrs[i]
    html_out += f'<h2>{cefr}</h2>'
    data_slice = data_slice.drop(['frequency_rank'], axis=1)
    data_slice = data_slice.rename(columns={'word' : f'word ({cefr})'})
    data_slice = data_slice.rename(columns={'example_english' : 'example (English)'})
    data_slice = data_slice.rename(columns={'example_spanish' : 'example (Spanish)'})

    data_slice = data_slice.sample(frac=1) # shuffle

    style = data_slice.style.format(
        escape="html",
        )
    style = style.hide(axis='index')
    html_out += style.to_html()

filename = DATASET+'_underscore_by_cefr_shuffled'
with open(f'output/{filename}.html', 'w', encoding='utf-8') as f:
    f.write(html_out)

# to pdf
cmd = f"""pandoc -f html -t pdf output/{filename}.html -t html5 -o output/{filename}.pdf --metadata pagetitle="{filename}" -V margin-top=2 -V margin-bottom=2 -V margin-left=2 -V margin-right=2 -c format/table.css --pdf-engine-opt=--enable-local-file-access --title '{filename}'"""
os.system(cmd)
# Out:
# /tmp/ipykernel_63091/2719714033.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["example_spanish"] = data.apply(lambda row: replace_word_in_field_with_underscore(row.word, row.example_spanish) , axis=1)
# Loading pages (1/6)
# Counting pages (2/6)
# Resolving links (4/6)
# Loading headers and footers (5/6)
# Printing pages (6/6)
# Done
# 0

# %%
# By Ranking / pseudo-cefr. Alphabetical
data = load_data2()
data["example_spanish"] = data.apply(lambda row: replace_word_in_field_with_underscore(row.word, row.example_spanish) , axis=1)
data.head()

data_by_cefr = [
    data.iloc[:1000], #A1
    data.iloc[1000:2000], #A2
    data.iloc[2000:3000], #B1
    data.iloc[3000:4000], #B2
    data.iloc[4000:], #C1
    ]

data_by_cefr[1].head()
cefrs = ['A1', 'A2', 'B1', 'B2', 'C1']

# Complete to HTML
html_out = ''
for i, data_slice in enumerate(data_by_cefr):
    if data_slice.empty:
        continue
    cefr = cefrs[i]
    html_out += f'<h2>{cefr}</h2>'
    data_slice = data_slice.drop(['frequency_rank'], axis=1)
    data_slice = data_slice.sort_values('word')
    data_slice = data_slice.rename(columns={'word' : f'word ({cefr})'})
    data_slice = data_slice.rename(columns={'example_english' : 'example (English)'})
    data_slice = data_slice.rename(columns={'example_spanish' : 'example (Spanish)'})

    style = data_slice.style.format(
        escape="html",
        )
    style = style.hide(axis='index')
    html_out += style.to_html()

filename = DATASET+'_underscore_by_cefr_alphabetical'
with open(f'output/{filename}.html', 'w', encoding='utf-8') as f:
    f.write(html_out)

# to pdf
cmd = f"""pandoc -f html -t pdf output/{filename}.html -t html5 -o output/{filename}.pdf --metadata pagetitle="{filename}" -V margin-top=2 -V margin-bottom=2 -V margin-left=2 -V margin-right=2 -c format/table.css --pdf-engine-opt=--enable-local-file-access --title '{filename}'"""
os.system(cmd)
# Out:
# /tmp/ipykernel_63091/1532673601.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["example_spanish"] = data.apply(lambda row: replace_word_in_field_with_underscore(row.word, row.example_spanish) , axis=1)
# Loading pages (1/6)
# Counting pages (2/6)
# Resolving links (4/6)
# Loading headers and footers (5/6)
# Printing pages (6/6)
# Done
# 0

# %% [markdown]
# ## 2 Column LateX word, type and definition

# %%
# 2 column 5000 not by rank
# shuffle and alphabetical
import re
# Fix supertabular and add \textit to type
column_format = 'p{1.2in}p{2.3in}p{1.2in}p{2.3in}'
def fix_latex_line(line):
    if re.match(r"^\\begin{supertabular}", line):
        # Add column_format to supertabular}
        return '\\begin{supertabular}'+'{'+column_format+'}'
    if re.match(r"^\\.*{tabular}", line):
        # Remove {tabular}
        return ''
    if re.match(r"^\w+\s.*\(\w+\s?\w+?\)", line):
        # Italics
        return re.sub(r"(^\w+\s.*)(\(\w+\s?\w+?\))", r"\1\\textit{\2}", line)
    return line

# columns = ["word", "type", "english", "frequency_rank"]
data = load_data2()
data["example_spanish"] = data.apply(lambda row: replace_word_in_field_with_underscore(row.word, row.example_spanish) , axis=1)
data["word"] = data.apply(lambda row: f"{row.word.strip()} ({row.type.strip()})" , axis=1)
#data = data[["word", "spanish", "english", "example_spanish", "example_english"]]
data = data[["word", "english"]]

style = data.style.format(
    escape="latex",
    )
style = style.hide(axis='index')
style = style.hide(axis='columns')


latex = style.to_latex(
    environment='supertabular',
    column_format=column_format
)

latex_lines = latex.splitlines()

latex = '\n'.join((map(fix_latex_line, latex_lines)))

with open(f'build/{DATASET}_two_column_alphabetical.tex', 'w') as f:
    f.write(latex)

cmd_build = f"latexmk -pdf -cd format/{DATASET}_two_column_alphabetical.tex -outdir=../output"
os.system(cmd_build)

#### Same for shuffle

data = data.sample(frac=1) # shuffle
style = data.style.format(
    escape="latex",
    )
style = style.hide(axis='index')
style = style.hide(axis='columns')

column_format = 'p{1.2in}p{2.3in}p{1.2in}p{2.3in}'

latex = style.to_latex(
    environment='supertabular',
    column_format=column_format
)

latex_lines = latex.splitlines()
latex = '\n'.join((map(fix_latex_line, latex_lines)))

with open(f'build/{DATASET}_two_column_shuffle.tex', 'w') as f:
    f.write(latex)

cmd_build = f"latexmk -pdf -cd format/{DATASET}_two_column_shuffle.tex -outdir=../output"
os.system(cmd_build)
# Out:
# Rc files read:
#   /etc/LatexMk
# Latexmk: This is Latexmk, John Collins, 20 November 2021, version: 4.76.
# Latexmk: Changing directory to 'format/'
# Rule 'pdflatex': File changes, etc:
#    Changed files, or newly in use since previous run(s):
#       'spanish_5000_two_column_alphabetical.tex'
# ------------
# Run number 1 of rule 'pdflatex'
# ------------
# ------------
# Running 'pdflatex  -recorder -output-directory="/home/jelle/wd/words/spanish/output"  "spanish_5000_two_column_alphabetical.tex"'
# ------------
# Latexmk: applying rule 'pdflatex'...
# This is pdfTeX, Version 3.141592653-2.6-1.40.22 (TeX Live 2022/dev/Debian) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./spanish_5000_two_column_alphabetical.tex
# LaTeX2e <2021-11-15> patch level 1
# L3 programming layer <2022-01-21>
# (/usr/share/texlive/texmf-dist/tex/latex/base/article.cls
# Document Class: article 2021/10/04 v1.4n Standard LaTeX document class
# (/usr/share/texlive/texmf-dist/tex/latex/base/size10.clo))
# (/usr/share/texlive/texmf-dist/tex/latex/geometry/geometry.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/share/texlive/texmf-dist/tex/generic/iftex/ifvtex.sty
# (/usr/share/texlive/texmf-dist/tex/generic/iftex/iftex.sty)))
# (/usr/share/texlive/texmf-dist/tex/latex/blindtext/blindtext.sty
# (/usr/share/texlive/texmf-dist/tex/latex/tools/xspace.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/base/inputenc.sty
# (/usr/share/texlive/texmf-dist/tex/latex/ucs/utf8x.def))
# (/usr/share/texlive/texmf-dist/tex/latex/ucs/ucs.sty
# (/usr/share/texlive/texmf-dist/tex/latex/ucs/data/uni-global.def))
# (/usr/share/texlive/texmf-dist/tex/latex/supertabular/supertabular.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/tools/array.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/psnfss/helvet.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/psnfss/ot1phv.fd)
# (/usr/share/texlive/texmf-dist/tex/latex/l3backend/l3backend-pdftex.def)
# (/home/jelle/wd/words/spanish/output/spanish_5000_two_column_alphabetical.aux)
# *geometry* driver: auto-detecting
# *geometry* detected driver: pdftex
# (/usr/share/texlive/texmf-dist/tex/latex/ucs/ucsencs.def)
# No file spanish_5000_two_column_alphabetical.toc.
#
# (/home/jelle/wd/words/spanish/output/../build/spanish_5000_two_column_alphabeti
# cal.tex
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1--1
# []
# (/usr/share/texlive/texmf-dist/tex/latex/ucs/data/uni-0.def)
# (/usr/share/texlive/texmf-dist/tex/latex/ucs/data/uni-32.def)
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1--57
# []
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 57--111
# []
# [1{/var/lib/texmf/fonts/map/pdftex/updmap/pdftex.map}]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 111--174
# []
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 174--237
# []
# [2]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 237--300
# []
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 300--363
# []
# [3]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 363--426
# []
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 426--489
# []
# [4]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 489--552
# []
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 552--615
# []
# [5]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 615--678
# []
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 678--741
# []
# [6]
# Underfull \hbox (badness 10000) in paragraph at lines 759--759
# []\OT1/phv/m/n/10 especialmente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 741--803
# []
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 803--866
# []
# [7]
# Underfull \hbox (badness 10000) in paragraph at lines 917--917
# []\OT1/phv/m/n/10 responsabilidad
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 866--928
# []
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 928--991
# []
# [8] (/usr/share/texlive/texmf-dist/tex/latex/ucs/data/uni-34.def)
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 991--1054
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 1073--1073
# []\OT1/phv/m/n/10 estadounidense
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1054--1116
# []
# [9]
# Underfull \hbox (badness 10000) in paragraph at lines 1133--1133
# []\OT1/phv/m/n/10 pr[]acticamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1116--1178
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 1187--1187
# []\OT1/phv/m/n/10 completamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1178--1240
# []
# [10]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1240--1303
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 1341--1341
# []\OT1/phv/m/n/10 probablemente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1303--1365
# []
# [11]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1365--1428
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 1471--1471
# []\OT1/phv/m/n/10 inmediatamente
#
# Underfull \hbox (badness 10000) in paragraph at lines 1482--1482
# []\OT1/phv/m/n/10 absolutamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1428--1489
# []
# [12]
# Underfull \hbox (badness 10000) in paragraph at lines 1504--1504
# []\OT1/phv/m/n/10 aproximadamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1489--1551
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 1563--1563
# []\OT1/phv/m/n/10 perfectamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1551--1613
# []
# [13]
# Underfull \hbox (badness 10000) in paragraph at lines 1618--1618
# []\OT1/phv/m/n/10 comportamiento
#
# Underfull \hbox (badness 10000) in paragraph at lines 1659--1659
# []\OT1/phv/m/n/10 principalmente
#
# Underfull \hbox (badness 10000) in paragraph at lines 1670--1670
# []\OT1/phv/m/n/10 acontecimiento
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1613--1673
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 1688--1688
# []\OT1/phv/m/n/10 norteamericano
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1673--1735
# []
# [14]
# Underfull \hbox (badness 10000) in paragraph at lines 1758--1758
# []\OT1/phv/m/n/10 posteriormente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1735--1797
# []
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1797--1860
# []
# [15]
# Underfull \hbox (badness 10000) in paragraph at lines 1867--1867
# []\OT1/phv/m/n/10 contempor[]aneo
#
# Underfull \hbox (badness 10000) in paragraph at lines 1896--1896
# []\OT1/phv/m/n/10 verdaderamente
#
# Underfull \hbox (badness 10000) in paragraph at lines 1919--1919
# []\OT1/phv/m/n/10 correspondiente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1860--1920
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 1930--1930
# []\OT1/phv/m/n/10 descubrimiento
#
# Underfull \hbox (badness 10000) in paragraph at lines 1934--1934
# []\OT1/phv/m/n/10 reconocimiento
#
# Underfull \hbox (badness 10000) in paragraph at lines 1976--1976
# []\OT1/phv/m/n/10 evidentemente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1920--1980
# []
# [16]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1980--2043
# []
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 2043--2106
# []
# [17]
# Underfull \hbox (badness 10000) in paragraph at lines 2112--2112
# []\OT1/phv/m/n/10 definitivamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 2106--2168
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 2184--2184
# []\OT1/phv/m/n/10 recientemente
#
# Underfull \hbox (badness 10000) in paragraph at lines 2186--2186
# []\OT1/phv/m/n/10 latinoamericano
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 2168--2229
# []
# [18]
# Underfull \hbox (badness 10000) in paragraph at lines 2235--2235
# []\OT1/phv/m/n/10 funcionamiento
#
# Underfull \hbox (badness 10000) in paragraph at lines 2238--2238
# []\OT1/phv/m/n/10 fundamentalmente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 2229--2290
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 2342--2342
# []\OT1/phv/m/n/10 establecimiento
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 2290--2352
# []
# [19]
# Underfull \hbox (badness 10000) in paragraph at lines 2398--2398
# []\OT1/phv/m/n/10 personalmente
#
# Underfull \hbox (badness 10000) in paragraph at lines 2400--2400
# []\OT1/phv/m/n/10 profundamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 2352--2413
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 2445--2445
# []\OT1/phv/m/n/10 anteriormente
#
# Underfull \hbox (badness 10000) in paragraph at lines 2454--2454
# []\OT1/phv/m/n/10 gubernamental
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 2413--2474
# []
# [20]
# Underfull \hbox (badness 10000) in paragraph at lines 2529--2529
# []\OT1/phv/m/n/10 exclusivamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 2474--2536
# []
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 2536--2599
# []
# [21]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 2599--2662
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 2668--2668
# []\OT1/phv/m/n/10 aparentemente
#
# Underfull \hbox (badness 10000) in paragraph at lines 2701--2701
# []\OT1/phv/m/n/10 constantemente
#
# Underfull \hbox (badness 10000) in paragraph at lines 2714--2714
# []\OT1/phv/m/n/10 necesariamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 2662--2722
# []
# [22]
# Underfull \hbox (badness 10000) in paragraph at lines 2736--2736
# []\OT1/phv/m/n/10 enfrentamiento
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 2722--2784
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 2794--2794
# []\OT1/phv/m/n/10 particularmente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 2784--2845
# []
# [23]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 2845--2908
# []
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 2908--2971
# []
# [24]
# Underfull \hbox (badness 10000) in paragraph at lines 3001--3001
# []\OT1/phv/m/n/10 mantenimiento
#
# Underfull \hbox (badness 10000) in paragraph at lines 3029--3029
# []\OT1/phv/m/n/10 suficientemente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 2971--3032
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 3094--3094
# []\OT1/phv/m/n/10 vicepresidente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 3032--3095
# []
# [25]
# Underfull \hbox (badness 10000) in paragraph at lines 3130--3130
# []\OT1/phv/m/n/10 respectivamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 3095--3157
# []
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 3157--3220
# []
# [26]
# Underfull \hbox (badness 10000) in paragraph at lines 3263--3263
# []\OT1/phv/m/n/10 desgraciadamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 3220--3282
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 3320--3320
# []\OT1/phv/m/n/10 concretamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 3282--3344
# []
# [27]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 3344--3407
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 3419--3419
# []\OT1/phv/m/n/10 administrador
#
# Underfull \hbox (badness 10000) in paragraph at lines 3466--3466
# []\OT1/phv/m/n/10 lamentablemente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 3407--3467
# []
# [28]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 3467--3530
# []
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 3530--3593
# []
# [29]
# Underfull \hbox (badness 10000) in paragraph at lines 3628--3628
# []\OT1/phv/m/n/10 indudablemente
#
# Underfull \hbox (badness 10000) in paragraph at lines 3645--3645
# []\OT1/phv/m/n/10 supuestamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 3593--3654
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 3657--3657
# []\OT1/phv/m/n/10 afortunadamente
#
# Underfull \hbox (badness 10000) in paragraph at lines 3688--3688
# []\OT1/phv/m/n/10 espec[]^^Pficamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 3654--3715
# []
# [30]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 3715--3778
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 3789--3789
# []\OT1/phv/m/n/10 continuamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 3778--3840
# []
# [31]
# Underfull \hbox (badness 10000) in paragraph at lines 3885--3885
# []\OT1/phv/m/n/10 autom[]aticamente
#
# Overfull \hbox (3.88509pt too wide) in paragraph at lines 3893--3893
# []\OT1/phv/m/n/10 independientemente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 3840--3901
# []
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 3901--3964
# []
# [32]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 3964--4027
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 4037--4037
# []\OT1/phv/m/n/10 frecuentemente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 4027--4089
# []
# [33]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 4089--4152
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 4175--4175
# []\OT1/phv/m/n/10 correctamente
#
# Underfull \hbox (badness 10000) in paragraph at lines 4179--4179
# []\OT1/phv/m/n/10 sucesivamente
#
# Underfull \hbox (badness 10000) in paragraph at lines 4210--4210
# []\OT1/phv/m/n/10 correspondencia
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 4152--4211
# []
# [34]
# Underfull \hbox (badness 10000) in paragraph at lines 4239--4239
# []\OT1/phv/m/n/10 cuidadosamente
#
# Underfull \hbox (badness 10000) in paragraph at lines 4260--4260
# []\OT1/phv/m/n/10 econ[]omicamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 4211--4272
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 4274--4274
# []\OT1/phv/m/n/10 desplazamiento
#
# Underfull \hbox (badness 10000) in paragraph at lines 4330--4330
# []\OT1/phv/m/n/10 habitualmente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 4272--4333
# []
# [35]
# Underfull \hbox (badness 10000) in paragraph at lines 4362--4362
# []\OT1/phv/m/n/10 entretenimiento
#
# Underfull \hbox (badness 10000) in paragraph at lines 4378--4378
# []\OT1/phv/m/n/10 extremadamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 4333--4394
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 4423--4423
# []\OT1/phv/m/n/10 complementario
#
# Underfull \hbox (badness 10000) in paragraph at lines 4426--4426
# []\OT1/phv/m/n/10 simult[]aneamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 4394--4455
# []
# [36]
# Underfull \hbox (badness 10000) in paragraph at lines 4507--4507
# []\OT1/phv/m/n/10 cinematogr[]afico
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 4455--4517
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 4528--4528
# []\OT1/phv/m/n/10 tranquilamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 4517--4579
# []
# [37]
# Underfull \hbox (badness 10000) in paragraph at lines 4624--4624
# []\OT1/phv/m/n/10 enormemente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 4579--4641
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 4690--4690
# []\OT1/phv/m/n/10 esencialmente
#
# Underfull \hbox (badness 10000) in paragraph at lines 4699--4699
# []\OT1/phv/m/n/10 tradicionalmente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 4641--4702
# []
# [38]
# Underfull \hbox (badness 10000) in paragraph at lines 4704--4704
# []\OT1/phv/m/n/10 permanentemente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 4702--4764
# []
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 4764--4827
# []
# [39]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 4827--4890
# []
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 4890--4953
# []
# [40]
# Underfull \hbox (badness 10000) in paragraph at lines 4989--4989
# []\OT1/phv/m/n/10 hispanoamericano
# )
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 4953--26
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 4953--26
#
# (/home/jelle/wd/words/spanish/output/spanish_5000_two_column_alphabetical.aux)
# )
# (see the transcript file for additional information){/usr/share/texlive/texmf-d
# ist/fonts/enc/dvips/base/8r.enc}</usr/share/texlive/texmf-dist/fonts/type1/publ
# ic/amsfonts/cm/cmsy10.pfb></usr/share/texlive/texmf-dist/fonts/type1/urw/helvet
# ic/uhvb8a.pfb></usr/share/texlive/texmf-dist/fonts/type1/urw/helvetic/uhvr8a.pf
# b></usr/share/texlive/texmf-dist/fonts/type1/urw/helvetic/uhvro8a.pfb>
# Output written on /home/jelle/wd/words/spanish/output/spanish_5000_two_column_a
# lphabetical.pdf (40 pages, 183857 bytes).
# Transcript written on /home/jelle/wd/words/spanish/output/spanish_5000_two_colu
# mn_alphabetical.log.
# Latexmk: Examining '/home/jelle/wd/words/spanish/output/spanish_5000_two_column_alphabetical.log'
# === TeX engine is 'pdfTeX'
# Latexmk: applying rule 'pdflatex'...
# This is pdfTeX, Version 3.141592653-2.6-1.40.22 (TeX Live 2022/dev/Debian) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./spanish_5000_two_column_alphabetical.tex
# LaTeX2e <2021-11-15> patch level 1
# L3 programming layer <2022-01-21>
# (/usr/share/texlive/texmf-dist/tex/latex/base/article.cls
# Latexmk: Missing input file 'spanish_5000_two_column_alphabetical.toc' (or dependence on it) from following:
#   'No file spanish_5000_two_column_alphabetical.toc.'
# Latexmk: Log file says output to '/home/jelle/wd/words/spanish/output/spanish_5000_two_column_alphabetical.pdf'
# Rule 'pdflatex': File changes, etc:
#    Changed files, or newly in use since previous run(s):
#       '/home/jelle/wd/words/spanish/output/spanish_5000_two_column_alphabetical.aux'
#       '/home/jelle/wd/words/spanish/output/spanish_5000_two_column_alphabetical.toc'
# ------------
# Run number 2 of rule 'pdflatex'
# ------------
# ------------
# Running 'pdflatex  -recorder -output-directory="/home/jelle/wd/words/spanish/output"  "spanish_5000_two_column_alphabetical.tex"'
# ------------
# Document Class: article 2021/10/04 v1.4n Standard LaTeX document class
# (/usr/share/texlive/texmf-dist/tex/latex/base/size10.clo))
# (/usr/share/texlive/texmf-dist/tex/latex/geometry/geometry.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/share/texlive/texmf-dist/tex/generic/iftex/ifvtex.sty
# (/usr/share/texlive/texmf-dist/tex/generic/iftex/iftex.sty)))
# (/usr/share/texlive/texmf-dist/tex/latex/blindtext/blindtext.sty
# (/usr/share/texlive/texmf-dist/tex/latex/tools/xspace.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/base/inputenc.sty
# (/usr/share/texlive/texmf-dist/tex/latex/ucs/utf8x.def))
# (/usr/share/texlive/texmf-dist/tex/latex/ucs/ucs.sty
# (/usr/share/texlive/texmf-dist/tex/latex/ucs/data/uni-global.def))
# (/usr/share/texlive/texmf-dist/tex/latex/supertabular/supertabular.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/tools/array.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/psnfss/helvet.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/psnfss/ot1phv.fd)
# (/usr/share/texlive/texmf-dist/tex/latex/l3backend/l3backend-pdftex.def)
# (/home/jelle/wd/words/spanish/output/spanish_5000_two_column_alphabetical.aux)
# *geometry* driver: auto-detecting
# *geometry* detected driver: pdftex
# (/usr/share/texlive/texmf-dist/tex/latex/ucs/ucsencs.def)
# (/home/jelle/wd/words/spanish/output/spanish_5000_two_column_alphabetical.toc)
# (/home/jelle/wd/words/spanish/output/../build/spanish_5000_two_column_alphabeti
# cal.tex
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1--1
# []
# (/usr/share/texlive/texmf-dist/tex/latex/ucs/data/uni-0.def)
# (/usr/share/texlive/texmf-dist/tex/latex/ucs/data/uni-32.def)
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1--56
# []
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 56--110
# []
# [1{/var/lib/texmf/fonts/map/pdftex/updmap/pdftex.map}]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 110--173
# []
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 173--236
# []
# [2]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 236--299
# []
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 299--362
# []
# [3]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 362--425
# []
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 425--488
# []
# [4]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 488--551
# []
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 551--614
# []
# [5]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 614--677
# []
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 677--740
# []
# [6]
# Underfull \hbox (badness 10000) in paragraph at lines 759--759
# []\OT1/phv/m/n/10 especialmente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 740--802
# []
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 802--865
# []
# [7]
# Underfull \hbox (badness 10000) in paragraph at lines 917--917
# []\OT1/phv/m/n/10 responsabilidad
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 865--927
# []
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 927--990
# []
# [8] (/usr/share/texlive/texmf-dist/tex/latex/ucs/data/uni-34.def)
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 990--1053
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 1073--1073
# []\OT1/phv/m/n/10 estadounidense
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1053--1115
# []
# [9]
# Underfull \hbox (badness 10000) in paragraph at lines 1133--1133
# []\OT1/phv/m/n/10 pr[]acticamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1115--1177
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 1187--1187
# []\OT1/phv/m/n/10 completamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1177--1239
# []
# [10]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1239--1302
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 1341--1341
# []\OT1/phv/m/n/10 probablemente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1302--1364
# []
# [11]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1364--1427
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 1471--1471
# []\OT1/phv/m/n/10 inmediatamente
#
# Underfull \hbox (badness 10000) in paragraph at lines 1482--1482
# []\OT1/phv/m/n/10 absolutamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1427--1488
# []
# [12]
# Underfull \hbox (badness 10000) in paragraph at lines 1504--1504
# []\OT1/phv/m/n/10 aproximadamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1488--1550
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 1563--1563
# []\OT1/phv/m/n/10 perfectamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1550--1612
# []
# [13]
# Underfull \hbox (badness 10000) in paragraph at lines 1618--1618
# []\OT1/phv/m/n/10 comportamiento
#
# Underfull \hbox (badness 10000) in paragraph at lines 1659--1659
# []\OT1/phv/m/n/10 principalmente
#
# Underfull \hbox (badness 10000) in paragraph at lines 1670--1670
# []\OT1/phv/m/n/10 acontecimiento
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1612--1671
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 1688--1688
# []\OT1/phv/m/n/10 norteamericano
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1671--1733
# []
# [14]
# Underfull \hbox (badness 10000) in paragraph at lines 1758--1758
# []\OT1/phv/m/n/10 posteriormente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1733--1795
# []
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1795--1858
# []
# [15]
# Underfull \hbox (badness 10000) in paragraph at lines 1867--1867
# []\OT1/phv/m/n/10 contempor[]aneo
#
# Underfull \hbox (badness 10000) in paragraph at lines 1896--1896
# []\OT1/phv/m/n/10 verdaderamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1858--1919
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 1919--1919
# []\OT1/phv/m/n/10 correspondiente
#
# Underfull \hbox (badness 10000) in paragraph at lines 1930--1930
# []\OT1/phv/m/n/10 descubrimiento
#
# Underfull \hbox (badness 10000) in paragraph at lines 1934--1934
# []\OT1/phv/m/n/10 reconocimiento
#
# Underfull \hbox (badness 10000) in paragraph at lines 1976--1976
# []\OT1/phv/m/n/10 evidentemente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1919--1977
# []
# [16]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1977--2040
# []
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 2040--2103
# []
# [17]
# Underfull \hbox (badness 10000) in paragraph at lines 2112--2112
# []\OT1/phv/m/n/10 definitivamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 2103--2165
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 2184--2184
# []\OT1/phv/m/n/10 recientemente
#
# Underfull \hbox (badness 10000) in paragraph at lines 2186--2186
# []\OT1/phv/m/n/10 latinoamericano
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 2165--2226
# []
# [18]
# Underfull \hbox (badness 10000) in paragraph at lines 2235--2235
# []\OT1/phv/m/n/10 funcionamiento
#
# Underfull \hbox (badness 10000) in paragraph at lines 2238--2238
# []\OT1/phv/m/n/10 fundamentalmente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 2226--2287
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 2342--2342
# []\OT1/phv/m/n/10 establecimiento
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 2287--2349
# []
# [19]
# Underfull \hbox (badness 10000) in paragraph at lines 2398--2398
# []\OT1/phv/m/n/10 personalmente
#
# Underfull \hbox (badness 10000) in paragraph at lines 2400--2400
# []\OT1/phv/m/n/10 profundamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 2349--2410
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 2445--2445
# []\OT1/phv/m/n/10 anteriormente
#
# Underfull \hbox (badness 10000) in paragraph at lines 2454--2454
# []\OT1/phv/m/n/10 gubernamental
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 2410--2471
# []
# [20]
# Underfull \hbox (badness 10000) in paragraph at lines 2529--2529
# []\OT1/phv/m/n/10 exclusivamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 2471--2533
# []
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 2533--2596
# []
# [21]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 2596--2659
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 2668--2668
# []\OT1/phv/m/n/10 aparentemente
#
# Underfull \hbox (badness 10000) in paragraph at lines 2701--2701
# []\OT1/phv/m/n/10 constantemente
#
# Underfull \hbox (badness 10000) in paragraph at lines 2714--2714
# []\OT1/phv/m/n/10 necesariamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 2659--2719
# []
# [22]
# Underfull \hbox (badness 10000) in paragraph at lines 2736--2736
# []\OT1/phv/m/n/10 enfrentamiento
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 2719--2781
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 2794--2794
# []\OT1/phv/m/n/10 particularmente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 2781--2842
# []
# [23]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 2842--2905
# []
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 2905--2968
# []
# [24]
# Underfull \hbox (badness 10000) in paragraph at lines 3001--3001
# []\OT1/phv/m/n/10 mantenimiento
#
# Underfull \hbox (badness 10000) in paragraph at lines 3029--3029
# []\OT1/phv/m/n/10 suficientemente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 2968--3030
# []
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 3030--3093
# []
# [25]
# Underfull \hbox (badness 10000) in paragraph at lines 3094--3094
# []\OT1/phv/m/n/10 vicepresidente
#
# Underfull \hbox (badness 10000) in paragraph at lines 3130--3130
# []\OT1/phv/m/n/10 respectivamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 3093--3154
# []
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 3154--3217
# []
# [26]
# Underfull \hbox (badness 10000) in paragraph at lines 3263--3263
# []\OT1/phv/m/n/10 desgraciadamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 3217--3279
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 3320--3320
# []\OT1/phv/m/n/10 concretamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 3279--3341
# []
# [27]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 3341--3404
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 3419--3419
# []\OT1/phv/m/n/10 administrador
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 3404--3466
# []
# [28]
# Underfull \hbox (badness 10000) in paragraph at lines 3466--3466
# []\OT1/phv/m/n/10 lamentablemente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 3466--3528
# []
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 3528--3591
# []
# [29]
# Underfull \hbox (badness 10000) in paragraph at lines 3628--3628
# []\OT1/phv/m/n/10 indudablemente
#
# Underfull \hbox (badness 10000) in paragraph at lines 3645--3645
# []\OT1/phv/m/n/10 supuestamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 3591--3652
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 3657--3657
# []\OT1/phv/m/n/10 afortunadamente
#
# Underfull \hbox (badness 10000) in paragraph at lines 3688--3688
# []\OT1/phv/m/n/10 espec[]^^Pficamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 3652--3713
# []
# [30]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 3713--3776
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 3789--3789
# []\OT1/phv/m/n/10 continuamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 3776--3838
# []
# [31]
# Underfull \hbox (badness 10000) in paragraph at lines 3885--3885
# []\OT1/phv/m/n/10 autom[]aticamente
#
# Overfull \hbox (3.88509pt too wide) in paragraph at lines 3893--3893
# []\OT1/phv/m/n/10 independientemente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 3838--3899
# []
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 3899--3962
# []
# [32]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 3962--4025
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 4037--4037
# []\OT1/phv/m/n/10 frecuentemente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 4025--4087
# []
# [33]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 4087--4150
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 4175--4175
# []\OT1/phv/m/n/10 correctamente
#
# Underfull \hbox (badness 10000) in paragraph at lines 4179--4179
# []\OT1/phv/m/n/10 sucesivamente
#
# Underfull \hbox (badness 10000) in paragraph at lines 4210--4210
# []\OT1/phv/m/n/10 correspondencia
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 4150--4211
# []
# [34]
# Underfull \hbox (badness 10000) in paragraph at lines 4239--4239
# []\OT1/phv/m/n/10 cuidadosamente
#
# Underfull \hbox (badness 10000) in paragraph at lines 4260--4260
# []\OT1/phv/m/n/10 econ[]omicamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 4211--4272
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 4274--4274
# []\OT1/phv/m/n/10 desplazamiento
#
# Underfull \hbox (badness 10000) in paragraph at lines 4330--4330
# []\OT1/phv/m/n/10 habitualmente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 4272--4333
# []
# [35]
# Underfull \hbox (badness 10000) in paragraph at lines 4362--4362
# []\OT1/phv/m/n/10 entretenimiento
#
# Underfull \hbox (badness 10000) in paragraph at lines 4378--4378
# []\OT1/phv/m/n/10 extremadamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 4333--4394
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 4423--4423
# []\OT1/phv/m/n/10 complementario
#
# Underfull \hbox (badness 10000) in paragraph at lines 4426--4426
# []\OT1/phv/m/n/10 simult[]aneamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 4394--4455
# []
# [36]
# Underfull \hbox (badness 10000) in paragraph at lines 4507--4507
# []\OT1/phv/m/n/10 cinematogr[]afico
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 4455--4517
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 4528--4528
# []\OT1/phv/m/n/10 tranquilamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 4517--4579
# []
# [37]
# Underfull \hbox (badness 10000) in paragraph at lines 4624--4624
# []\OT1/phv/m/n/10 enormemente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 4579--4641
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 4690--4690
# []\OT1/phv/m/n/10 esencialmente
#
# Underfull \hbox (badness 10000) in paragraph at lines 4699--4699
# []\OT1/phv/m/n/10 tradicionalmente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 4641--4702
# []
# [38]
# Underfull \hbox (badness 10000) in paragraph at lines 4704--4704
# []\OT1/phv/m/n/10 permanentemente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 4702--4764
# []
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 4764--4827
# []
# [39]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 4827--4890
# []
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 4890--4953
# []
# [40]
# Underfull \hbox (badness 10000) in paragraph at lines 4989--4989
# []\OT1/phv/m/n/10 hispanoamericano
# )
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 4953--26
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 4953--26
#
# (/home/jelle/wd/words/spanish/output/spanish_5000_two_column_alphabetical.aux)
# )
# (see the transcript file for additional information){/usr/share/texlive/texmf-d
# ist/fonts/enc/dvips/base/8r.enc}</usr/share/texlive/texmf-dist/fonts/type1/publ
# ic/amsfonts/cm/cmsy10.pfb></usr/share/texlive/texmf-dist/fonts/type1/urw/helvet
# ic/uhvb8a.pfb></usr/share/texlive/texmf-dist/fonts/type1/urw/helvetic/uhvr8a.pf
# b></usr/share/texlive/texmf-dist/fonts/type1/urw/helvetic/uhvro8a.pfb>
# Output written on /home/jelle/wd/words/spanish/output/spanish_5000_two_column_a
# lphabetical.pdf (40 pages, 183737 bytes).
# Transcript written on /home/jelle/wd/words/spanish/output/spanish_5000_two_colu
# mn_alphabetical.log.
# Latexmk: Examining '/home/jelle/wd/words/spanish/output/spanish_5000_two_column_alphabetical.log'
# === TeX engine is 'pdfTeX'
# Latexmk: All targets (/home/jelle/wd/words/spanish/output/spanish_5000_two_column_alphabetical.pdf) are up-to-date
# Latexmk: Log file says output to '/home/jelle/wd/words/spanish/output/spanish_5000_two_column_alphabetical.pdf'
# Latexmk: Undoing directory change
# Rc files read:
#   /etc/LatexMk
# Latexmk: This is Latexmk, John Collins, 20 November 2021, version: 4.76.
# Latexmk: Changing directory to 'format/'
# Rule 'pdflatex': File changes, etc:
#    Changed files, or newly in use since previous run(s):
#       'spanish_5000_two_column_shuffle.tex'
# ------------
# Run number 1 of rule 'pdflatex'
# ------------
# ------------
# Running 'pdflatex  -recorder -output-directory="/home/jelle/wd/words/spanish/output"  "spanish_5000_two_column_shuffle.tex"'
# ------------
# Latexmk: applying rule 'pdflatex'...
# This is pdfTeX, Version 3.141592653-2.6-1.40.22 (TeX Live 2022/dev/Debian) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./spanish_5000_two_column_shuffle.tex
# LaTeX2e <2021-11-15> patch level 1
# L3 programming layer <2022-01-21>
# (/usr/share/texlive/texmf-dist/tex/latex/base/article.cls
# Document Class: article 2021/10/04 v1.4n Standard LaTeX document class
# (/usr/share/texlive/texmf-dist/tex/latex/base/size10.clo))
# (/usr/share/texlive/texmf-dist/tex/latex/geometry/geometry.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/share/texlive/texmf-dist/tex/generic/iftex/ifvtex.sty
# (/usr/share/texlive/texmf-dist/tex/generic/iftex/iftex.sty)))
# (/usr/share/texlive/texmf-dist/tex/latex/blindtext/blindtext.sty
# (/usr/share/texlive/texmf-dist/tex/latex/tools/xspace.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/base/inputenc.sty
# (/usr/share/texlive/texmf-dist/tex/latex/ucs/utf8x.def))
# (/usr/share/texlive/texmf-dist/tex/latex/ucs/ucs.sty
# (/usr/share/texlive/texmf-dist/tex/latex/ucs/data/uni-global.def))
# (/usr/share/texlive/texmf-dist/tex/latex/supertabular/supertabular.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/tools/array.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/psnfss/helvet.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/psnfss/ot1phv.fd)
# (/usr/share/texlive/texmf-dist/tex/latex/l3backend/l3backend-pdftex.def)
# (/home/jelle/wd/words/spanish/output/spanish_5000_two_column_shuffle.aux)
# *geometry* driver: auto-detecting
# *geometry* detected driver: pdftex
# (/usr/share/texlive/texmf-dist/tex/latex/ucs/ucsencs.def)
# No file spanish_5000_two_column_shuffle.toc.
#
# (/home/jelle/wd/words/spanish/output/../build/spanish_5000_two_column_shuffle.t
# ex
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1--1
# []
# (/usr/share/texlive/texmf-dist/tex/latex/ucs/data/uni-0.def)
# Underfull \hbox (badness 10000) in paragraph at lines 25--25
# []\OT1/phv/m/n/10 acontecimiento
#
# Underfull \hbox (badness 10000) in paragraph at lines 43--43
# []\OT1/phv/m/n/10 permanentemente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1--55
# []
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 55--110
# []
# [1{/var/lib/texmf/fonts/map/pdftex/updmap/pdftex.map}]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 110--172
# []
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 172--235
# []
# [2]
# Underfull \hbox (badness 10000) in paragraph at lines 239--239
# []\OT1/phv/m/n/10 desgraciadamente
#
# Underfull \hbox (badness 10000) in paragraph at lines 270--270
# []\OT1/phv/m/n/10 suficientemente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 235--296
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 308--308
# []\OT1/phv/m/n/10 gubernamental
#
# Underfull \hbox (badness 10000) in paragraph at lines 348--348
# []\OT1/phv/m/n/10 profundamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 296--357
# []
# [3]
# Underfull \hbox (badness 10000) in paragraph at lines 381--381
# []\OT1/phv/m/n/10 afortunadamente
#
# Underfull \hbox (badness 10000) in paragraph at lines 405--405
# []\OT1/phv/m/n/10 aparentemente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 357--418
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 438--438
# []\OT1/phv/m/n/10 definitivamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 418--480
# []
# [4]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 480--543
# []
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 543--606
# []
# [5]
# Underfull \hbox (badness 10000) in paragraph at lines 608--608
# []\OT1/phv/m/n/10 estadounidense
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 606--668
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 729--729
# []\OT1/phv/m/n/10 latinoamericano
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 668--730
# []
# [6]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 730--793
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 799--799
# []\OT1/phv/m/n/10 enfrentamiento
#
# Underfull \hbox (badness 10000) in paragraph at lines 852--852
# []\OT1/phv/m/n/10 tradicionalmente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 793--853
# []
# [7]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 853--916
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 964--964
# []\OT1/phv/m/n/10 inmediatamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 916--978
# []
# [8]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 978--1041
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 1044--1044
# []\OT1/phv/m/n/10 simult[]aneamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1041--1103
# []
# [9]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1103--1166
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 1194--1194
# []\OT1/phv/m/n/10 posteriormente
#
# Underfull \hbox (badness 10000) in paragraph at lines 1214--1214
# []\OT1/phv/m/n/10 norteamericano
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1166--1227
# []
# [10]
# Underfull \hbox (badness 10000) in paragraph at lines 1250--1250
# []\OT1/phv/m/n/10 exclusivamente
#
# Underfull \hbox (badness 10000) in paragraph at lines 1282--1282
# []\OT1/phv/m/n/10 perfectamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1227--1288
# []
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1288--1351
# []
# [11]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1351--1414
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 1418--1418
# []\OT1/phv/m/n/10 correspondiente
#
# Underfull \hbox (badness 10000) in paragraph at lines 1470--1470
# []\OT1/phv/m/n/10 recientemente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1414--1475
# []
# [12]
# Underfull \hbox (badness 10000) in paragraph at lines 1499--1499
# []\OT1/phv/m/n/10 completamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1475--1537
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 1581--1581
# []\OT1/phv/m/n/10 extremadamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1537--1599
# []
# [13]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1599--1662
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 1718--1718
# []\OT1/phv/m/n/10 frecuentemente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1662--1724
# []
# [14]
# Underfull \hbox (badness 10000) in paragraph at lines 1761--1761
# []\OT1/phv/m/n/10 supuestamente
#
# Underfull \hbox (badness 10000) in paragraph at lines 1785--1785
# []\OT1/phv/m/n/10 tranquilamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1724--1786
# []
# (/usr/share/texlive/texmf-dist/tex/latex/ucs/data/uni-32.def)
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1786--1849
# []
# [15]
# Underfull \hbox (badness 10000) in paragraph at lines 1904--1904
# []\OT1/phv/m/n/10 pr[]acticamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1849--1911
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 1920--1920
# []\OT1/phv/m/n/10 habitualmente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1911--1973
# []
# [16]
# Underfull \hbox (badness 10000) in paragraph at lines 2015--2015
# []\OT1/phv/m/n/10 administrador
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1973--2035
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 2076--2076
# []\OT1/phv/m/n/10 funcionamiento
#
# Underfull \hbox (badness 10000) in paragraph at lines 2092--2092
# []\OT1/phv/m/n/10 verdaderamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 2035--2096
# []
# [17]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 2096--2159
# []
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 2159--2222
# []
# [18]
# Underfull \hbox (badness 10000) in paragraph at lines 2265--2265
# []\OT1/phv/m/n/10 principalmente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 2222--2284
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 2291--2291
# []\OT1/phv/m/n/10 concretamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 2284--2346
# []
# [19]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 2346--2409
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 2471--2471
# []\OT1/phv/m/n/10 responsabilidad
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 2409--2472
# []
# [20]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 2472--2535
# []
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 2535--2598
# []
# [21]
# Underfull \hbox (badness 10000) in paragraph at lines 2619--2619
# []\OT1/phv/m/n/10 establecimiento
#
# Underfull \hbox (badness 10000) in paragraph at lines 2642--2642
# []\OT1/phv/m/n/10 reconocimiento
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 2598--2659
# []
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 2659--2722
# []
# [22]
# Underfull \hbox (badness 10000) in paragraph at lines 2725--2725
# []\OT1/phv/m/n/10 espec[]^^Pficamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 2722--2784
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 2812--2812
# []\OT1/phv/m/n/10 correspondencia
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 2784--2846
# []
# [23]
# Underfull \hbox (badness 10000) in paragraph at lines 2851--2851
# []\OT1/phv/m/n/10 autom[]aticamente
#
# Underfull \hbox (badness 10000) in paragraph at lines 2886--2886
# []\OT1/phv/m/n/10 descubrimiento
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 2846--2906
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 2914--2914
# []\OT1/phv/m/n/10 sucesivamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 2906--2968
# []
# [24]
# Underfull \hbox (badness 10000) in paragraph at lines 2995--2995
# []\OT1/phv/m/n/10 entretenimiento
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 2968--3030
# []
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 3030--3093
# []
# [25]
# Underfull \hbox (badness 10000) in paragraph at lines 3152--3152
# []\OT1/phv/m/n/10 cuidadosamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 3093--3155
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 3188--3188
# []\OT1/phv/m/n/10 hispanoamericano
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 3155--3217
# []
# [26]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 3217--3280
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 3294--3294
# []\OT1/phv/m/n/10 anteriormente
#
# Underfull \hbox (badness 10000) in paragraph at lines 3315--3315
# []\OT1/phv/m/n/10 lamentablemente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 3280--3341
# []
# [27]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 3341--3404
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 3445--3445
# []\OT1/phv/m/n/10 especialmente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 3404--3466
# []
# [28]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 3466--3529
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 3576--3576
# []\OT1/phv/m/n/10 correctamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 3529--3591
# []
# [29]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 3591--3654
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 3694--3694
# []\OT1/phv/m/n/10 constantemente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 3654--3716
# []
# [30]
# Underfull \hbox (badness 10000) in paragraph at lines 3719--3719
# []\OT1/phv/m/n/10 fundamentalmente
#
# Underfull \hbox (badness 10000) in paragraph at lines 3753--3753
# []\OT1/phv/m/n/10 personalmente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 3716--3777
# []
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 3777--3840
# []
# [31]
# Underfull \hbox (badness 10000) in paragraph at lines 3879--3879
# []\OT1/phv/m/n/10 indudablemente
#
# Underfull \hbox (badness 10000) in paragraph at lines 3880--3880
# []\OT1/phv/m/n/10 aproximadamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 3840--3901
# []
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 3901--3964
# []
# [32]
# Underfull \hbox (badness 10000) in paragraph at lines 4012--4012
# []\OT1/phv/m/n/10 enormemente
#
# Underfull \hbox (badness 10000) in paragraph at lines 4013--4013
# []\OT1/phv/m/n/10 mantenimiento
#
# Underfull \hbox (badness 10000) in paragraph at lines 4016--4016
# []\OT1/phv/m/n/10 vicepresidente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 3964--4024
# []
#
# Overfull \hbox (3.88509pt too wide) in paragraph at lines 4041--4041
# []\OT1/phv/m/n/10 independientemente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 4024--4086
# []
# [33]
# Underfull \hbox (badness 10000) in paragraph at lines 4088--4088
# []\OT1/phv/m/n/10 comportamiento
#
# Underfull \hbox (badness 10000) in paragraph at lines 4126--4126
# []\OT1/phv/m/n/10 respectivamente
#
# Underfull \hbox (badness 10000) in paragraph at lines 4138--4138
# []\OT1/phv/m/n/10 probablemente
#
# Underfull \hbox (badness 10000) in paragraph at lines 4141--4141
# []\OT1/phv/m/n/10 necesariamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 4086--4145
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 4206--4206
# []\OT1/phv/m/n/10 contempor[]aneo
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 4145--4207
# []
# [34]
# Underfull \hbox (badness 10000) in paragraph at lines 4260--4260
# []\OT1/phv/m/n/10 econ[]omicamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 4207--4269
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 4282--4282
# ...
# Rule 'pdflatex': File changes, etc:
#    Changed files, or newly in use since previous run(s):
#       '/home/jelle/wd/words/spanish/output/spanish_5000_two_column_shuffle.aux'
#       '/home/jelle/wd/words/spanish/output/spanish_5000_two_column_shuffle.toc'
# ------------
# Run number 2 of rule 'pdflatex'
# ------------
# ------------
# Running 'pdflatex  -recorder -output-directory="/home/jelle/wd/words/spanish/output"  "spanish_5000_two_column_shuffle.tex"'
# ------------
# (/usr/share/texlive/texmf-dist/tex/latex/ucs/utf8x.def))
# (/usr/share/texlive/texmf-dist/tex/latex/ucs/ucs.sty
# (/usr/share/texlive/texmf-dist/tex/latex/ucs/data/uni-global.def))
# (/usr/share/texlive/texmf-dist/tex/latex/supertabular/supertabular.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/tools/array.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/psnfss/helvet.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/psnfss/ot1phv.fd)
# (/usr/share/texlive/texmf-dist/tex/latex/l3backend/l3backend-pdftex.def)
# (/home/jelle/wd/words/spanish/output/spanish_5000_two_column_shuffle.aux)
# *geometry* driver: auto-detecting
# *geometry* detected driver: pdftex
# (/usr/share/texlive/texmf-dist/tex/latex/ucs/ucsencs.def)
# (/home/jelle/wd/words/spanish/output/spanish_5000_two_column_shuffle.toc)
# (/home/jelle/wd/words/spanish/output/../build/spanish_5000_two_column_shuffle.t
# ex
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1--1
# []
# (/usr/share/texlive/texmf-dist/tex/latex/ucs/data/uni-0.def)
# Underfull \hbox (badness 10000) in paragraph at lines 25--25
# []\OT1/phv/m/n/10 acontecimiento
#
# Underfull \hbox (badness 10000) in paragraph at lines 43--43
# []\OT1/phv/m/n/10 permanentemente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1--54
# []
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 54--109
# []
# [1{/var/lib/texmf/fonts/map/pdftex/updmap/pdftex.map}]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 109--171
# []
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 171--234
# []
# [2]
# Underfull \hbox (badness 10000) in paragraph at lines 239--239
# []\OT1/phv/m/n/10 desgraciadamente
#
# Underfull \hbox (badness 10000) in paragraph at lines 270--270
# []\OT1/phv/m/n/10 suficientemente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 234--295
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 308--308
# []\OT1/phv/m/n/10 gubernamental
#
# Underfull \hbox (badness 10000) in paragraph at lines 348--348
# []\OT1/phv/m/n/10 profundamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 295--356
# []
# [3]
# Underfull \hbox (badness 10000) in paragraph at lines 381--381
# []\OT1/phv/m/n/10 afortunadamente
#
# Underfull \hbox (badness 10000) in paragraph at lines 405--405
# []\OT1/phv/m/n/10 aparentemente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 356--417
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 438--438
# []\OT1/phv/m/n/10 definitivamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 417--479
# []
# [4]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 479--542
# []
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 542--605
# []
# [5]
# Underfull \hbox (badness 10000) in paragraph at lines 608--608
# []\OT1/phv/m/n/10 estadounidense
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 605--667
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 729--729
# []\OT1/phv/m/n/10 latinoamericano
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 667--730
# []
# [6]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 730--793
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 799--799
# []\OT1/phv/m/n/10 enfrentamiento
#
# Underfull \hbox (badness 10000) in paragraph at lines 852--852
# []\OT1/phv/m/n/10 tradicionalmente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 793--853
# []
# [7]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 853--916
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 964--964
# []\OT1/phv/m/n/10 inmediatamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 916--978
# []
# [8]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 978--1041
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 1044--1044
# []\OT1/phv/m/n/10 simult[]aneamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1041--1103
# []
# [9]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1103--1166
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 1194--1194
# []\OT1/phv/m/n/10 posteriormente
#
# Underfull \hbox (badness 10000) in paragraph at lines 1214--1214
# []\OT1/phv/m/n/10 norteamericano
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1166--1227
# []
# [10]
# Underfull \hbox (badness 10000) in paragraph at lines 1250--1250
# []\OT1/phv/m/n/10 exclusivamente
#
# Underfull \hbox (badness 10000) in paragraph at lines 1282--1282
# []\OT1/phv/m/n/10 perfectamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1227--1288
# []
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1288--1351
# []
# [11]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1351--1414
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 1418--1418
# []\OT1/phv/m/n/10 correspondiente
#
# Underfull \hbox (badness 10000) in paragraph at lines 1470--1470
# []\OT1/phv/m/n/10 recientemente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1414--1475
# []
# [12]
# Underfull \hbox (badness 10000) in paragraph at lines 1499--1499
# []\OT1/phv/m/n/10 completamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1475--1537
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 1581--1581
# []\OT1/phv/m/n/10 extremadamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1537--1599
# []
# [13]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1599--1662
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 1718--1718
# []\OT1/phv/m/n/10 frecuentemente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1662--1724
# []
# [14]
# Underfull \hbox (badness 10000) in paragraph at lines 1761--1761
# []\OT1/phv/m/n/10 supuestamente
#
# Underfull \hbox (badness 10000) in paragraph at lines 1785--1785
# []\OT1/phv/m/n/10 tranquilamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1724--1786
# []
# (/usr/share/texlive/texmf-dist/tex/latex/ucs/data/uni-32.def)
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1786--1849
# []
# [15]
# Underfull \hbox (badness 10000) in paragraph at lines 1904--1904
# []\OT1/phv/m/n/10 pr[]acticamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1849--1911
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 1920--1920
# []\OT1/phv/m/n/10 habitualmente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1911--1973
# []
# [16]
# Underfull \hbox (badness 10000) in paragraph at lines 2015--2015
# []\OT1/phv/m/n/10 administrador
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1973--2035
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 2076--2076
# []\OT1/phv/m/n/10 funcionamiento
#
# Underfull \hbox (badness 10000) in paragraph at lines 2092--2092
# []\OT1/phv/m/n/10 verdaderamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 2035--2096
# []
# [17]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 2096--2159
# []
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 2159--2222
# []
# [18]
# Underfull \hbox (badness 10000) in paragraph at lines 2265--2265
# []\OT1/phv/m/n/10 principalmente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 2222--2284
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 2291--2291
# []\OT1/phv/m/n/10 concretamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 2284--2346
# []
# [19]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 2346--2409
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 2471--2471
# []\OT1/phv/m/n/10 responsabilidad
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 2409--2472
# []
# [20]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 2472--2535
# []
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 2535--2598
# []
# [21]
# Underfull \hbox (badness 10000) in paragraph at lines 2619--2619
# []\OT1/phv/m/n/10 establecimiento
#
# Underfull \hbox (badness 10000) in paragraph at lines 2642--2642
# []\OT1/phv/m/n/10 reconocimiento
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 2598--2659
# []
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 2659--2722
# []
# [22]
# Underfull \hbox (badness 10000) in paragraph at lines 2725--2725
# []\OT1/phv/m/n/10 espec[]^^Pficamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 2722--2784
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 2812--2812
# []\OT1/phv/m/n/10 correspondencia
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 2784--2846
# []
# [23]
# Underfull \hbox (badness 10000) in paragraph at lines 2851--2851
# []\OT1/phv/m/n/10 autom[]aticamente
#
# Underfull \hbox (badness 10000) in paragraph at lines 2886--2886
# []\OT1/phv/m/n/10 descubrimiento
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 2846--2906
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 2914--2914
# []\OT1/phv/m/n/10 sucesivamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 2906--2968
# []
# [24]
# Underfull \hbox (badness 10000) in paragraph at lines 2995--2995
# []\OT1/phv/m/n/10 entretenimiento
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 2968--3030
# []
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 3030--3093
# []
# [25]
# Underfull \hbox (badness 10000) in paragraph at lines 3152--3152
# []\OT1/phv/m/n/10 cuidadosamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 3093--3155
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 3188--3188
# []\OT1/phv/m/n/10 hispanoamericano
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 3155--3217
# []
# [26]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 3217--3280
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 3294--3294
# []\OT1/phv/m/n/10 anteriormente
#
# Underfull \hbox (badness 10000) in paragraph at lines 3315--3315
# []\OT1/phv/m/n/10 lamentablemente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 3280--3341
# []
# [27]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 3341--3404
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 3445--3445
# []\OT1/phv/m/n/10 especialmente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 3404--3466
# []
# [28]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 3466--3529
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 3576--3576
# []\OT1/phv/m/n/10 correctamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 3529--3591
# []
# [29]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 3591--3654
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 3694--3694
# []\OT1/phv/m/n/10 constantemente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 3654--3716
# []
# [30]
# Underfull \hbox (badness 10000) in paragraph at lines 3719--3719
# []\OT1/phv/m/n/10 fundamentalmente
#
# Underfull \hbox (badness 10000) in paragraph at lines 3753--3753
# []\OT1/phv/m/n/10 personalmente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 3716--3777
# []
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 3777--3840
# []
# [31]
# Underfull \hbox (badness 10000) in paragraph at lines 3879--3879
# []\OT1/phv/m/n/10 indudablemente
#
# Underfull \hbox (badness 10000) in paragraph at lines 3880--3880
# []\OT1/phv/m/n/10 aproximadamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 3840--3901
# []
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 3901--3964
# []
# [32]
# Underfull \hbox (badness 10000) in paragraph at lines 4012--4012
# []\OT1/phv/m/n/10 enormemente
#
# Underfull \hbox (badness 10000) in paragraph at lines 4013--4013
# []\OT1/phv/m/n/10 mantenimiento
#
# Underfull \hbox (badness 10000) in paragraph at lines 4016--4016
# []\OT1/phv/m/n/10 vicepresidente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 3964--4024
# []
#
# Overfull \hbox (3.88509pt too wide) in paragraph at lines 4041--4041
# []\OT1/phv/m/n/10 independientemente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 4024--4086
# []
# [33]
# Underfull \hbox (badness 10000) in paragraph at lines 4088--4088
# []\OT1/phv/m/n/10 comportamiento
#
# Underfull \hbox (badness 10000) in paragraph at lines 4126--4126
# []\OT1/phv/m/n/10 respectivamente
#
# Underfull \hbox (badness 10000) in paragraph at lines 4138--4138
# []\OT1/phv/m/n/10 probablemente
#
# Underfull \hbox (badness 10000) in paragraph at lines 4141--4141
# []\OT1/phv/m/n/10 necesariamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 4086--4145
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 4206--4206
# []\OT1/phv/m/n/10 contempor[]aneo
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 4145--4207
# []
# [34]
# Underfull \hbox (badness 10000) in paragraph at lines 4260--4260
# []\OT1/phv/m/n/10 econ[]omicamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 4207--4269
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 4282--4282
# []\OT1/phv/m/n/10 cinematogr[]afico
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 4269--4331
# []
# [35]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 4331--4394
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 4450--4450
# []\OT1/phv/m/n/10 desplazamiento
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 4394--4456
# []
# [36]
# Underfull \hbox (badness 10000) in paragraph at lines 4513--4513
# []\OT1/phv/m/n/10 evidentemente
#
# Underfull \hbox (badness 10000) in paragraph at lines 4517--4517
# []\OT1/phv/m/n/10 particularmente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 4456--4518
# []
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 4518--4581
# []
# [37]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 4581--4644
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 4706--4706
# []\OT1/phv/m/n/10 complementario
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 4644--4707
# []
# [38]
# Underfull \hbox (badness 10000) in paragraph at lines 4719--4719
# []\OT1/phv/m/n/10 absolutamente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 4707--4769
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 4790--4790
# []\OT1/phv/m/n/10 continuamente
# (/usr/share/texlive/texmf-dist/tex/latex/ucs/data/uni-34.def)
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 4769--4831
# []
# [39]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 4831--4894
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 4920--4920
# []\OT1/phv/m/n/10 esencialmente
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 4894--4956
# []
# [40])
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 4956--26
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 4956--26
#
# (/home/jelle/wd/words/spanish/output/spanish_5000_two_column_shuffle.aux) )
# (see the transcript file for additional information){/usr/share/texlive/texmf-d
# ist/fonts/enc/dvips/base/8r.enc}</usr/share/texlive/texmf-dist/fonts/type1/publ
# ic/amsfonts/cm/cmsy10.pfb></usr/share/texlive/texmf-dist/fonts/type1/urw/helvet
# ic/uhvb8a.pfb></usr/share/texlive/texmf-dist/fonts/type1/urw/helvetic/uhvr8a.pf
# b></usr/share/texlive/texmf-dist/fonts/type1/urw/helvetic/uhvro8a.pfb>
# Output written on /home/jelle/wd/words/spanish/output/spanish_5000_two_column_s
# huffle.pdf (40 pages, 184926 bytes).
# Transcript written on /home/jelle/wd/words/spanish/output/spanish_5000_two_colu
# mn_shuffle.log.
# Latexmk: Examining '/home/jelle/wd/words/spanish/output/spanish_5000_two_column_shuffle.log'
# === TeX engine is 'pdfTeX'
# Latexmk: All targets (/home/jelle/wd/words/spanish/output/spanish_5000_two_column_shuffle.pdf) are up-to-date
# Latexmk: Log file says output to '/home/jelle/wd/words/spanish/output/spanish_5000_two_column_shuffle.pdf'
# Latexmk: Undoing directory change
# 0

# %%
# two column, cefr by rank
import re
# Fix supertabular and add \textit to type
column_format = 'p{1.2in}p{2.3in}p{1.2in}p{2.3in}'
def fix_latex_line(line):
    if re.match(r"^\\begin{supertabular}", line):
        # Add column_format to supertabular}
        return '\\begin{supertabular}'+'{'+column_format+'}'
    if re.match(r"^\\.*{tabular}", line):
        # Remove {tabular}
        return ''
    if re.match(r"^\w+\s.*\(\w+\s?\w+?\)", line):
        # Italics
        return re.sub(r"(^\w+\s.*)(\(\w+\s?\w+?\))", r"\1\\textit{\2}", line)
    return line

data = load_data2()
data_by_cefr = [
    data.iloc[:1000], #A1
    data.iloc[1000:2000], #A2
    data.iloc[2000:3000], #B1
    data.iloc[3000:4000], #B2
    data.iloc[4000:], #C1
    ]

cefrs = ['A1', 'A2', 'B1', 'B2', 'C1']
for i, data_slice in enumerate(data_by_cefr):
    if data_slice.empty:
        continue
    cefr = cefrs[i]
    data_slice = data_slice[["word", "english", "type"]]
    data_slice["word"] = data_slice.apply(lambda row: f"{row.word.strip()} ({row.type.strip()})" , axis=1)
    data_slice = data_slice[["word", "english"]]

    #data_slice = data_slice.sort_values('word')
    #data_slice = data_slice.rename(columns={'word' : f'word ({cefr})'})

    style = data_slice.style.format(
        escape="latex",
        )
    style = style.hide(axis='index')
    style = style.hide(axis='columns')

    latex = style.to_latex(
        environment='supertabular',
        column_format=column_format
    )

    latex_lines = latex.splitlines()

    latex = '\n'.join((map(fix_latex_line, latex_lines)))

    filename = f'spanish_5000_two_column_shuffle_{cefr}'
    with open(f'build/{filename}.tex', 'w') as f:
        f.write(latex)
# Out:
# /tmp/ipykernel_63091/4273685475.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_slice["word"] = data_slice.apply(lambda row: f"{row.word.strip()} ({row.type.strip()})" , axis=1)
# /tmp/ipykernel_63091/4273685475.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_slice["word"] = data_slice.apply(lambda row: f"{row.word.strip()} ({row.type.strip()})" , axis=1)
# /tmp/ipykernel_63091/4273685475.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_slice["word"] = data_slice.apply(lambda row: f"{row.word.strip()} ({row.type.strip()})" , axis=1)
# /tmp/ipykernel_63091/4273685475.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_slice["word"] = data_slice.apply(lambda row: f"{row.word.strip()} ({row.type.strip()})" , axis=1)
# /tmp/ipykernel_63091/4273685475.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_slice["word"] = data_slice.apply(lambda row: f"{row.word.strip()} ({row.type.strip()})" , axis=1)

# %%
# two column, cefr by rank
import re
# Fix supertabular and add \textit to type
column_format = 'p{1.2in}p{2.3in}p{1.2in}p{2.3in}'
def fix_latex_line(line):
    if re.match(r"^\\begin{supertabular}", line):
        # Add column_format to supertabular}
        return '\\begin{supertabular}'+'{'+column_format+'}'
    if re.match(r"^\\.*{tabular}", line):
        # Remove {tabular}
        return ''
    if re.match(r"^\w+\s.*\(\w+\s?\w+?\)", line):
        # Italics
        return re.sub(r"(^\w+\s.*)(\(\w+\s?\w+?\))", r"\1\\textit{\2}", line)
    return line

data = load_data2()
data["example_spanish"] = data.apply(lambda row: replace_word_in_field_with_underscore(row.word, row.example_spanish) , axis=1)
data_by_cefr = [
    data.iloc[:1000], #A1
    data.iloc[1000:2000], #A2
    data.iloc[2000:3000], #B1
    data.iloc[3000:4000], #B2
    data.iloc[4000:], #C1
    ]

cefrs = ['A1', 'A2', 'B1', 'B2', 'C1']
for i, data_slice in enumerate(data_by_cefr):
    if data_slice.empty:
        continue
    cefr = cefrs[i]
    data_slice = data_slice[["word", "english", "type"]]
    data_slice["word"] = data_slice.apply(lambda row: f"{row.word.strip()} ({row.type.strip()})" , axis=1)
    data_slice = data_slice[["word", "english"]]

    data_slice = data_slice.sort_values('word')
    #data_slice = data_slice.rename(columns={'word' : f'word ({cefr})'})

    style = data_slice.style.format(
        escape="latex",
        )
    style = style.hide(axis='index')
    style = style.hide(axis='columns')

    latex = style.to_latex(
        environment='supertabular',
        column_format=column_format
    )

    latex_lines = latex.splitlines()

    latex = '\n'.join((map(fix_latex_line, latex_lines)))

    filename = f'{DATASET}_two_column_alphabetical_{cefr}'
    with open(f'build/{filename}.tex', 'w') as f:
        f.write(latex)

# %%
# 4 column with examples alphabetical
import re
# Fix supertabular and add \textit to type
#column_format = 'p{1.2in}p{2.3in}p{1.2in}p{2.3in}'
# 0.787401575 inches margin total
# A4 width 8.3 inch
#column_format = 'p{1.0in}p{3.0in}p{3.0in}' # total 8.3in - 0.7874in - column_width
column_format = 'p{0.8in}p{1.1in}p{2.55in}p{2.55in}' # total 8.3in - 0.7874in - column_width
#column_format = 'ccc'
def fix_latex_line(line):
    if re.match(r"^\\begin{supertabular}", line):
        # Add column_format to supertabular}
        return '\\begin{supertabular}'+'{'+column_format+'}'
    if re.match(r"^\\.*{tabular}", line):
        # Remove {tabular}
        return ''
    if re.match(r"^\w+\s.*\(\w+\s?\w+?\)", line):
        # Italics
        return re.sub(r"(^\w+\s.*)(\(\w+\s?\w+?\))", r"\1\\textit{\2}", line)
    return line

data = load_data2()
data["example_spanish"] = data.apply(lambda row: replace_word_in_field_with_underscore(row.word, row.example_spanish) , axis=1)
data_by_cefr = [
    data.iloc[:1000], #A1
    data.iloc[1000:2000], #A2
    data.iloc[2000:3000], #B1
    data.iloc[3000:4000], #B2
    data.iloc[4000:], #C1
    ]

cefrs = ['A1', 'A2', 'B1', 'B2', 'C1']
for i, data_slice in enumerate(data_by_cefr):
    if data_slice.empty:
        continue
    cefr = cefrs[i]
    data_slice = data_slice[["word", "english", "example_spanish", "example_english", "type"]]
    data_slice["word"] = data_slice.apply(lambda row: f"{row.word.strip()} ({row.type.strip()})" , axis=1)
    data_slice = data_slice[["word", "english", "example_spanish", "example_english"]]


    data_slice = data_slice.sort_values('word')
    #data_slice = data_slice.rename(columns={'word' : f'word ({cefr})'})

    style = data_slice.style.format(
        escape="latex",
        )
    style = style.hide(axis='index')
    style = style.hide(axis='columns')

    latex = style.to_latex(
        environment='supertabular',
        column_format=column_format
    )

    latex_lines = latex.splitlines()

    latex = '\n'.join((map(fix_latex_line, latex_lines)))

    filename = f'spanish_5000_two_column_alphabetical_{cefr}_with_example'
    with open(f'build/{filename}.tex', 'w') as f:
        f.write(latex)
# Out:
# /tmp/ipykernel_63091/2496701175.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_slice["word"] = data_slice.apply(lambda row: f"{row.word.strip()} ({row.type.strip()})" , axis=1)
# /tmp/ipykernel_63091/2496701175.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_slice["word"] = data_slice.apply(lambda row: f"{row.word.strip()} ({row.type.strip()})" , axis=1)
# /tmp/ipykernel_63091/2496701175.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_slice["word"] = data_slice.apply(lambda row: f"{row.word.strip()} ({row.type.strip()})" , axis=1)
# /tmp/ipykernel_63091/2496701175.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_slice["word"] = data_slice.apply(lambda row: f"{row.word.strip()} ({row.type.strip()})" , axis=1)
# /tmp/ipykernel_63091/2496701175.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_slice["word"] = data_slice.apply(lambda row: f"{row.word.strip()} ({row.type.strip()})" , axis=1)

# %%
# 4 column with examples shuffle
import re
# Fix supertabular and add \textit to type
#column_format = 'p{1.2in}p{2.3in}p{1.2in}p{2.3in}'
# 0.787401575 inches margin total
# A4 width 8.3 inch
#column_format = 'p{1.0in}p{3.0in}p{3.0in}' # total 8.3in - 0.7874in - column_width
column_format = 'p{0.8in}p{1.1in}p{2.55in}p{2.55in}' # total 8.3in - 0.7874in - column_width
#column_format = 'ccc'
def fix_latex_line(line):
    if re.match(r"^\\begin{supertabular}", line):
        # Add column_format to supertabular}
        return '\\begin{supertabular}'+'{'+column_format+'}'
    if re.match(r"^\\.*{tabular}", line):
        # Remove {tabular}
        return ''
    if re.match(r"^\w+\s.*\(\w+\s?\w+?\)", line):
        # Italics
        return re.sub(r"(^\w+\s.*)(\(\w+\s?\w+?\))", r"\1\\textit{\2}", line)
    return line

data = load_data2()
data["example_spanish"] = data.apply(lambda row: replace_word_in_field_with_underscore(row.word, row.example_spanish) , axis=1)
data_by_cefr = [
    data.iloc[:1000], #A1
    data.iloc[1000:2000], #A2
    data.iloc[2000:3000], #B1
    data.iloc[3000:4000], #B2
    data.iloc[4000:], #C1
    ]

cefrs = ['A1', 'A2', 'B1', 'B2', 'C1']
for i, data_slice in enumerate(data_by_cefr):
    if data_slice.empty:
        continue
    cefr = cefrs[i]
    data_slice = data_slice[["word", "english", "example_spanish", "example_english", "type"]]
    data_slice["word"] = data_slice.apply(lambda row: f"{row.word.strip()} ({row.type.strip()})" , axis=1)
    data_slice = data_slice[["word", "english", "example_spanish", "example_english"]]

    #data_slice = data_slice.sort_values('word')
    #data_slice = data_slice.rename(columns={'word' : f'word ({cefr})'})

    style = data_slice.style.format(
        escape="latex",
        )
    style = style.hide(axis='index')
    style = style.hide(axis='columns')

    latex = style.to_latex(
        environment='supertabular',
        column_format=column_format
    )

    latex_lines = latex.splitlines()

    latex = '\n'.join((map(fix_latex_line, latex_lines)))

    filename = f'spanish_5000_two_column_shuffle_{cefr}_with_example'
    with open(f'build/{filename}.tex', 'w') as f:
        f.write(latex)
# Out:
# /tmp/ipykernel_63091/907187028.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_slice["word"] = data_slice.apply(lambda row: f"{row.word.strip()} ({row.type.strip()})" , axis=1)
# /tmp/ipykernel_63091/907187028.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_slice["word"] = data_slice.apply(lambda row: f"{row.word.strip()} ({row.type.strip()})" , axis=1)
# /tmp/ipykernel_63091/907187028.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_slice["word"] = data_slice.apply(lambda row: f"{row.word.strip()} ({row.type.strip()})" , axis=1)
# /tmp/ipykernel_63091/907187028.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_slice["word"] = data_slice.apply(lambda row: f"{row.word.strip()} ({row.type.strip()})" , axis=1)
# /tmp/ipykernel_63091/907187028.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_slice["word"] = data_slice.apply(lambda row: f"{row.word.strip()} ({row.type.strip()})" , axis=1)

# %% [markdown]
# ## 2 Column LateX word,type and definition by CEFR shuffle

# %%
# Run terminal cd format latexmk oxford*.tex to finish build pdfs
DATASET='spanish_5000'
cmd_build = f"latexmk -pdf -cd format/{DATASET}*.tex -outdir=../output" 
os.system(cmd_build)

# %%
# Clean any build files in output/
files_to_remove = ["*.fls", "*.log", "*.toc", "*.synctex*", "*.fdb*", "*.aux"]
cmd_cleanup_output = "rm "+" ".join(f"output/{f}" for f in files_to_remove)
cmd_cleanup_format = "rm "+" ".join(f"format/{f}" for f in files_to_remove+["*.pdf"])
cmd_cleanup_main = "rm "+" ".join(f"./{f}" for f in files_to_remove)
os.system(";".join((cmd_cleanup_format, cmd_cleanup_main, cmd_cleanup_output)))
