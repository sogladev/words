# %% [markdown]
# # Scrape epub frequency dictionary

# %%
#from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd

# %%
#driver = webdriver.Firefox()
#driver.get("https://www.oxfordlearnersdictionaries.com/wordlists/oxford3000-5000")

# %%
# Open book with calibre editor -> chapters as *.xlink.html -> export file
# Read xhtml data from file.
with open('data/alphabetical.xlink.xhtml', 'r') as chapter_alphabetical:
    content = chapter_alphabetical.read()
    soup = BeautifulSoup(content, 'html')
print(soup)
# Out:
# <?xml version='1.0' encoding='utf-8'?>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <title>A Frequency Dictionary of Spanish: Core Vocabulary for Learners</title>
# <link href="css/stylesheet.css" rel="stylesheet" type="text/css"/>
# <meta content="urn:uuid:ef0bf3dd-6627-4ef2-a354-0a8c4f5aefb7" name="Adept.expected.resource"/>
# </head>
# <body>
# <p class="pagenum"><span id="page258">p.258</span></p>
# <p class="chtitle"><a href="toc.xlink.xhtml#alpha"><span class="hyperlink">Alphabetical index</span></a></p>
# <div class="box">
# <p class="noindent"><span class="bold">Word family head</span>, <span class="italic">pos</span>, gloss<span class="italic">,</span> <span class="trade5">rank</span></p>
# </div>
# <p class="hh1">A</p>
# <p class="ulist"><span class="bold">a</span> <span class="lightoblique">prep</span> to, at <span class="trade5">8</span></p>
# <p class="ulist"><span class="bold">abajo</span> <span class="lightoblique">adv</span> down, below, downward <span class="trade5">788</span></p>
# <p class="ulist"><span class="bold">abandonado</span> <span class="lightoblique">adj</span> abandoned <span class="trade5">2896</span></p>
# <p class="ulist"><span class="bold">abandonar</span> <span class="lightoblique">v</span> to abandon, leave (a place) <span class="trade5">680</span></p>
# <p class="ulist"><span class="bold">abandono</span> <span class="lightoblique">nm</span> abandonment, desertion <span class="trade5">3463</span></p>
# <p class="ulist"><span class="bold">abarcar</span> <span class="lightoblique">v</span> to encompass, comprise <span class="trade5">2338</span></p>
# <p class="ulist"><span class="bold">abierto</span> <span class="lightoblique">adj</span> open, unlocked <span class="trade5">654</span></p>
# <p class="ulist"><span class="bold">abismo</span> <span class="lightoblique">nm</span> abyss, large gap <span class="trade5">4069</span></p>
# <p class="ulist"><span class="bold">abogado</span> <span class="lightoblique">nm/f</span> lawyer <span class="trade5">1211</span></p>
# <p class="ulist"><span class="bold">abordar</span> <span class="lightoblique">v</span> to board, get in/on <span class="trade5">2472</span></p>
# <p class="ulist"><span class="bold">aborto</span> <span class="lightoblique">nm</span> abortion <span class="trade5">3825</span></p>
# <p class="ulist"><span class="bold">abrazar</span> <span class="lightoblique">v</span> to hug, embrace <span class="trade5">1687</span></p>
# <p class="ulist"><span class="bold">abrazo</span> <span class="lightoblique">nm</span> hug, embrace <span class="trade5">2230</span></p>
# <p class="ulist"><span class="bold">abrigo</span> <span class="lightoblique">nm</span> overcoat, shelter <span class="trade5">3827</span></p>
# <p class="ulist"><span class="bold">abril</span> <span class="lightoblique">nm</span> April <span class="trade5">1064</span></p>
# <p class="ulist"><span class="bold">abrir</span> <span class="lightoblique">v</span> to open <span class="trade5">246</span></p>
# <p class="ulist"><span class="bold">absolutamente</span> <span class="lightoblique">adv</span> absolutely, completely <span class="trade5">1480</span></p>
# <p class="ulist"><span class="bold">absoluto</span> <span class="lightoblique">adj</span> absolute <span class="trade5">1096</span></p>
# <p class="ulist"><span class="bold">absorber</span> <span class="lightoblique">v</span> to absorb, soak up <span class="trade5">2831</span></p>
# <p class="ulist"><span class="bold">abstracto</span> <span class="lightoblique">adj</span> abstract <span class="trade5">3566</span></p>
# <p class="ulist"><span class="bold">absurdo</span> <span class="lightoblique">adj</span> absurd <span class="trade5">1757</span></p>
# <p class="ulist"><span class="bold">abuela</span> <span class="lightoblique">nf</span> grandmother <span class="trade5">783</span></p>
# <p class="ulist"><span class="bold">abuelo</span> <span class="lightoblique">nm</span> grandfather <span class="trade5">4796</span></p>
# <p class="ulist"><span class="bold">abundancia</span> <span class="lightoblique">nf</span> abundance <span class="trade5">4315</span></p>
# <p class="ulist"><span class="bold">abundante</span> <span class="lightoblique">adj</span> abundant, plentiful <span class="trade5">2784</span></p>
# <p class="ulist"><span class="bold">abundar</span> <span class="lightoblique">v</span> to be plentiful <span class="trade5">3797</span></p>
# <p class="ulist"><span class="bold">aburrido</span> <span class="lightoblique">adj</span> boring, bored <span class="trade5">3917</span></p>
# <p class="ulist"><span class="bold">aburrir</span> <span class="lightoblique">v</span> to bore, tire <span class="trade5">2975</span></p>
# <p class="ulist"><span class="bold">abusar</span> <span class="lightoblique">v</span> to abuse <span class="trade5">4468</span></p>
# <p class="ulist"><span class="bold">abuso</span> <span class="lightoblique">nm</span> abuse, misuse <span class="trade5">2899</span></p>
# <p class="ulist"><span class="bold">acá</span> <span class="lightoblique">adv</span> here, around here <span class="trade5">1010</span></p>
# <p class="ulist"><span class="bold">acabar</span> <span class="lightoblique">v</span> a. de V: to have just Ved; finish <span class="trade5">303</span></p>
# <p class="ulist"><span class="bold">academia</span> <span class="lightoblique">nf</span> academy <span class="trade5">2293</span></p>
# <p class="ulist"><span class="bold">académico</span> <span class="lightoblique">adj</span> academic <span class="trade5">2124</span></p>
# <p class="ulist"><span class="bold">acariciar</span> <span class="lightoblique">v</span> to stroke, fondle, caress <span class="trade5">1888</span></p>
# <p class="ulist"><span class="bold">acaso</span> <span class="lightoblique">adv</span> by chance, maybe <span class="trade5">1328</span></p>
# <p class="ulist"><span class="bold">acceder</span> <span class="lightoblique">v</span> to consent, agree, accede <span class="trade5">1768</span></p>
# <p class="ulist"><span class="bold">accesible</span> <span class="lightoblique">adj</span> accessible <span class="trade5">4965</span></p>
# <p class="ulist"><span class="bold">acceso</span> <span class="lightoblique">nm</span> access, entry <span class="trade5">1178</span></p>
# <p class="ulist"><span class="bold">accidente</span> <span class="lightoblique">nm</span> accident, irregularity <span class="trade5">1661</span></p>
# <p class="ulist"><span class="bold">acción</span> <span class="lightoblique">nf</span> action, act, deed <span class="trade5">404</span></p>
# <p class="ulist"><span class="bold">aceite</span> <span class="lightoblique">nm</span> oil <span class="trade5">2101</span></p>
# <p class="ulist"><span class="bold">acelerar</span> <span class="lightoblique">v</span> to accelerate, speed (up) <span class="trade5">3145</span></p>
# <p class="ulist"><span class="bold">acento</span> <span class="lightoblique">nm</span> accent, stress <span class="trade5">3244</span></p>
# <p class="ulist"><span class="bold">acentuar</span> <span class="lightoblique">v</span> to accent, stress <span class="trade5">3682</span></p>
# <p class="ulist"><span class="bold">aceptable</span> <span class="lightoblique">adj</span> acceptable, suitable <span class="trade5">5004</span></p>
# <p class="ulist"><span class="bold">aceptación</span> <span class="lightoblique">nf</span> acceptance, approval <span class="trade5">3342</span></p>
# <p class="ulist"><span class="bold">aceptar</span> <span class="lightoblique">v</span> to accept <span class="trade5">433</span></p>
# <p class="ulist"><span class="bold">acera</span> <span class="lightoblique">nf</span> sidewalk <span class="trade5">3854</span></p>
# <p class="ulist"><span class="bold">acerca</span> <span class="lightoblique">prep</span> about, concerning <span class="trade5">842</span></p>
# <p class="ulist"><span class="bold">acercar</span> <span class="lightoblique">v</span> to come near <span class="trade5">156</span></p>
# <p class="ulist"><span class="bold">acero</span> <span class="lightoblique">nm</span> steel <span class="trade5">3038</span></p>
# <p class="ulist"><span class="bold">acertar</span> <span class="lightoblique">v</span> to get right <span class="trade5">3831</span></p>
# <p class="ulist"><span class="bold">ácido</span> <span class="lightoblique">nm</span> acid <span class="trade5">2932</span></p>
# <p class="ulist"><span class="bold">aclarar</span> <span class="lightoblique">v</span> to clarify, clear up <span class="trade5">1505</span></p>
# <p class="ulist"><span class="bold">acoger</span> <span class="lightoblique">v</span> to welcome, accept <span class="trade5">2875</span></p>
# <p class="ulist"><span class="bold">acomodar</span> <span class="lightoblique">v</span> to be/make comfortable <span class="trade5">2419</span></p>
# <p class="ulist"><span class="bold">acompañar</span> <span class="lightoblique">v</span> to accompany <span class="trade5">606</span></p>
# <p class="ulist"><span class="bold">aconsejar</span> <span class="lightoblique">v</span> to advise, counsel <span class="trade5">2764</span></p>
# <p class="ulist"><span class="bold">acontecer</span> <span class="lightoblique">v</span> to happen, come about <span class="trade5">4584</span></p>
# <p class="ulist"><span class="bold">acontecimiento</span> <span class="lightoblique">nm</span> event, happening <span class="trade5">1668</span></p>
# <p class="ulist"><span class="bold">acordar</span> <span class="lightoblique">v</span> to remember, remind <span class="trade5">535</span></p>
# <p class="ulist"><span class="bold">acorde</span> <span class="lightoblique">nm</span> agreement, accord <span class="trade5">4276</span></p>
# <p class="ulist"><span class="bold">acostar</span> <span class="lightoblique">v</span> to put/go to bed <span class="trade5">1798</span></p>
# <p class="ulist"><span class="bold">acostumbrar</span> <span class="lightoblique">v</span> to be accustomed to <span class="trade5">1255</span></p>
# <p class="ulist"><span class="bold">acta</span> <span class="lightoblique">nf (el)</span> (meeting) proceedings, minutes <span class="trade5">4057</span></p>
# <p class="ulist"><span class="bold">actitud</span> <span class="lightoblique">nf</span> attitude <span class="trade5">835</span></p>
# <p class="ulist"><span class="bold">activar</span> <span class="lightoblique">v</span> to activate, stimulate <span class="trade5">3821</span></p>
# <p class="ulist"><span class="bold">actividad</span> <span class="lightoblique">nf</span> activity, action <span class="trade5">344</span></p>
# <p class="ulist"><span class="bold">activo</span> <span class="lightoblique">adj</span> active <span class="trade5">1278</span></p>
# <p class="ulist"><span class="bold">acto</span> <span class="lightoblique">nm</span> act, action <span class="trade5">673</span></p>
# <p class="ulist"><span class="bold">actor</span> <span class="lightoblique">nm</span> actor <span class="trade5">1533</span></p>
# <p class="ulist"><span class="bold">actriz</span> <span class="lightoblique">nf</span> actress <span class="trade5">3567</span></p>
# <p class="ulist"><span class="bold">actuación</span> <span class="lightoblique">nf</span> performance, acting <span class="trade5">1835</span></p>
# <p class="ulist"><span class="bold">actual</span> <span class="lightoblique">adj</span> current <span class="trade5">499</span></p>
# <p class="ulist"><span class="bold">actualidad</span> <span class="lightoblique">nf</span> present (time) <span class="trade5">1291</span></p>
# <p class="ulist"><span class="bold">actualización</span> <span class="lightoblique">nf</span> update, modernization <span class="trade5">3938</span></p>
# <p class="ulist"><span class="bold">actualizar</span> <span class="lightoblique">v</span> to update <span class="trade5">3426</span></p>
# <p class="ulist"><span class="bold">actualmente</span> <span class="lightoblique">adv</span> now, at present <span class="trade5">1037</span></p>
# <p class="ulist"><span class="bold">actuar</span> <span class="lightoblique">v</span> to act <span class="trade5">762</span></p>
# <p class="ulist"><span class="bold">acudir</span> <span class="lightoblique">v</span> to attend, go to, frequent <span class="trade5">1453</span></p>
# <p class="ulist"><span class="bold">acuerdo</span> <span class="lightoblique">nm</span> accord; de a.: in agreement <span class="trade5">348</span></p>
# <p class="ulist"><span class="bold">acumulación</span> <span class="lightoblique">nf</span> accumulation <span class="trade5">4426</span></p>
# <p class="ulist"><span class="bold">acumular</span> <span class="lightoblique">v</span> to accumulate, amass <span class="trade5">2132</span></p>
# <p class="ulist"><span class="bold">acusación</span> <span class="lightoblique">nf</span> accusation, charge <span class="trade5">3285</span></p>
# <p class="pagenum"><span id="page259">p.259</span></p>
# <p class="ulist"><span class="bold">acusado</span> <span class="lightoblique">nm/f</span> defendant, accused <span class="trade5">4989</span></p>
# <p class="ulist"><span class="bold">acusar</span> <span class="lightoblique">v</span> to accuse <span class="trade5">1712</span></p>
# <p class="ulist"><span class="bold">adaptación</span> <span class="lightoblique">nf</span> adaptation <span class="trade5">3291</span></p>
# <p class="ulist"><span class="bold">adaptar</span> <span class="lightoblique">v</span> to adapt <span class="trade5">2172</span></p>
# <p class="ulist"><span class="bold">adecuado</span> <span class="lightoblique">adj</span> adequate, suitable <span class="trade5">1223</span></p>
# <p class="ulist"><span class="bold">adelantar</span> <span class="lightoblique">v</span> to move forward <span class="trade5">2021</span></p>
# <p class="ulist"><span class="bold">adelante</span> <span class="lightoblique">adv</span> forward, further <span class="trade5">722</span></p>
# <p class="ulist"><span class="bold">ademán</span> <span class="lightoblique">nm</span> gesture, expression <span class="trade5">3598</span></p>
# <p class="ulist"><span class="bold">además</span> <span class="lightoblique">adv</span> also, as well, besides <span class="trade5">155</span></p>
# <p class="ulist"><span class="bold">adentro</span> <span class="lightoblique">adv</span> inside <span class="trade5">1602</span></p>
# <p class="ulist"><span class="bold">adherir</span> <span class="lightoblique">v</span> to adhere, attach <span class="trade5">4382</span></p>
# <p class="ulist"><span class="bold">adicional</span> <span class="lightoblique">adj</span> additional <span class="trade5">2738</span></p>
# <p class="ulist"><span class="bold">adiós</span> <span class="lightoblique">interj</span> goodbye <span class="trade5">2309</span></p>
# <p class="ulist"><span class="bold">adivinar</span> <span class="lightoblique">v</span> to guess, solve <span class="trade5">2201</span></p>
# <p class="ulist"><span class="bold">administración</span> <span class="lightoblique">nf</span> administration <span class="trade5">1147</span></p>
# <p class="ulist"><span class="bold">administrador</span> <span class="lightoblique">nm/f</span> administrator, manager <span class="trade5">3417</span></p>
# <p class="ulist"><span class="bold">administrar</span> <span class="lightoblique">v</span> to administer, manage <span class="trade5">2786</span></p>
# <p class="ulist"><span class="bold">administrativo</span> <span class="lightoblique">adj</span> administrative <span class="trade5">1980</span></p>
# <p class="ulist"><span class="bold">admirable</span> <span class="lightoblique">adj</span> admirable <span class="trade5">4561</span></p>
# <p class="ulist"><span class="bold">admiración</span> <span class="lightoblique">nf</span> admiration <span class="trade5">3284</span></p>
# <p class="ulist"><span class="bold">admirar</span> <span class="lightoblique">v</span> to admire <span class="trade5">2078</span></p>
# <p class="ulist"><span class="bold">admitir</span> <span class="lightoblique">v</span> to admit <span class="trade5">1483</span></p>
# <p class="ulist"><span class="bold">adolescencia</span> <span class="lightoblique">nf</span> adolescence <span class="trade5">3962</span></p>
# <p class="ulist"><span class="bold">adolescente</span> <span class="lightoblique">nc</span> adolescent <span class="trade5">2257</span></p>
# <p class="ulist"><span class="bold">adónde</span> <span class="lightoblique">adv</span> to where? <span class="trade5">3994</span></p>
# <p class="ulist"><span class="bold">adopción</span> <span class="lightoblique">nf</span> adoption <span class="trade5">4986</span></p>
# <p class="ulist"><span class="bold">adoptar</span> <span class="lightoblique">v</span> to adopt <span class="trade5">1347</span></p>
# <p class="ulist"><span class="bold">adorar</span> <span class="lightoblique">v</span> to worship, adore <span class="trade5">3096</span></p>
# <p class="ulist"><span class="bold">adornar</span> <span class="lightoblique">v</span> to adorn, to decorate <span class="trade5">3343</span></p>
# <p class="ulist"><span class="bold">adorno</span> <span class="lightoblique">nm</span> decoration, adornment <span class="trade5">4257</span></p>
# <p class="ulist"><span class="bold">adquirir</span> <span class="lightoblique">v</span> to acquire, get <span class="trade5">913</span></p>
# <p class="ulist"><span class="bold">adquisición</span> <span class="lightoblique">nf</span> acquisition <span class="trade5">3777</span></p>
# <p class="ulist"><span class="bold">adulto</span> <span class="lightoblique">nm</span> adult, grown-up <span class="trade5">1574</span></p>
# <p class="ulist"><span class="bold">adversario</span> <span class="lightoblique">nm</span> adversary <span class="trade5">4660</span></p>
# <p class="ulist"><span class="bold">advertencia</span> <span class="lightoblique">nf</span> warning, notice <span class="trade5">4041</span></p>
# <p class="ulist"><span class="bold">advertir</span> <span class="lightoblique">v</span> to notice, warn <span class="trade5">981</span></p>
# <p class="ulist"><span class="bold">aéreo</span> <span class="lightoblique">adj</span> aerial, air <span class="trade5">2235</span></p>
# <p class="ulist"><span class="bold">aeropuerto</span> <span class="lightoblique">nm</span> airport <span class="trade5">2492</span></p>
# <p class="ulist"><span class="bold">afán</span> <span class="lightoblique">nm</span> eagerness, zeal, effort <span class="trade5">3097</span></p>
# <p class="ulist"><span class="bold">afectar</span> <span class="lightoblique">v</span> to affect <span class="trade5">881</span></p>
# <p class="ulist"><span class="bold">afecto</span> <span class="lightoblique">nm</span> affection, fondness <span class="trade5">3230</span></p>
# <p class="ulist"><span class="bold">aferrar</span> <span class="lightoblique">v</span> to grasp, clutch <span class="trade5">3838</span></p>
# <p class="ulist"><span class="bold">afición</span> <span class="lightoblique">nf</span> fondness, interest <span class="trade5">3258</span></p>
# <p class="ulist"><span class="bold">aficionado</span> <span class="lightoblique">nm</span> fan, devotee <span class="trade5">3344</span></p>
# <p class="ulist"><span class="bold">afilar</span> <span class="lightoblique">v</span> to sharpen <span class="trade5">4768</span></p>
# <p class="ulist"><span class="bold">afirmación</span> <span class="lightoblique">nf</span> statement, assertion <span class="trade5">2892</span></p>
# <p class="ulist"><span class="bold">afirmar</span> <span class="lightoblique">v</span> to assert, affirm <span class="trade5">636</span></p>
# <p class="ulist"><span class="bold">aflojar</span> <span class="lightoblique">v</span> to loosen <span class="trade5">4827</span></p>
# <p class="ulist"><span class="bold">afortunadamente</span> <span class="lightoblique">adv</span> luckily, fortunately <span class="trade5">3655</span></p>
# <p class="ulist"><span class="bold">africano</span> <span class="lightoblique">adj</span> African <span class="trade5">3263</span></p>
# <p class="ulist"><span class="bold">afrontar</span> <span class="lightoblique">v</span> to face, confront <span class="trade5">3268</span></p>
# <p class="ulist"><span class="bold">afuera</span> <span class="lightoblique">adv</span> outside <span class="trade5">1413</span></p>
# <p class="ulist"><span class="bold">agachar</span> <span class="lightoblique">v</span> to duck, bend down <span class="trade5">4613</span></p>
# <p class="ulist"><span class="bold">agarrar</span> <span class="lightoblique">v</span> to grasp, catch <span class="trade5">1621</span></p>
# <p class="ulist"><span class="bold">agencia</span> <span class="lightoblique">nf</span> agency, branch <span class="trade5">1834</span></p>
# <p class="ulist"><span class="bold">agenda</span> <span class="lightoblique">nf</span> diary, agenda, schedule <span class="trade5">2988</span></p>
# <p class="ulist"><span class="bold">agente</span> <span class="lightoblique">nc</span> agent <span class="trade5">1493</span></p>
# <p class="ulist"><span class="bold">agitar</span> <span class="lightoblique">v</span> to shake, move <span class="trade5">2174</span></p>
# <p class="ulist"><span class="bold">agosto</span> <span class="lightoblique">nm</span> August <span class="trade5">931</span></p>
# <p class="ulist"><span class="bold">agotar</span> <span class="lightoblique">v</span> to exhaust, wear out, run out <span class="trade5">2332</span></p>
# <p class="ulist"><span class="bold">agradable</span> <span class="lightoblique">adj</span> nice, pleasant <span class="trade5">1997</span></p>
# <p class="ulist"><span class="bold">agradar</span> <span class="lightoblique">v</span> to please <span class="trade5">3446</span></p>
# <p class="ulist"><span class="bold">agradecer</span> <span class="lightoblique">v</span> to thank for <span class="trade5">1428</span></p>
# <p class="ulist"><span class="bold">agradecido</span> <span class="lightoblique">adj</span> grateful, thankful <span class="trade5">4339</span></p>
# <p class="ulist"><span class="bold">agrario</span> <span class="lightoblique">adj</span> agrarian, agricultural <span class="trade5">4121</span></p>
# <p class="ulist"><span class="bold">agravar</span> <span class="lightoblique">v</span> to aggravate <span class="trade5">4779</span></p>
# <p class="ulist"><span class="bold">agregar</span> <span class="lightoblique">v</span> to add, gather <span class="trade5">923</span></p>
# <p class="ulist"><span class="bold">agresión</span> <span class="lightoblique">nf</span> aggression, attack <span class="trade5">3590</span></p>
# <p class="ulist"><span class="bold">agresivo</span> <span class="lightoblique">adj</span> aggressive <span class="trade5">3259</span></p>
# <p class="ulist"><span class="bold">agrícola</span> <span class="lightoblique">adj</span> agricultural, farming <span class="trade5">2318</span></p>
# <p class="ulist"><span class="bold">agricultor</span> <span class="lightoblique">nm/f</span> farmer <span class="trade5">4438</span></p>
# <p class="ulist"><span class="bold">agricultura</span> <span class="lightoblique">nf</span> agriculture, farming <span class="trade5">2447</span></p>
# <p class="ulist"><span class="bold">agrupación</span> <span class="lightoblique">nf</span> group, association <span class="trade5">3799</span></p>
# <p class="ulist"><span class="bold">agrupar</span> <span class="lightoblique">v</span> to (put in) group <span class="trade5">3508</span></p>
# <p class="ulist"><span class="bold">agua</span> <span class="lightoblique">nf (el)</span> water <span class="trade5">204</span></p>
# <p class="ulist"><span class="bold">aguantar</span> <span class="lightoblique">v</span> to endure, put up with <span class="trade5">1879</span></p>
# <p class="ulist"><span class="bold">aguardar</span> <span class="lightoblique">v</span> to wait for, await <span class="trade5">2915</span></p>
# <p class="ulist"><span class="bold">agudo</span> <span class="lightoblique">adj</span> sharp, acute <span class="trade5">2516</span></p>
# <p class="ulist"><span class="bold">aguja</span> <span class="lightoblique">nf</span> needle, spire, stylus <span class="trade5">3841</span></p>
# <p class="ulist"><span class="bold">agujero</span> <span class="lightoblique">nm</span> hole, opening <span class="trade5">2692</span></p>
# <p class="ulist"><span class="bold">ah</span> <span class="lightoblique">interj</span> oh <span class="trade5">242</span></p>
# <p class="ulist"><span class="bold">ahí</span> <span class="lightoblique">adv</span> there <span class="trade5">180</span></p>
# <p class="ulist"><span class="bold">ahogar</span> <span class="lightoblique">v</span> to drown, choke, flood <span class="trade5">2782</span></p>
# <p class="ulist"><span class="bold">ahora</span> <span class="lightoblique">adv</span> now <span class="trade5">81</span></p>
# <p class="ulist"><span class="bold">ahorita</span> <span class="lightoblique">adv</span> right now, in a minute <span class="trade5">3023</span></p>
# <p class="ulist"><span class="bold">ahorrar</span> <span class="lightoblique">v</span> to save (money, time) <span class="trade5">3169</span></p>
# <p class="ulist"><span class="bold">ahorro</span> <span class="lightoblique">nm</span> saving, thrift <span class="trade5">3753</span></p>
# <p class="ulist"><span class="bold">aire</span> <span class="lightoblique">nm</span> air, wind, appearance <span class="trade5">401</span></p>
# <p class="ulist"><span class="bold">aislado</span> <span class="lightoblique">adj</span> isolated <span class="trade5">2635</span></p>
# <p class="ulist"><span class="bold">aislamiento</span> <span class="lightoblique">nm</span> isolation <span class="trade5">4953</span></p>
# <p class="ulist"><span class="bold">aislar</span> <span class="lightoblique">v</span> to isolate, insulate <span class="trade5">4355</span></p>
# <p class="ulist"><span class="bold">ajedrez</span> <span class="lightoblique">nm</span> chess <span class="trade5">4970</span></p>
# <p class="ulist"><span class="bold">ajeno</span> <span class="lightoblique">adj</span> not belonging to, detached <span class="trade5">1549</span></p>
# <p class="ulist"><span class="bold">ajustar</span> <span class="lightoblique">v</span> to adjust, tighten <span class="trade5">2740</span></p>
# <p class="ulist"><span class="bold">ajuste</span> <span class="lightoblique">nm</span> adjustment, settlement <span class="trade5">3830</span></p>
# <p class="ulist"><span class="bold">ala</span> <span class="lightoblique">nf (el)</span> wing, flank <span class="trade5">1995</span></p>
# <p class="ulist"><span class="bold">alambre</span> <span class="lightoblique">nm</span> wire <span class="trade5">4457</span></p>
# <p class="ulist"><span class="bold">alarma</span> <span class="lightoblique">nf</span> alarm <span class="trade5">4359</span></p>
# <p class="pagenum"><span id="page260">p.260</span></p>
# <p class="ulist"><span class="bold">alarmar</span> <span class="lightoblique">v</span> to alarm <span class="trade5">4956</span></p>
# <p class="ulist"><span class="bold">alba</span> <span class="lightoblique">nf (el)</span> dawn, daybreak <span class="trade5">4368</span></p>
# <p class="ulist"><span class="bold">albergar</span> <span class="lightoblique">v</span> to lodge, harbor <span class="trade5">3658</span></p>
# <p class="ulist"><span class="bold">alcalde</span> <span class="lightoblique">nm</span> mayor <span class="trade5">2011</span></p>
# <p class="ulist"><span class="bold">alcance</span> <span class="lightoblique">nm</span> reach, scope <span class="trade5">1953</span></p>
# <p class="ulist"><span class="bold">alcanzar</span> <span class="lightoblique">v</span> to reach, catch up with <span class="trade5">371</span></p>
# <p class="ulist"><span class="bold">alcohol</span> <span class="lightoblique">nm</span> alcohol <span class="trade5">2296</span></p>
# <p class="ulist"><span class="bold">aldea</span> <span class="lightoblique">nf</span> small village <span class="trade5">4109</span></p>
# <p class="ulist"><span class="bold">alegar</span> <span class="lightoblique">v</span> to plead, argue <span class="trade5">4100</span></p>
# <p class="ulist"><span class="bold">alegrar</span> <span class="lightoblique">v</span> to be/make happy <span class="trade5">2252</span></p>
# <p class="ulist"><span class="bold">alegre</span> <span class="lightoblique">adj</span> happy, lively, cheerful <span class="trade5">2081</span></p>
# <p class="ulist"><span class="bold">alegría</span> <span class="lightoblique">nf</span> joy, happiness <span class="trade5">1220</span></p>
# <p class="ulist"><span class="bold">alejar</span> <span class="lightoblique">v</span> to move away <span class="trade5">919</span></p>
# <p class="ulist"><span class="bold">alemán</span> <span class="lightoblique">adj</span> German <span class="trade5">761</span></p>
# <p class="ulist"><span class="bold">alentar</span> <span class="lightoblique">v</span> to encourage <span class="trade5">3837</span></p>
# <p class="ulist"><span class="bold">alerta</span> <span class="lightoblique">nf</span> alert <span class="trade5">4377</span></p>
# <p class="ulist"><span class="bold">alertar</span> <span class="lightoblique">v</span> to alert, warn <span class="trade5">4501</span></p>
# <p class="ulist"><span class="bold">alfombra</span> <span class="lightoblique">nf</span> rug, carpet, mat <span class="trade5">3428</span></p>
# <p class="ulist"><span class="bold">algo</span> <span class="lightoblique">pron</span> something, somewhat <span class="trade5">110</span></p>
# <p class="ulist"><span class="bold">algodón</span> <span class="lightoblique">nm</span> cotton <span class="trade5">3611</span></p>
# <p class="ulist"><span class="bold">alguien</span> <span class="lightoblique">pron</span> somebody, someone, anyone <span class="trade5">346</span></p>
# <p class="ulist"><span class="bold">alguno</span> <span class="lightoblique">adj</span> some, a few <span class="trade5">51</span></p>
# <p class="ulist"><span class="bold">aliado</span> <span class="lightoblique">nm</span> ally <span class="trade5">3346</span></p>
# <p class="ulist"><span class="bold">alianza</span> <span class="lightoblique">nf</span> alliance <span class="trade5">2213</span></p>
# <p class="ulist"><span class="bold">aliento</span> <span class="lightoblique">nm</span> breath, courage, spirit <span class="trade5">2674</span></p>
# <p class="ulist"><span class="bold">alimentación</span> <span class="lightoblique">nf</span> feeding, food <span class="trade5">2577</span></p>
# <p class="ulist"><span class="bold">alimentar</span> <span class="lightoblique">v</span> to feed, support <span class="trade5">1858</span></p>
# <p class="ulist"><span class="bold">alimentario</span> <span class="lightoblique">adj</span> food <span class="trade5">4478</span></p>
# <p class="ulist"><span class="bold">alimento</span> <span class="lightoblique">nm</span> food, nourishment <span class="trade5">1018</span></p>
# <p class="ulist"><span class="bold">aliviar</span> <span class="lightoblique">v</span> to lighten, relieve, comfort <span class="trade5">3206</span></p>
# <p class="ulist"><span class="bold">alivio</span> <span class="lightoblique">nm</span> relief, unburdening <span class="trade5">3892</span></p>
# <p class="ulist"><span class="bold">allá</span> <span class="lightoblique">adv</span> there, over there <span class="trade5">314</span></p>
# <p class="ulist"><span class="bold">allí</span> <span class="lightoblique">adv</span> there, over there <span class="trade5">197</span></p>
# <p class="ulist"><span class="bold">alma</span> <span class="lightoblique">nf (el)</span> soul <span class="trade5">672</span></p>
# <p class="ulist"><span class="bold">almacén</span> <span class="lightoblique">nm</span> warehouse, store <span class="trade5">2980</span></p>
# <p class="ulist"><span class="bold">almacenar</span> <span class="lightoblique">v</span> to store, keep <span class="trade5">3489</span></p>
# <p class="ulist"><span class="bold">almohada</span> <span class="lightoblique">nf</span> pillow <span class="trade5">4267</span></p>
# <p class="ulist"><span class="bold">almorzar</span> <span class="lightoblique">v</span> to have lunch <span class="trade5">4018</span></p>
# <p class="ulist"><span class="bold">almuerzo</span> <span class="lightoblique">nm</span> lunch <span class="trade5">2887</span></p>
# <p class="ulist"><span class="bold">alojar</span> <span class="lightoblique">v</span> to host, accommodate <span class="trade5">4546</span></p>
# <p class="ulist"><span class="bold">alquilar</span> <span class="lightoblique">v</span> to rent, hire <span class="trade5">3786</span></p>
# <p class="ulist"><span class="bold">alquiler</span> <span class="lightoblique">nm</span> rent, rental <span class="trade5">4454</span></p>
# <p class="ulist"><span class="bold">alrededor</span> <span class="lightoblique">nm</span> surrounding area, vicinity <span class="trade5">1807</span></p>
# <p class="ulist"><span class="bold">alrededor</span> <span class="lightoblique">adv</span> about, around, round <span class="trade5">2274</span></p>
# <p class="ulist"><span class="bold">altamente</span> <span class="lightoblique">adv</span> highly <span class="trade5">4347</span></p>
# <p class="ulist"><span class="bold">altar</span> <span class="lightoblique">nm</span> altar <span class="trade5">3272</span></p>
# <p class="ulist"><span class="bold">alteración</span> <span class="lightoblique">nf</span> alteration, change <span class="trade5">3226</span></p>
# <p class="ulist"><span class="bold">alterar</span> <span class="lightoblique">v</span> to alter, modify <span class="trade5">2389</span></p>
# <p class="ulist"><span class="bold">alternar</span> <span class="lightoblique">v</span> to alternate <span class="trade5">4486</span></p>
# <p class="ulist"><span class="bold">alternativa</span> <span class="lightoblique">nf</span> alternative <span class="trade5">2073</span></p>
# <p class="ulist"><span class="bold">alternativo</span> <span class="lightoblique">adj</span> alternating, alternative <span class="trade5">3517</span></p>
# <p class="ulist"><span class="bold">alto</span> <span class="lightoblique">adj</span> tall, high <span class="trade5">231</span></p>
# <p class="ulist"><span class="bold">altura</span> <span class="lightoblique">nf</span> height, altitude <span class="trade5">970</span></p>
# <p class="ulist"><span class="bold">aludir</span> <span class="lightoblique">v</span> to allude to <span class="trade5">3627</span></p>
# <p class="ulist"><span class="bold">alumno</span> <span class="lightoblique">nm</span> student, pupil <span class="trade5">862</span></p>
# <p class="ulist"><span class="bold">alusión</span> <span class="lightoblique">nf</span> allusion, hint <span class="trade5">4698</span></p>
# <p class="ulist"><span class="bold">alzar</span> <span class="lightoblique">v</span> to life, raise <span class="trade5">1614</span></p>
# <p class="ulist"><span class="bold">ama</span> <span class="lightoblique">nc</span> housekeeper, housewife <span class="trade5">4392</span></p>
# <p class="ulist"><span class="bold">amable</span> <span class="lightoblique">adj</span> kind, nice, friendly <span class="trade5">2707</span></p>
# <p class="ulist"><span class="bold">amanecer</span> <span class="lightoblique">nm</span> daybreak, dawn <span class="trade5">2591</span></p>
# <p class="ulist"><span class="bold">amanecer</span> <span class="lightoblique">v</span> to dawn, become light <span class="trade5">3119</span></p>
# <p class="ulist"><span class="bold">amante</span> <span class="lightoblique">nc</span> lover <span class="trade5">2210</span></p>
# <p class="ulist"><span class="bold">amar</span> <span class="lightoblique">v</span> to love <span class="trade5">700</span></p>
# <p class="ulist"><span class="bold">amargo</span> <span class="lightoblique">adj</span> bitter, sour, painful <span class="trade5">3437</span></p>
# <p class="ulist"><span class="bold">amargura</span> <span class="lightoblique">nf</span> bitterness, sorrow <span class="trade5">4567</span></p>
# <p class="ulist"><span class="bold">amarillento</span> <span class="lightoblique">adj</span> yellowish <span class="trade5">4777</span></p>
# <p class="ulist"><span class="bold">amarillo</span> <span class="lightoblique">adj</span> yellow <span class="trade5">1381</span></p>
# <p class="ulist"><span class="bold">amarrar</span> <span class="lightoblique">v</span> to tie, fasten <span class="trade5">4799</span></p>
# <p class="ulist"><span class="bold">ambición</span> <span class="lightoblique">nf</span> ambition <span class="trade5">3512</span></p>
# <p class="ulist"><span class="bold">ambicioso</span> <span class="lightoblique">adj</span> ambitious, greedy <span class="trade5">4991</span></p>
# <p class="ulist"><span class="bold">ambiental</span> <span class="lightoblique">adj</span> environmental <span class="trade5">2361</span></p>
# <p class="ulist"><span class="bold">ambiente</span> <span class="lightoblique">nm</span> environment, atmosphere <span class="trade5">729</span></p>
# <p class="ulist"><span class="bold">ámbito</span> <span class="lightoblique">nm</span> sphere, space <span class="trade5">1633</span></p>
# <p class="ulist"><span class="bold">ambos</span> <span class="lightoblique">adj</span> both <span class="trade5">536</span></p>
# <p class="ulist"><span class="bold">amenaza</span> <span class="lightoblique">nf</span> threat <span class="trade5">1896</span></p>
# <p class="ulist"><span class="bold">amenazar</span> <span class="lightoblique">v</span> to threaten <span class="trade5">1796</span></p>
# <p class="ulist"><span class="bold">americano</span> <span class="lightoblique">adj</span> American <span class="trade5">1176</span></p>
# <p class="ulist"><span class="bold">amiga</span> <span class="lightoblique">nf</span> friend (f) <span class="trade5">1172</span></p>
# <p class="ulist"><span class="bold">amigo</span> <span class="lightoblique">nm</span> friend <span class="trade5">210</span></p>
# <p class="ulist"><span class="bold">amistad</span> <span class="lightoblique">nf</span> friendship <span class="trade5">1512</span></p>
# <p class="ulist"><span class="bold">amo</span> <span class="lightoblique">nm</span> master, boss (m) <span class="trade5">2953</span></p>
# <p class="ulist"><span class="bold">amontonar</span> <span class="lightoblique">v</span> to gather, accumulate <span class="trade5">4576</span></p>
# <p class="ulist"><span class="bold">amor</span> <span class="lightoblique">nm</span> love <span class="trade5">283</span></p>
# <p class="ulist"><span class="bold">amoroso</span> <span class="lightoblique">adj</span> loving, affectionate <span class="trade5">3231</span></p>
# <p class="ulist"><span class="bold">amparar</span> <span class="lightoblique">v</span> to protect, shelter <span class="trade5">4687</span></p>
# <p class="ulist"><span class="bold">amparo</span> <span class="lightoblique">nm</span> protection, shelter <span class="trade5">4848</span></p>
# <p class="ulist"><span class="bold">ampliación</span> <span class="lightoblique">nf</span> enlargement, extension <span class="trade5">4261</span></p>
# <p class="ulist"><span class="bold">ampliamente</span> <span class="lightoblique">adv</span> widely <span class="trade5">4528</span></p>
# <p class="ulist"><span class="bold">ampliar</span> <span class="lightoblique">v</span> to enlarge, increase, expand <span class="trade5">2061</span></p>
# <p class="ulist"><span class="bold">amplio</span> <span class="lightoblique">adj</span> wide, ample, broad <span class="trade5">880</span></p>
# <p class="ulist"><span class="bold">añadir</span> <span class="lightoblique">v</span> to add <span class="trade5">1028</span></p>
# <p class="ulist"><span class="bold">análisis</span> <span class="lightoblique">nm</span> analysis <span class="trade5">1065</span></p>
# <p class="ulist"><span class="bold">analista</span> <span class="lightoblique">nc</span> analyst <span class="trade5">4023</span></p>
# <p class="ulist"><span class="bold">analizar</span> <span class="lightoblique">v</span> to analyze <span class="trade5">1126</span></p>
# <p class="ulist"><span class="bold">ancho</span> <span class="lightoblique">adj</span> wide <span class="trade5">2089</span></p>
# <p class="ulist"><span class="bold">ancho</span> <span class="lightoblique">nm</span> width <span class="trade5">4593</span></p>
# <p class="ulist"><span class="bold">anciano</span> <span class="lightoblique">nm/f</span> old person <span class="trade5">1677</span></p>
# <p class="ulist"><span class="bold">andaluz</span> <span class="lightoblique">adj</span> Andalusian <span class="trade5">4782</span></p>
# <p class="pagenum"><span id="page261">p.261</span></p>
# <p class="ulist"><span class="bold">andar</span> <span class="lightoblique">v</span> to walk, function <span class="trade5">420</span></p>
# <p class="ulist"><span class="bold">andino</span> <span class="lightoblique">adj</span> Andean <span class="trade5">4601</span></p>
# <p class="ulist"><span class="bold">anécdota</span> <span class="lightoblique">nf</span> anecdote <span class="trade5">2942</span></p>
# <p class="ulist"><span class="bold">ángel</span> <span class="lightoblique">nm</span> angel <span class="trade5">1300</span></p>
# <p class="ulist"><span class="bold">ángulo</span> <span class="lightoblique">nm</span> angle <span class="trade5">2969</span></p>
# <p class="ulist"><span class="bold">angustia</span> <span class="lightoblique">nf</span> anguish, distress <span class="trade5">1988</span></p>
# <p class="ulist"><span class="bold">anhelo</span> <span class="lightoblique">nm</span> longing, yearning <span class="trade5">4801</span></p>
# <p class="ulist"><span class="bold">anillo</span> <span class="lightoblique">nm</span> (finger) ring <span class="trade5">2902</span></p>
# <p class="ulist"><span class="bold">animado</span> <span class="lightoblique">adj</span> excited, lively <span class="trade5">4385</span></p>
# <p class="ulist"><span class="bold">animal</span> <span class="lightoblique">nm</span> animal <span class="trade5">322</span></p>
# <p class="ulist"><span class="bold">animar</span> <span class="lightoblique">v</span> to cheer up <span class="trade5">1630</span></p>
# <p class="ulist"><span class="bold">ánimo</span> <span class="lightoblique">nm</span> zest, spirit, heart <span class="trade5">1855</span></p>
# <p class="ulist"><span class="bold">aniversario</span> <span class="lightoblique">nm</span> anniversary <span class="trade5">3985</span></p>
# <p class="ulist"><span class="bold">año</span> <span class="lightoblique">nm</span> year <span class="trade5">46</span></p>
# <p class="ulist"><span class="bold">anoche</span> <span class="lightoblique">adv</span> last night <span class="trade5">2897</span></p>
# <p class="ulist"><span class="bold">anónimo</span> <span class="lightoblique">adj</span> anonymous <span class="trade5">3392</span></p>
# <p class="ulist"><span class="bold">anotar</span> <span class="lightoblique">v</span> to annotate, jot, note <span class="trade5">2694</span></p>
# <p class="ulist"><span class="bold">ansia</span> <span class="lightoblique">nf (el)</span> anxiety, anguish <span class="trade5">4146</span></p>
# <p class="ulist"><span class="bold">ansiedad</span> <span class="lightoblique">nf</span> anxiety <span class="trade5">2746</span></p>
# <p class="ulist"><span class="bold">ansioso</span> <span class="lightoblique">adj</span> anxious, eager <span class="trade5">3693</span></p>
# <p class="ulist"><span class="bold">ante</span> <span class="lightoblique">prep</span> before, in the presence of <span class="trade5">224</span></p>
# <p class="ulist"><span class="bold">antecedente</span> <span class="lightoblique">nm</span> antecedent <span class="trade5">3174</span></p>
# <p class="ulist"><span class="bold">antemano</span> <span class="lightoblique">adv</span> beforehand, in advance <span class="trade5">4803</span></p>
# <p class="ulist"><span class="bold">antena</span> <span class="lightoblique">nf</span> antenna <span class="trade5">4536</span></p>
# <p class="ulist"><span class="bold">anteojo</span> <span class="lightoblique">nm</span> telescope, eyeglasses <span class="trade5">4739</span></p>
# <p class="ulist"><span class="bold">antepasado</span> <span class="lightoblique">nm</span> ancestor <span class="trade5">4153</span></p>
# <p class="ulist"><span class="bold">anterior</span> <span class="lightoblique">adj</span> previous, preceding <span class="trade5">493</span></p>
# <p class="ulist"><span class="bold">anteriormente</span> <span class="lightoblique">adv</span> previously <span class="trade5">2443</span></p>
# <p class="ulist"><span class="bold">antes</span> <span class="lightoblique">adv</span> before <span class="trade5">190</span></p>
# <p class="ulist"><span class="bold">anticipar</span> <span class="lightoblique">v</span> to anticipate, advance <span class="trade5">3588</span></p>
# <p class="ulist"><span class="bold">antigüedad</span> <span class="lightoblique">nf</span> antiquity, seniority <span class="trade5">3083</span></p>
# <p class="ulist"><span class="bold">antiguo</span> <span class="lightoblique">adj</span> old, ancient, former <span class="trade5">446</span></p>
# <p class="ulist"><span class="bold">anual</span> <span class="lightoblique">adj</span> annual, yearly <span class="trade5">1952</span></p>
# <p class="ulist"><span class="bold">anular</span> <span class="lightoblique">v</span> to annul, cancel <span class="trade5">4042</span></p>
# <p class="ulist"><span class="bold">anunciar</span> <span class="lightoblique">v</span> to announce, advertise <span class="trade5">785</span></p>
# <p class="ulist"><span class="bold">anuncio</span> <span class="lightoblique">nm</span> advertisement, announcement <span class="trade5">2076</span></p>
# <p class="ulist"><span class="bold">apagado</span> <span class="lightoblique">adj</span> turned off <span class="trade5">4585</span></p>
# <p class="ulist"><span class="bold">apagar</span> <span class="lightoblique">v</span> to turn off, extinguish <span class="trade5">1780</span></p>
# <p class="ulist"><span class="bold">aparato</span> <span class="lightoblique">nm</span> apparatus, device <span class="trade5">1725</span></p>
# <p class="ulist"><span class="bold">aparecer</span> <span class="lightoblique">v</span> to appear <span class="trade5">292</span></p>
# <p class="ulist"><span class="bold">aparente</span> <span class="lightoblique">adj</span> apparent <span class="trade5">3391</span></p>
# <p class="ulist"><span class="bold">aparentemente</span> <span class="lightoblique">adv</span> apparently <span class="trade5">2666</span></p>
# <p class="ulist"><span class="bold">aparición</span> <span class="lightoblique">nf</span> appearance, apparition <span class="trade5">1785</span></p>
# <p class="ulist"><span class="bold">apariencia</span> <span class="lightoblique">nf</span> appearance, aspect <span class="trade5">2295</span></p>
# <p class="ulist"><span class="bold">apartamento</span> <span class="lightoblique">nm</span> apartment <span class="trade5">4271</span></p>
# <p class="ulist"><span class="bold">apartar</span> <span class="lightoblique">v</span> to move away, separate <span class="trade5">1566</span></p>
# <p class="ulist"><span class="bold">aparte</span> <span class="lightoblique">adv</span> apart, aside, separately <span class="trade5">1290</span></p>
# <p class="ulist"><span class="bold">apasionar</span> <span class="lightoblique">v</span> to inspire, be passionate about <span class="trade5">4644</span></p>
# <p class="ulist"><span class="bold">apelar</span> <span class="lightoblique">v</span> to call upon, appeal to <span class="trade5">4436</span></p>
# <p class="ulist"><span class="bold">apellido</span> <span class="lightoblique">nm</span> last name <span class="trade5">2576</span></p>
# <p class="ulist"><span class="bold">apenas</span> <span class="lightoblique">adv</span> hardly, barely <span class="trade5">486</span></p>
# <p class="ulist"><span class="bold">apertura</span> <span class="lightoblique">nf</span> opening, beginning <span class="trade5">2412</span></p>
# <p class="ulist"><span class="bold">apetito</span> <span class="lightoblique">nm</span> appetite <span class="trade5">4248</span></p>
# <p class="ulist"><span class="bold">aplastar</span> <span class="lightoblique">v</span> to flatten, crush, smash <span class="trade5">3118</span></p>
# ...
# <p class="ulist"><span class="bold">veloz</span> <span class="lightoblique">adj</span> fast, quick <span class="trade5">4521</span></p>
# <p class="ulist"><span class="bold">vena</span> <span class="lightoblique">nf</span> vein <span class="trade5">3405</span></p>
# <p class="ulist"><span class="bold">vencer</span> <span class="lightoblique">v</span> to overcome, conquer <span class="trade5">1426</span></p>
# <p class="ulist"><span class="bold">vendedor</span> <span class="lightoblique">nm/f</span> salesperson <span class="trade5">2551</span></p>
# <p class="ulist"><span class="bold">vender</span> <span class="lightoblique">v</span> to sell <span class="trade5">528</span></p>
# <p class="ulist"><span class="bold">veneno</span> <span class="lightoblique">nm</span> poison, venom <span class="trade5">4344</span></p>
# <p class="ulist"><span class="bold">venezolano</span> <span class="lightoblique">adj</span> Venezuelan <span class="trade5">2178</span></p>
# <p class="ulist"><span class="bold">venganza</span> <span class="lightoblique">nf</span> revenge, vengeance <span class="trade5">3657</span></p>
# <p class="ulist"><span class="bold">vengar</span> <span class="lightoblique">v</span> to take revenge, avenge <span class="trade5">2347</span></p>
# <p class="ulist"><span class="bold">venir</span> <span class="lightoblique">v</span> to come <span class="trade5">118</span></p>
# <p class="ulist"><span class="bold">venta</span> <span class="lightoblique">nf</span> sale <span class="trade5">1039</span></p>
# <p class="ulist"><span class="bold">ventaja</span> <span class="lightoblique">nf</span> advantage, benefit <span class="trade5">1401</span></p>
# <p class="ulist"><span class="bold">ventana</span> <span class="lightoblique">nf</span> window <span class="trade5">725</span></p>
# <p class="ulist"><span class="bold">ventanilla</span> <span class="lightoblique">nf</span> (vehicle) window <span class="trade5">4202</span></p>
# <p class="ulist"><span class="bold">ver</span> <span class="lightoblique">v</span> to see <span class="trade5">38</span></p>
# <p class="ulist"><span class="bold">verano</span> <span class="lightoblique">nm</span> summer <span class="trade5">1139</span></p>
# <p class="ulist"><span class="bold">verbal</span> <span class="lightoblique">adj</span> verbal, oral <span class="trade5">3880</span></p>
# <p class="ulist"><span class="bold">verbo</span> <span class="lightoblique">nm</span> verb <span class="trade5">3443</span></p>
# <p class="ulist"><span class="bold">verdad</span> <span class="lightoblique">nf</span> truth <span class="trade5">176</span></p>
# <p class="ulist"><span class="bold">verdaderamente</span> <span class="lightoblique">adv</span> truly <span class="trade5">1894</span></p>
# <p class="ulist"><span class="bold">verdadero</span> <span class="lightoblique">adj</span> true, real <span class="trade5">558</span></p>
# <p class="ulist"><span class="bold">verde</span> <span class="lightoblique">adj</span> green <span class="trade5">812</span></p>
# <p class="ulist"><span class="bold">verdura</span> <span class="lightoblique">nf</span> vegetables, greenery <span class="trade5">4335</span></p>
# <p class="ulist"><span class="bold">vereda</span> <span class="lightoblique">nf</span> path, sidewalk <span class="trade5">3414</span></p>
# <p class="ulist"><span class="bold">vergüenza</span> <span class="lightoblique">nf</span> embarrassment <span class="trade5">1979</span></p>
# <p class="ulist"><span class="bold">verificar</span> <span class="lightoblique">v</span> to verify <span class="trade5">3468</span></p>
# <p class="ulist"><span class="bold">versión</span> <span class="lightoblique">nf</span> version, account <span class="trade5">1057</span></p>
# <p class="ulist"><span class="bold">verso</span> <span class="lightoblique">nm</span> verse, poem <span class="trade5">2336</span></p>
# <p class="ulist"><span class="bold">verter</span> <span class="lightoblique">v</span> to pour, spill, shed <span class="trade5">4034</span></p>
# <p class="ulist"><span class="bold">vertical</span> <span class="lightoblique">adj</span> vertical, upright <span class="trade5">3885</span></p>
# <p class="ulist"><span class="bold">vestido</span> <span class="lightoblique">nm</span> dress <span class="trade5">1697</span></p>
# <p class="ulist"><span class="bold">vestir</span> <span class="lightoblique">v</span> to wear, dress <span class="trade5">701</span></p>
# <p class="ulist"><span class="bold">vez</span> <span class="lightoblique">nf</span> time (specific occurrence); en v. de: instead of <span class="trade5">59</span></p>
# <p class="ulist"><span class="bold">vía</span> <span class="lightoblique">nf</span> road, way; por v.: by means <span class="trade5">904</span></p>
# <p class="ulist"><span class="bold">viable</span> <span class="lightoblique">adj</span> viable, feasible <span class="trade5">4718</span></p>
# <p class="ulist"><span class="bold">viajar</span> <span class="lightoblique">v</span> to travel <span class="trade5">902</span></p>
# <p class="ulist"><span class="bold">viaje</span> <span class="lightoblique">nm</span> travel, trip <span class="trade5">519</span></p>
# <p class="ulist"><span class="bold">viajero</span> <span class="lightoblique">nm</span> traveler, passenger <span class="trade5">3265</span></p>
# <p class="ulist"><span class="bold">vibración</span> <span class="lightoblique">nf</span> vibration <span class="trade5">4616</span></p>
# <p class="ulist"><span class="bold">vibrar</span> <span class="lightoblique">v</span> to vibrate, tremble <span class="trade5">4047</span></p>
# <p class="ulist"><span class="bold">vicepresidente</span> <span class="lightoblique">nm/f</span> vice president <span class="trade5">3092</span></p>
# <p class="ulist"><span class="bold">vicio</span> <span class="lightoblique">nm</span> vice, bad habit, defect <span class="trade5">3515</span></p>
# <p class="ulist"><span class="bold">víctima</span> <span class="lightoblique">nf</span> victim, casualty <span class="trade5">1154</span></p>
# <p class="ulist"><span class="bold">victoria</span> <span class="lightoblique">nf</span> victory, triumph <span class="trade5">1266</span></p>
# <p class="ulist"><span class="bold">vida</span> <span class="lightoblique">nf</span> life <span class="trade5">85</span></p>
# <p class="ulist"><span class="bold">vídeo</span> <span class="lightoblique">nm</span> video <span class="trade5">1180</span></p>
# <p class="ulist"><span class="bold">vidrio</span> <span class="lightoblique">nm</span> glass, pane <span class="trade5">1905</span></p>
# <p class="pagenum"><span id="page309">p.309</span></p>
# <p class="ulist"><span class="bold">viejo</span> <span class="lightoblique">adj</span> old, aged <span class="trade5">225</span></p>
# <p class="ulist"><span class="bold">viento</span> <span class="lightoblique">nm</span> wind, scent <span class="trade5">814</span></p>
# <p class="ulist"><span class="bold">vientre</span> <span class="lightoblique">nm</span> womb, belly <span class="trade5">2294</span></p>
# <p class="ulist"><span class="bold">viernes</span> <span class="lightoblique">nm</span> Friday <span class="trade5">1259</span></p>
# <p class="ulist"><span class="bold">vigencia</span> <span class="lightoblique">nf</span> validity <span class="trade5">3862</span></p>
# <p class="ulist"><span class="bold">vigente</span> <span class="lightoblique">adj</span> in force, valid <span class="trade5">3171</span></p>
# <p class="ulist"><span class="bold">vigilancia</span> <span class="lightoblique">nf</span> surveillance, vigilance <span class="trade5">3623</span></p>
# <p class="ulist"><span class="bold">vigilar</span> <span class="lightoblique">v</span> to watch over, guard <span class="trade5">2800</span></p>
# <p class="ulist"><span class="bold">vigor</span> <span class="lightoblique">nm</span> force, strength, vigor <span class="trade5">3877</span></p>
# <p class="ulist"><span class="bold">villa</span> <span class="lightoblique">nf</span> village, town <span class="trade5">2877</span></p>
# <p class="ulist"><span class="bold">vinculación</span> <span class="lightoblique">nf</span> link, connection <span class="trade5">4884</span></p>
# <p class="ulist"><span class="bold">vincular</span> <span class="lightoblique">v</span> to conenct, link, bind <span class="trade5">2590</span></p>
# <p class="ulist"><span class="bold">vínculo</span> <span class="lightoblique">nm</span> tie, bond, link <span class="trade5">3047</span></p>
# <p class="ulist"><span class="bold">vino</span> <span class="lightoblique">nm</span> wine <span class="trade5">1344</span></p>
# <p class="ulist"><span class="bold">violación</span> <span class="lightoblique">nf</span> violation, rape <span class="trade5">2867</span></p>
# <p class="ulist"><span class="bold">violar</span> <span class="lightoblique">v</span> to violate, trespass, rape <span class="trade5">2517</span></p>
# <p class="ulist"><span class="bold">violencia</span> <span class="lightoblique">nf</span> violence <span class="trade5">1100</span></p>
# <p class="ulist"><span class="bold">violento</span> <span class="lightoblique">adj</span> violent <span class="trade5">1920</span></p>
# <p class="ulist"><span class="bold">violín</span> <span class="lightoblique">nm</span> violin <span class="trade5">3671</span></p>
# <p class="ulist"><span class="bold">virgen</span> <span class="lightoblique">nf</span> virgin <span class="trade5">2265</span></p>
# <p class="ulist"><span class="bold">virtual</span> <span class="lightoblique">adj</span> virtual, potential <span class="trade5">3529</span></p>
# <p class="ulist"><span class="bold">virtud</span> <span class="lightoblique">nf</span> virtue, quality <span class="trade5">2083</span></p>
# <p class="ulist"><span class="bold">virus</span> <span class="lightoblique">nm</span> virus <span class="trade5">2393</span></p>
# <p class="ulist"><span class="bold">visible</span> <span class="lightoblique">adj</span> visible <span class="trade5">2558</span></p>
# <p class="ulist"><span class="bold">visión</span> <span class="lightoblique">nf</span> vision <span class="trade5">1045</span></p>
# <p class="ulist"><span class="bold">visita</span> <span class="lightoblique">nf</span> visit, visitor, guest <span class="trade5">911</span></p>
# <p class="ulist"><span class="bold">visitante</span> <span class="lightoblique">nc</span> visitor <span class="trade5">2428</span></p>
# <p class="ulist"><span class="bold">visitar</span> <span class="lightoblique">v</span> to visit <span class="trade5">792</span></p>
# <p class="ulist"><span class="bold">víspera</span> <span class="lightoblique">nf</span> eve <span class="trade5">4531</span></p>
# <p class="ulist"><span class="bold">vista</span> <span class="lightoblique">nf</span> view, sight <span class="trade5">408</span></p>
# <p class="ulist"><span class="bold">visual</span> <span class="lightoblique">adj</span> visual <span class="trade5">3278</span></p>
# <p class="ulist"><span class="bold">vital</span> <span class="lightoblique">adj</span> vital, lively, essential <span class="trade5">2204</span></p>
# <p class="ulist"><span class="bold">vitamina</span> <span class="lightoblique">nf</span> vitamin <span class="trade5">4091</span></p>
# <p class="ulist"><span class="bold">viuda</span> <span class="lightoblique">nf</span> widow <span class="trade5">3651</span></p>
# <p class="ulist"><span class="bold">vivienda</span> <span class="lightoblique">nf</span> housing, dwelling <span class="trade5">1527</span></p>
# <p class="ulist"><span class="bold">vivir</span> <span class="lightoblique">v</span> to live <span class="trade5">142</span></p>
# <p class="ulist"><span class="bold">vivo</span> <span class="lightoblique">adj</span> alive, bright <span class="trade5">807</span></p>
# <p class="ulist"><span class="bold">vocación</span> <span class="lightoblique">nf</span> vocation, calling <span class="trade5">2368</span></p>
# <p class="ulist"><span class="bold">volante</span> <span class="lightoblique">nm</span> steering wheel <span class="trade5">4525</span></p>
# <p class="ulist"><span class="bold">volar</span> <span class="lightoblique">v</span> to fly <span class="trade5">1468</span></p>
# <p class="ulist"><span class="bold">volcán</span> <span class="lightoblique">nm</span> volcano <span class="trade5">4254</span></p>
# <p class="ulist"><span class="bold">volcar</span> <span class="lightoblique">v</span> to turn/knock over, empty <span class="trade5">4166</span></p>
# <p class="ulist"><span class="bold">voltear</span> <span class="lightoblique">v</span> to turn over, turn around <span class="trade5">3861</span></p>
# <p class="ulist"><span class="bold">volumen</span> <span class="lightoblique">nm</span> volume <span class="trade5">1568</span></p>
# <p class="ulist"><span class="bold">voluntad</span> <span class="lightoblique">nf</span> will, willpower, intention <span class="trade5">1051</span></p>
# <p class="ulist"><span class="bold">voluntario</span> <span class="lightoblique">adj</span> voluntary, volunteer <span class="trade5">2732</span></p>
# <p class="ulist"><span class="bold">volver</span> <span class="lightoblique">v</span> to return, to V again <span class="trade5">112</span></p>
# <p class="ulist"><span class="bold">vos</span> <span class="lightoblique">pron</span> you (subj-sg/+fam) <span class="trade5">517</span></p>
# <p class="ulist"><span class="bold">vosotros</span> <span class="lightoblique">pron</span> you (subj-pl/+fam) <span class="trade5">2202</span></p>
# <p class="ulist"><span class="bold">votación</span> <span class="lightoblique">nf</span> vote, voting <span class="trade5">2985</span></p>
# <p class="ulist"><span class="bold">votar</span> <span class="lightoblique">v</span> to vote <span class="trade5">1828</span></p>
# <p class="ulist"><span class="bold">voto</span> <span class="lightoblique">nm</span> vote <span class="trade5">1363</span></p>
# <p class="ulist"><span class="bold">voz</span> <span class="lightoblique">nf</span> voice <span class="trade5">252</span></p>
# <p class="ulist"><span class="bold">vuelo</span> <span class="lightoblique">nm</span> flight <span class="trade5">1739</span></p>
# <p class="ulist"><span class="bold">vuelta</span> <span class="lightoblique">nf</span> return, turn <span class="trade5">1012</span></p>
# <p class="ulist"><span class="bold">vuestro</span> <span class="lightoblique">adj</span> your (pl/+fam) <span class="trade5">1748</span></p>
# <p class="ulist"><span class="bold">vulgar</span> <span class="lightoblique">adj</span> vulgar, common, banal <span class="trade5">4324</span></p>
# <p class="ulist"><span class="bold">vulnerable</span> <span class="lightoblique">adj</span> vulnerable <span class="trade5">4736</span></p>
# <p class="hh1">W</p>
# <p class="ulist"><span class="bold">web</span> <span class="lightoblique">nm</span> Internet, web <span class="trade5">1265</span></p>
# <p class="ulist"><span class="bold">whisky</span> <span class="lightoblique">nm</span> whisky <span class="trade5">4169</span></p>
# <p class="hh1">Y</p>
# <p class="ulist"><span class="bold">y</span> <span class="lightoblique">conj</span> and <span class="trade5">4</span></p>
# <p class="ulist"><span class="bold">ya</span> <span class="lightoblique">adv</span> already, still <span class="trade5">39</span></p>
# <p class="ulist"><span class="bold">yacer</span> <span class="lightoblique">v</span> to lie, be located <span class="trade5">4568</span></p>
# <p class="ulist"><span class="bold">yacimiento</span> <span class="lightoblique">nm</span> deposit, field <span class="trade5">4209</span></p>
# <p class="ulist"><span class="bold">yo</span> <span class="lightoblique">pron</span> I (subj) <span class="trade5">28</span></p>
# <p class="hh1">Z</p>
# <p class="ulist"><span class="bold">zapatilla</span> <span class="lightoblique">nf</span> slipper, shoe <span class="trade5">4939</span></p>
# <p class="ulist"><span class="bold">zapato</span> <span class="lightoblique">nm</span> shoe <span class="trade5">1477</span></p>
# <p class="ulist"><span class="bold">zona</span> <span class="lightoblique">nf</span> area, zone <span class="trade5">359</span></p>
# </body>
# </html>

# %%
words_span = soup.find_all("p", attrs={"class": "ulist"})
# Word family head, pos, gloss, rank
print(words_span[0])
# Out:
# <p class="ulist"><span class="bold">a</span> <span class="lightoblique">prep</span> to, at <span class="trade5">8</span></p>

# %%
# Each entry is structured as:
# Word family head, pos, gloss, rank
entry = words_span[0]
entry_stripped_strings = list(entry.stripped_strings)
word = entry_stripped_strings[0]
type = entry_stripped_strings[1]
english = entry_stripped_strings[2]
frequency_rank = entry_stripped_strings[3] # lower is more frequent

# %%
# Create empty a frame with columns we wish to extract
columns = ["word", "type", "english", "frequency_rank"]
df = pd.DataFrame(columns=columns)

# Extract fields from wordlist
words = soup.find_all("p", attrs={"class": "ulist"})

for entry in words:
    #if word.has_attr("class"):
    #    # Skip where class="hidden"
    #    continue
    try:
    # Each entry is structured as:
    # Word family head, pos, gloss, rank
        entry_stripped_strings = list(entry.stripped_strings)
        word = entry_stripped_strings[0]
        type = entry_stripped_strings[1]
        english = entry_stripped_strings[2]
        frequency_rank = entry_stripped_strings[3] # lower is more frequent
    except Exception as e:
        print(f"Exception {e} for {word}")
    # Add data to dataframe
    data = {
        "word": word,
        "type": type,
        "english": english,
        "frequency_rank": frequency_rank
    }
    df_new = pd.DataFrame.from_records([data])
    df = pd.concat([df, df_new])

# %%
df.head()
# Out:
#          word  type                      english frequency_rank
# 0           a  prep                       to, at              8
# 0       abajo   adv        down, below, downward            788
# 0  abandonado   adj                    abandoned           2896
# 0   abandonar     v  to abandon, leave (a place)            680
# 0    abandono    nm       abandonment, desertion           3463

# %%
# Save data to pkl file
df.to_pickle("./data/spanish.pkl")
#df = pd.read_pickle("./data/spanish.pkl")

# %%
df = pd.read_pickle("./data/spanish.pkl")
df['frequency_rank'] = pd.to_numeric(df['frequency_rank'], errors='coerce')
df.frequency_rank.quantile([0.25,0.5,0.75])
df.frequency_rank.max()
# Out:
# 5010.0

# %%
#read data by cefr

# Open book with calibre editor -> chapters as *.xlink.html -> export file
# Read xhtml data from file.
with open('data/frequency.xlink.xhtml', 'r') as chapter_alphabetical:
    content = chapter_alphabetical.read()
    soup = BeautifulSoup(content, 'html')
list_of_lists = soup.find_all("div", attrs={"class": ["listb", "list"]}) # freq_rank, word, type, translation

# %%
# fix for item: 269 se2_ti instead
# fix for item: 1327 juventud 2 entrances for explanation; fixed in .xhtml
nlistd40 = [] # freq_rank, word, type, translation
blist1 = [] # explanation
for list_of_words in list_of_lists:
    nlistd40 += list_of_words.find_all("p", attrs={"class": ["nlist4d0", "se2_ti"]})
    blist1 += list_of_words.find_all("p", attrs={"class": "blist1"})

# %%
# data: <p class="nlist4d0">      <span class="bold">1    el, la</span> <span class="lightoblique">art</span> the (<span class="symbol"><span class="flag-symbol-font">+</span></span>m, f)</p>
# explanation: <p class="blist1">•    el diccionario tenía también frases útiles – the dictionary also had useful phrases</p>
columns = ["word", "type", "english", "frequency_rank", "spanish"]
df = pd.DataFrame(columns=columns)

import re
for data, explanation in zip(nlistd40, blist1):
    first_span = data.find("span").text
    frequency_rank = re.search(r"\d*(?:\s+\d+)*", first_span)[0]
    word = re.search(r"\d+\s+(\w+)", first_span)[1]

    #second_span = data.find_next('span').find_next('span').text
    stripped_strings = list(data.stripped_strings)
    type = stripped_strings[1]
    #english = stripped_strings[2]

    exp_test = explanation.text
    stripped_strings_xp = list(explanation.stripped_strings)
    splitted = exp_test.split('–')
    spanish, english = splitted[0].strip(), splitted[1].strip()
    spanish = spanish.encode('ascii', 'ignore').decode()
    english = english.encode('ascii', 'ignore').decode()

    data = {
        "word": word,
        "type": type,
        "english": english,
        "frequency_rank": frequency_rank,
        "spanish": spanish
    }
    df_new = pd.DataFrame.from_records([data])
    df = pd.concat([df, df_new])

# %% [markdown]
# # Spanish done

# %%
# Save data to pkl file
df.to_pickle("./data/spanish2.pkl")
#df = pd.read_pickle("./data/spanish.pkl")
