# %% [markdown]
# # Format 3000,5000,5000 exclusive data to word lists
# format 3000,5000,5000_exclusve in the following formats:
#
# * all data text british: word, type, definition, example, phonetics, cefr
# * all data text usa: word, type, definition, example, phonetics, cefr
# * all data + pronounciation: same as above with clickable HTML
# * 2 column: word, type, definiton
#
# All of the above grouped by cefr

# %%
import pandas as pd
import os

# %%
DATASET = 'oxford_3000'
DATASET = 'oxford_5000'
DATASET = 'oxford_5000_exclusive'
df = pd.read_pickle(f"./data/{DATASET}.pkl")
df.head()
# Out:
#        word       type cefr    phon_br   phon_n_am  \
# 0   abolish       verb   c1  /əˈbɒlɪʃ/  /əˈbɑːlɪʃ/
# 1  abortion       noun   c1  /əˈbɔːʃn/  /əˈbɔːrʃn/
# 2   absence       noun   c1  /ˈæbsəns/   /ˈæbsəns/
# 3    absent  adjective   c1  /ˈæbsənt/   /ˈæbsənt/
# 4    absorb       verb   b2  /əbˈzɔːb/  /əbˈzɔːrb/
#
#                                           definition  \
# 0  to officially end a law, a system or an instit...
# 1  the deliberate ending of a pregnancy at an ear...
# 2  the fact of somebody being away from a place w...
# 3            not in a place because of illness, etc.
# 4  to take in a liquid, gas or other substance fr...
#
#                                              example               uk  \
# 0                      This tax should be abolished.   abolish_uk.mp3
# 1                         to support/oppose abortion  abortion_uk.mp3
# 2  in somebody's absence, The decision was made i...   absence_uk.mp3
# 3             He was absent from work for two weeks.    absent_uk.mp3
# 4  absorb something, Plants absorb carbon dioxide...    absorb_uk.mp3
#
#                 us
# 0   abolish_us.mp3
# 1  abortion_us.mp3
# 2   absence_us.mp3
# 3    absent_us.mp3
# 4    absorb_us.mp3

# %% [markdown]
# ## HTML+PDF all columns alphabetical

# %%
# Complete to HTML
data = df[["word", "type", "cefr", "phon_br", "phon_n_am", "definition", "example"]]
data['cefr'] = data['cefr'].map(lambda x: x.strip().upper())

data = data.rename(columns={'phon_br' : 'phonetic(UK)'})
data = data.rename(columns={'phon_n_am' : 'phonetic(US)'})

style = data.style.format(
    escape="html",
    )
style = style.hide(axis='index')

html = style.to_html()
filename = DATASET + '_alphabetical'
with open(f'output/{filename}.html', 'w') as f:
    f.write(html)

cmd = f'pandoc -f html -t pdf output/{filename}.html -t html5 -o output/{filename}.pdf --metadata pagetitle="{filename}" -V margin-top=2 -V margin-bottom=2 -V margin-left=2 -V margin-right=2 -c format/table.css --pdf-engine-opt=--enable-local-file-access'
os.system(cmd)
# Out:
# /tmp/ipykernel_125638/560310808.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['cefr'] = data['cefr'].map(lambda x: x.strip().upper())
# Loading pages (1/6)
# Counting pages (2/6)
# Resolving links (4/6)
# Loading headers and footers (5/6)
# Printing pages (6/6)
# Done
# 0

# %% [markdown]
# ## HTML+PDF all columns grouped by CEFR

# %%
data = df
data['cefr'] = data['cefr'].map(lambda x: x.strip().upper())
cefrs = ['A1', 'A2', 'B1', 'B2', 'C1']
data_by_cefr = list(map(lambda c : data[data['cefr'] == c], cefrs))

# %%
data_by_cefr[1].head()
# Out:
#         word       type cefr      phon_br    phon_n_am  \
# 2    ability       noun   A2   /əˈbɪləti/   /əˈbɪləti/
# 3       able  adjective   A2      /ˈeɪbl/      /ˈeɪbl/
# 8     abroad     adverb   A2    /əˈbrɔːd/    /əˈbrɔːd/
# 13    accept       verb   A2    /əkˈsept/    /əkˈsept/
# 17  accident       noun   A2  /ˈæksɪdənt/  /ˈæksɪdənt/
#
#                                            definition  \
# 2   the fact that somebody/something is able to do...
# 3   to have the skill, intelligence, opportunity, ...
# 8                          in or to a foreign country
# 13  to take willingly something that is offered; t...
# 17  an unpleasant event, especially in a vehicle, ...
#
#                                               example               uk  \
# 2   People with the disease may lose their ability...   ability_uk.mp3
# 3      You must be able to speak French for this job.      able_uk.mp3
# 8                     to go/travel/live/study abroad     abroad_uk.mp3
# 13           He asked me to marry him and I accepted.    accept_uk.mp3
# 17                        a car/road/traffic accident  accident_uk.mp3
#
#                  us
# 2    ability_us.mp3
# 3       able_us.mp3
# 8     abroad_us.mp3
# 13    accept_us.mp3
# 17  accident_us.mp3

# %%
# Complete to HTML
html_out = ''
for data in data_by_cefr:
    if data.empty:
        continue
    data = data[['word', 'type', 'phon_br', 'phon_n_am', 'definition', 'example', 'cefr']]
    cefr = data['cefr'].iloc[0]
    html_out += f'<h2>{cefr}</h2>'
    data = data.drop(['cefr'], axis=1)
    print()
    data = data.rename(columns={'word' : f'word ({cefr})'})
    data = data.rename(columns={'phon_br' : 'phonetics (UK)'})
    data = data.rename(columns={'phon_n_am' : 'phonetics (US)'})

    style = data.style.format(
        escape="html",
        )
    style = style.hide(axis='index')
    html_out += style.to_html()


filename = DATASET+'_by_cefr'
with open(f'output/{filename}.html', 'w', encoding='utf-8') as f:
    f.write(html_out)

# to pdf
cmd = f"""pandoc -f html -t pdf output/{filename}.html -t html5 -o output/{filename}.pdf --metadata pagetitle="{filename}" -V margin-top=2 -V margin-bottom=2 -V margin-left=2 -V margin-right=2 -c format/table.css --pdf-engine-opt=--enable-local-file-access --title '{filename}'"""
os.system(cmd)
# Out:
# Loading pages (1/6)
# Counting pages (2/6)
# Resolving links (4/6)
# Loading headers and footers (5/6)
# Printing pages (6/6)
# Done
# 0

# %% [markdown]
# ## HTML+PDF all columns grouped by CEFR shuffle

# %%
# Complete to HTML
html_out = ''
for data in data_by_cefr:
    if data.empty:
        continue
    data = data[['word', 'type', 'phon_br', 'phon_n_am', 'definition', 'example', 'cefr']]
    cefr = data['cefr'].iloc[0]
    html_out += f'<h2>{cefr}</h2>'
    data = data.drop(['cefr'], axis=1)
    print()
    data = data.rename(columns={'word' : f'word ({cefr})'})
    data = data.rename(columns={'phon_br' : 'phonetics (UK)'})
    data = data.rename(columns={'phon_n_am' : 'phonetics (US)'})

    data = data.sample(frac=1)

    style = data.style.format(
        escape="html",
        )
    style = style.hide(axis='index')
    html_out += style.to_html()


filename = DATASET+'_by_cefr_shuffle'
with open(f'output/{filename}.html', 'w', encoding='utf-8') as f:
    f.write(html_out)

# to pdf
cmd = f"""pandoc -f html -t pdf output/{filename}.html -t html5 -o output/{filename}.pdf --metadata pagetitle="{filename}" -V margin-top=2 -V margin-bottom=2 -V margin-left=2 -V margin-right=2 -c format/table.css --pdf-engine-opt=--enable-local-file-access --title '{filename}'"""
os.system(cmd)
# Out:
# Loading pages (1/6)
# Counting pages (2/6)
# Resolving links (4/6)
# Loading headers and footers (5/6)
# Printing pages (6/6)
# Done
# 0

# %% [markdown]
# ## 2 Column LateX word,type and definition alphabetical

# %%
import re
# Fix supertabular and add \textit to type
def fix_latex_line(line):
    if re.match(r"^\\begin{supertabular}", line):
        # Add column_format to supertabular}
        return '\\begin{supertabular}'+'{'+column_format+'}'
    if re.match(r"^\\.*{tabular}", line):
        # Remove {tabular}
        return ''
    if re.match(r"^\w+\s.*\(\w+\s?\w+?\)", line):
        # Italics
        return re.sub(r"(^\w+\s.*)(\(\w+\s?\w+?\))", r"\1\\textit{\2}", line)
    return line

# %%
# 2 Column word + definition
data = df[["word", "definition", "type"]]
data["word"] = data.apply(lambda row: f"{row.word.strip()} ({row.type.strip()})" , axis=1)
data = data[["word", "definition"]]

style = data.style.format(
    escape="latex",
    )
style = style.hide(axis='index')
style = style.hide(axis='columns')

column_format = 'p{1.2in}p{2.3in}p{1.2in}p{2.3in}'
latex = style.to_latex(
    environment='supertabular',
    #encoding='utf8x',
    column_format=column_format
)

latex_lines = latex.splitlines()
latex = '\n'.join((map(fix_latex_line, latex_lines)))

filename = DATASET + '_table_alphabetical'
with open(f'./build/{filename}.tex', 'w') as f:
    f.write(latex)
# Out:
# /tmp/ipykernel_125638/628000250.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["word"] = data.apply(lambda row: f"{row.word.strip()} ({row.type.strip()})" , axis=1)

# %% [markdown]
# ## 2 Column LateX word,type and definition by CEFR

# %%
data = df
data['cefr'] = data['cefr'].map(lambda x: x.strip().upper())
cefrs = ['A1', 'A2', 'B1', 'B2', 'C1']
data_by_cefr = list(map(lambda c : data[data['cefr'] == c], cefrs))

# %%
data_by_cefr[1].head()
# Out:
#         word       type cefr      phon_br    phon_n_am  \
# 2    ability       noun   A2   /əˈbɪləti/   /əˈbɪləti/
# 3       able  adjective   A2      /ˈeɪbl/      /ˈeɪbl/
# 8     abroad     adverb   A2    /əˈbrɔːd/    /əˈbrɔːd/
# 13    accept       verb   A2    /əkˈsept/    /əkˈsept/
# 17  accident       noun   A2  /ˈæksɪdənt/  /ˈæksɪdənt/
#
#                                            definition  \
# 2   the fact that somebody/something is able to do...
# 3   to have the skill, intelligence, opportunity, ...
# 8                          in or to a foreign country
# 13  to take willingly something that is offered; t...
# 17  an unpleasant event, especially in a vehicle, ...
#
#                                               example               uk  \
# 2   People with the disease may lose their ability...   ability_uk.mp3
# 3      You must be able to speak French for this job.      able_uk.mp3
# 8                     to go/travel/live/study abroad     abroad_uk.mp3
# 13           He asked me to marry him and I accepted.    accept_uk.mp3
# 17                        a car/road/traffic accident  accident_uk.mp3
#
#                  us
# 2    ability_us.mp3
# 3       able_us.mp3
# 8     abroad_us.mp3
# 13    accept_us.mp3
# 17  accident_us.mp3

# %%
for data, cefr in zip(data_by_cefr, cefrs):
    if data.empty:
        continue
    data = data[["word", "definition", "type", "cefr"]]
    data["word"] = data.apply(lambda row: f"{row.word.strip()} ({row.type.strip()})" , axis=1)
    data = data[["word", "definition"]]

    style = data.style.format(
        escape="latex",
        )
    style = style.hide(axis='index')
    style = style.hide(axis='columns')

    column_format = 'p{1.2in}p{2.3in}p{1.2in}p{2.3in}'
    latex = style.to_latex(
        environment='supertabular',
        column_format=column_format
    )

    latex_lines = latex.splitlines()

    latex = '\n'.join((map(fix_latex_line, latex_lines)))

    filename = f'{DATASET}_{cefr}'
    with open(f'build/{filename}.tex', 'w') as f:
        f.write(latex)
# Out:
# /tmp/ipykernel_125638/1060421477.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["word"] = data.apply(lambda row: f"{row.word.strip()} ({row.type.strip()})" , axis=1)
# /tmp/ipykernel_125638/1060421477.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["word"] = data.apply(lambda row: f"{row.word.strip()} ({row.type.strip()})" , axis=1)
# /tmp/ipykernel_125638/1060421477.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["word"] = data.apply(lambda row: f"{row.word.strip()} ({row.type.strip()})" , axis=1)
# /tmp/ipykernel_125638/1060421477.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["word"] = data.apply(lambda row: f"{row.word.strip()} ({row.type.strip()})" , axis=1)

# %% [markdown]
# ## 2 Column LateX word,type and definition by CEFR shuffle

# %%
for data, cefr in zip(data_by_cefr, cefrs):
    if data.empty:
        continue
    data = data[["word", "definition", "type", "cefr"]]
    data["word"] = data.apply(lambda row: f"{row.word.strip()} ({row.type.strip()})" , axis=1)
    data = data[["word", "definition"]]

    data = data.sample(frac = 1)

    style = data.style.format(
        escape="latex",
        )
    style = style.hide(axis='index')
    style = style.hide(axis='columns')

    column_format = 'p{1.2in}p{2.3in}p{1.2in}p{2.3in}'
    latex = style.to_latex(
        environment='supertabular',
        column_format=column_format
    )

    latex_lines = latex.splitlines()
    latex = '\n'.join((map(fix_latex_line, latex_lines)))

    filename = f'{DATASET}_shuffle_{cefr}'
    with open(f'build/{filename}.tex', 'w') as f:
        f.write(latex)
# Out:
# /tmp/ipykernel_125638/3056780930.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["word"] = data.apply(lambda row: f"{row.word.strip()} ({row.type.strip()})" , axis=1)
# /tmp/ipykernel_125638/3056780930.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["word"] = data.apply(lambda row: f"{row.word.strip()} ({row.type.strip()})" , axis=1)
# /tmp/ipykernel_125638/3056780930.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["word"] = data.apply(lambda row: f"{row.word.strip()} ({row.type.strip()})" , axis=1)
# /tmp/ipykernel_125638/3056780930.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["word"] = data.apply(lambda row: f"{row.word.strip()} ({row.type.strip()})" , axis=1)

# %%
# Run terminal cd format latexmk oxford*.tex to finish build pdfs
cmd_build = f"latexmk -pdf -cd format/{DATASET}*.tex -outdir=../output" 
os.system(cmd_build)
# Out:
# Rc files read:
#   /etc/LatexMk
# Latexmk: This is Latexmk, John Collins, 20 November 2021, version: 4.76.
# Latexmk: Changing directory to 'format/'
# Rule 'pdflatex': File changes, etc:
#    Changed files, or newly in use since previous run(s):
#       'oxford_3000_two_column_alphabetical.tex'
# ------------
# Run number 1 of rule 'pdflatex'
# ------------
# ------------
# Running 'pdflatex  -recorder -output-directory="/home/jelle/wd/words/english/output"  "oxford_3000_two_column_alphabetical.tex"'
# ------------
# Latexmk: applying rule 'pdflatex'...
# This is pdfTeX, Version 3.141592653-2.6-1.40.22 (TeX Live 2022/dev/Debian) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./oxford_3000_two_column_alphabetical.tex
# LaTeX2e <2021-11-15> patch level 1
# L3 programming layer <2022-01-21>
# (/usr/share/texlive/texmf-dist/tex/latex/base/article.cls
# Document Class: article 2021/10/04 v1.4n Standard LaTeX document class
# (/usr/share/texlive/texmf-dist/tex/latex/base/size10.clo))
# (/usr/share/texlive/texmf-dist/tex/latex/geometry/geometry.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/share/texlive/texmf-dist/tex/generic/iftex/ifvtex.sty
# (/usr/share/texlive/texmf-dist/tex/generic/iftex/iftex.sty)))
# (/usr/share/texlive/texmf-dist/tex/latex/blindtext/blindtext.sty
# (/usr/share/texlive/texmf-dist/tex/latex/tools/xspace.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/base/inputenc.sty
# (/usr/share/texlive/texmf-dist/tex/latex/ucs/utf8x.def))
# (/usr/share/texlive/texmf-dist/tex/latex/ucs/ucs.sty
# (/usr/share/texlive/texmf-dist/tex/latex/ucs/data/uni-global.def))
# (/usr/share/texlive/texmf-dist/tex/latex/supertabular/supertabular.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/tools/array.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/psnfss/helvet.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/psnfss/ot1phv.fd)
# (/usr/share/texlive/texmf-dist/tex/latex/l3backend/l3backend-pdftex.def)
# (/home/jelle/wd/words/english/output/oxford_3000_two_column_alphabetical.aux)
# *geometry* driver: auto-detecting
# *geometry* detected driver: pdftex
# (/usr/share/texlive/texmf-dist/tex/latex/ucs/ucsencs.def)
# (/home/jelle/wd/words/english/output/../build/oxford_3000_table_alphabetical.te
# x
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1--1
# []
#
# Underfull \hbox (badness 2096) in paragraph at lines 3--4
# []\OT1/phv/m/n/10 used be-fore count-able or sin-gu-lar
#
# Underfull \hbox (badness 10000) in paragraph at lines 8--9
# []\OT1/phv/m/n/10 on the sub-ject of some-
#
# Underfull \hbox (badness 10000) in paragraph at lines 8--9
# \OT1/phv/m/n/10 body/something; in con-nec-tion
#
# Underfull \hbox (badness 10000) in paragraph at lines 14--14
# []\OT1/phv/m/n/10 academic \OT1/phv/m/sl/10 (ad-jec-
# (/usr/share/texlive/texmf-dist/tex/latex/ucs/data/uni-32.def)
# Underfull \hbox (badness 3108) in paragraph at lines 17--17
# []\OT1/phv/m/n/10 acceptable \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 10000) in paragraph at lines 21--21
# []\OT1/phv/m/n/10 accommodation
#
# Underfull \hbox (badness 10000) in paragraph at lines 23--23
# []\OT1/phv/m/n/10 according to
#
# Underfull \hbox (badness 4647) in paragraph at lines 23--24
# []\OT1/phv/m/n/10 as stated or re-ported by some-
#
# Underfull \hbox (badness 5802) in paragraph at lines 25--26
# []\OT1/phv/m/n/10 to have the opin-ion that some-
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1--28
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 29--29
# []\OT1/phv/m/n/10 achievement
#
# Underfull \hbox (badness 10000) in paragraph at lines 33--33
# []\OT1/phv/m/n/10 across \OT1/phv/m/sl/10 (prepo-si-
#
# Underfull \hbox (badness 10000) in paragraph at lines 47--47
# []\OT1/phv/m/n/10 additional \OT1/phv/m/sl/10 (ad-jec-
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 28--50
# []
# [1{/var/lib/texmf/fonts/map/pdftex/updmap/pdftex.map}]
# Underfull \hbox (badness 10000) in paragraph at lines 50--50
# []\OT1/phv/m/n/10 administration
#
# Underfull \hbox (badness 10000) in paragraph at lines 59--59
# []\OT1/phv/m/n/10 advanced \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 10000) in paragraph at lines 63--63
# []\OT1/phv/m/n/10 advertisement
#
# Underfull \hbox (badness 6825) in paragraph at lines 68--69
# []\OT1/phv/m/n/10 to pro-duce a change in some-
#
# Underfull \hbox (badness 10000) in paragraph at lines 77--77
# []\OT1/phv/m/n/10 against \OT1/phv/m/sl/10 (prepo-si-
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 50--78
# []
#
# Underfull \hbox (badness 3407) in paragraph at lines 84--84
# []\OT1/phv/m/n/10 aggressive \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 4531) in paragraph at lines 96--97
# []\OT1/phv/m/n/10 a com-pany that pro-vides reg-u-lar
#
# Underfull \hbox (badness 3168) in paragraph at lines 100--101
# []\OT1/phv/m/n/10 a book in which you keep pho-
#
# Underfull \hbox (badness 10000) in paragraph at lines 102--102
# []\OT1/phv/m/n/10 alcoholic \OT1/phv/m/sl/10 (ad-jec-
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 78--108
# []
# [2]
# Underfull \hbox (badness 1383) in paragraph at lines 109--109
# []\OT1/phv/m/n/10 all right \OT1/phv/m/sl/10 (ex-cla-ma-
#
# Underfull \hbox (badness 10000) in paragraph at lines 119--119
# []\OT1/phv/m/n/10 alternative \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 1939) in paragraph at lines 121--121
# []\OT1/phv/m/n/10 although \OT1/phv/m/sl/10 (con-junc-
#
# Underfull \hbox (badness 10000) in paragraph at lines 126--126
# []\OT1/phv/m/n/10 ambitious \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 1365) in paragraph at lines 126--127
# []\OT1/phv/m/n/10 determined to be suc-cess-ful, rich,
#
# Underfull \hbox (badness 10000) in paragraph at lines 127--127
# []\OT1/phv/m/n/10 among \OT1/phv/m/sl/10 (prepo-si-
#
# Underfull \hbox (badness 2521) in paragraph at lines 131--132
# \OT1/phv/m/n/10 some-thing in or-der to un-der-stand
#
# Underfull \hbox (badness 1337) in paragraph at lines 134--135
# \OT1/phv/m/n/10 some-thing has hap-pened that you
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 108--139
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 141--141
# []\OT1/phv/m/n/10 announcement
#
# Underfull \hbox (badness 10000) in paragraph at lines 144--144
# []\OT1/phv/m/n/10 annoying \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 10000) in paragraph at lines 146--146
# []\OT1/phv/m/n/10 another \OT1/phv/m/sl/10 (de-ter-
#
# Underfull \hbox (badness 10000) in paragraph at lines 160--160
# []\OT1/phv/m/n/10 anywhere \OT1/phv/m/sl/10 (pro-
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 139--164
# []
# [3]
# Underfull \hbox (badness 10000) in paragraph at lines 165--165
# []\OT1/phv/m/n/10 apparent \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 2689) in paragraph at lines 170--171
# []\OT1/phv/m/n/10 the way that some-body/something
#
# Underfull \hbox (badness 1057) in paragraph at lines 170--171
# \OT1/phv/m/n/10 looks on the out-side; what some-
#
# Underfull \hbox (badness 1320) in paragraph at lines 175--176
# []\OT1/phv/m/n/10 to rec-og-nize the good qual-i-ties of
#
# Underfull \hbox (badness 10000) in paragraph at lines 176--177
# []\OT1/phv/m/n/10 a way of deal-ing with some-
#
# Underfull \hbox (badness 4229) in paragraph at lines 176--177
# \OT1/phv/m/n/10 body/something; a way of do-ing
#
# Underfull \hbox (badness 1642) in paragraph at lines 181--181
# []\OT1/phv/m/n/10 approximately \OT1/phv/m/sl/10 (ad-
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 164--185
# []
#
# Underfull \hbox (badness 1173) in paragraph at lines 186--187
# []\OT1/phv/m/n/10 to speak an-grily to some-body be-
#
# Underfull \hbox (badness 10000) in paragraph at lines 194--194
# []\OT1/phv/m/n/10 around \OT1/phv/m/sl/10 (prepo-si-
#
# Underfull \hbox (badness 10000) in paragraph at lines 196--196
# []\OT1/phv/m/n/10 arrangement
#
# Underfull \hbox (badness 10000) in paragraph at lines 208--209
# []\OT1/phv/m/n/10 used to de-scribe some-
#
# Underfull \hbox (badness 10000) in paragraph at lines 208--209
# \OT1/phv/m/n/10 body/something ap-pear-ing to be
#
# Underfull \hbox (badness 10000) in paragraph at lines 209--209
# []\OT1/phv/m/n/10 ashamed \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 2452) in paragraph at lines 209--210
# \OT1/phv/m/n/10 about some-body/something or be-
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 185--213
# []
# [4]
# Underfull \hbox (badness 2073) in paragraph at lines 214--215
# []\OT1/phv/m/n/10 an opin-ion or a judge-ment about
#
# Underfull \hbox (badness 10000) in paragraph at lines 217--217
# []\OT1/phv/m/n/10 assistant \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 3179) in paragraph at lines 218--219
# []\OT1/phv/m/n/10 a per-son who helps or sup-ports
#
# Underfull \hbox (badness 3803) in paragraph at lines 220--220
# []\OT1/phv/m/n/10 associated \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 10000) in paragraph at lines 223--224
# []\OT1/phv/m/n/10 used to say where some-
#
# Underfull \hbox (badness 3343) in paragraph at lines 234--235
# []\OT1/phv/m/n/10 the way that you think and feel
#
# Underfull \hbox (badness 7221) in paragraph at lines 234--235
# \OT1/phv/m/n/10 that you be-have to-wards some-
#
# Underfull \hbox (badness 10000) in paragraph at lines 237--237
# []\OT1/phv/m/n/10 attractive \OT1/phv/m/sl/10 (ad-jec-
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 213--238
# []
#
# Underfull \hbox (badness 3271) in paragraph at lines 243--244
# \OT1/phv/m/n/10 colour and the weather be-comes
#
# Underfull \hbox (badness 10000) in paragraph at lines 244--244
# []\OT1/phv/m/n/10 available \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 3758) in paragraph at lines 252--253
# []\OT1/phv/m/n/10 to or at a dis-tance from some-
#
# Underfull \hbox (badness 6893) in paragraph at lines 256--257
# []\OT1/phv/m/n/10 to or into the place, con-di-tion,
#
# Underfull \hbox (badness 4366) in paragraph at lines 256--257
# \OT1/phv/m/n/10 sit-u-a-tion or ac-tiv-ity where some-
#
# Underfull \hbox (badness 2158) in paragraph at lines 258--259
# \OT1/phv/m/n/10 help; to give fi-nan-cial sup-port to
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 238--262
# []
# [5]
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 262--284
# []
#
# Underfull \hbox (badness 2368) in paragraph at lines 288--289
# []\OT1/phv/m/n/10 a fight be-tween armies, ships or
#
# Underfull \hbox (badness 1924) in paragraph at lines 292--293
# []\OT1/phv/m/n/10 an area of sand or small stones
#
# Underfull \hbox (badness 2772) in paragraph at lines 300--300
# []\OT1/phv/m/n/10 because \OT1/phv/m/sl/10 (con-junc-
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 284--305
# []
# [6]
# Underfull \hbox (badness 10000) in paragraph at lines 308--308
# []\OT1/phv/m/n/10 before \OT1/phv/m/sl/10 (con-junc-
#
# Underfull \hbox (badness 1917) in paragraph at lines 315--316
# []\OT1/phv/m/n/10 at or to-wards the back of some-
#
# Underfull \hbox (badness 10000) in paragraph at lines 316--316
# []\OT1/phv/m/n/10 behind \OT1/phv/m/sl/10 (prepo-si-
#
# Underfull \hbox (badness 1917) in paragraph at lines 316--317
# []\OT1/phv/m/n/10 at or to-wards the back of some-
#
# Underfull \hbox (badness 10000) in paragraph at lines 318--319
# []\OT1/phv/m/n/10 a strong feel-ing that some-
#
# Underfull \hbox (badness 4144) in paragraph at lines 318--319
# \OT1/phv/m/n/10 thing/somebody ex-ists or is true;
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 305--335
# []
#
# Underfull \hbox (badness 6842) in paragraph at lines 339--339
# []\OT1/phv/m/n/10 between \OT1/phv/m/sl/10 (prepo-si-
#
# Underfull \hbox (badness 10000) in paragraph at lines 341--341
# []\OT1/phv/m/n/10 beyond \OT1/phv/m/sl/10 (prepo-si-
#
# Underfull \hbox (badness 1077) in paragraph at lines 349--350
# []\OT1/phv/m/n/10 the sci-en-tific study of the life and
#
# Underfull \hbox (badness 4819) in paragraph at lines 360--361
# []\OT1/phv/m/n/10 responsibility for do-ing some-thing
#
# Underfull \hbox (badness 10000) in paragraph at lines 361--362
# []\OT1/phv/m/n/10 to think or say that some-
#
# Underfull \hbox (badness 4543) in paragraph at lines 361--362
# \OT1/phv/m/n/10 body/something is re-spon-si-ble for
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 335--366
# []
# [7]
# Underfull \hbox (badness 1014) in paragraph at lines 366--367
# []\OT1/phv/m/n/10 to stop some-thing from mov-ing or
#
# Underfull \hbox (badness 4454) in paragraph at lines 379--380
# []\OT1/phv/m/n/10 to at-tack some-thing/somebody by
#
# Underfull \hbox (badness 5331) in paragraph at lines 387--388
# \OT1/phv/m/n/10 you have lost in-ter-est in some-
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 366--388
# []
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 388--412
# []
# [8]
# Underfull \hbox (badness 3758) in paragraph at lines 420--421
# []\OT1/phv/m/n/10 to come to a place with some-
#
# Underfull \hbox (badness 1184) in paragraph at lines 435--436
# \OT1/phv/m/n/10 which are grow-ing or fas-tened to-
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 412--440
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 442--442
# []\OT1/phv/m/n/10 businessman
#
# Underfull \hbox (badness 3189) in paragraph at lines 460--461
# []\OT1/phv/m/n/10 to make some-body/something be-
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 440--464
# []
# [9]
# Underfull \hbox (badness 3068) in paragraph at lines 469--470
# \OT1/phv/m/n/10 some-body/something to do some-
#
# Underfull \hbox (badness 1178) in paragraph at lines 470--471
# []\OT1/phv/m/n/10 to de-cide that some-thing that has
#
# Underfull \hbox (badness 10000) in paragraph at lines 473--473
# []\OT1/phv/m/n/10 cannot \OT1/phv/m/sl/10 (modal
#
# Underfull \hbox (badness 10000) in paragraph at lines 480--481
# []\OT1/phv/m/n/10 the act of cap-tur-ing some-
#
# Underfull \hbox (badness 4060) in paragraph at lines 484--485
# []\OT1/phv/m/n/10 the pro-cess of car-ing for some-
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 464--487
# []
#
# Underfull \hbox (badness 6477) in paragraph at lines 489--490
# []\OT1/phv/m/n/10 not giv-ing enough at-ten-tion and
#
# Underfull \hbox (badness 5417) in paragraph at lines 492--493
# []\OT1/phv/m/n/10 to sup-port the weight of some-
#
# Underfull \hbox (badness 1005) in paragraph at lines 504--505
# []\OT1/phv/m/n/10 to make some-thing hap-pen, es-pe-
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 487--506
# []
# [10]
# Underfull \hbox (badness 1590) in paragraph at lines 520--521
# []\OT1/phv/m/n/10 to fas-ten some-thing with a chain;
#
# Underfull \hbox (badness 2050) in paragraph at lines 523--524
# []\OT1/phv/m/n/10 the per-son in charge of a meet-
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 506--533
# []
#
# Underfull \hbox (badness 8189) in paragraph at lines 533--533
# []\OT1/phv/m/n/10 characteristic \OT1/phv/m/sl/10 (ad-
#
# Underfull \hbox (badness 10000) in paragraph at lines 534--534
# []\OT1/phv/m/n/10 characteristic
#
# Underfull \hbox (badness 10000) in paragraph at lines 551--551
# []\OT1/phv/m/n/10 chemical \OT1/phv/m/sl/10 (ad-jec-
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 533--561
# []
# [11]
# Underfull \hbox (badness 10000) in paragraph at lines 569--569
# []\OT1/phv/m/n/10 circumstance
#
# Underfull \hbox (badness 2547) in paragraph at lines 578--579
# \OT1/phv/m/n/10 high qual-ity, set-ting stan-dards for
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 561--589
# []
#
# Underfull \hbox (badness 3769) in paragraph at lines 594--595
# []\OT1/phv/m/n/10 an in-stru-ment for mea-sur-ing and
#
# Underfull \hbox (badness 1024) in paragraph at lines 606--607
# []\OT1/phv/m/n/10 an ob-ject, a piece of ev-i-dence or
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 589--613
# []
# [12]
# Underfull \hbox (badness 5189) in paragraph at lines 613--614
# []\OT1/phv/m/n/10 the roasted seeds (called cof-fee
#
# Underfull \hbox (badness 2351) in paragraph at lines 616--617
# \OT1/phv/m/n/10 and/or throat, mak-ing you cough,
#
# Underfull \hbox (badness 1168) in paragraph at lines 617--618
# \OT1/phv/m/n/10 as an in-sti-tu-tion, a busi-ness or a
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 613--636
# []
#
# Underfull \hbox (badness 1852) in paragraph at lines 644--645
# []\OT1/phv/m/n/10 happening of-ten; ex-ist-ing in large
#
# Underfull \hbox (badness 10000) in paragraph at lines 646--646
# []\OT1/phv/m/n/10 communicate
#
# Underfull \hbox (badness 1859) in paragraph at lines 646--647
# []\OT1/phv/m/n/10 to share or ex-change in-for-ma-tion,
#
# Underfull \hbox (badness 10000) in paragraph at lines 647--647
# []\OT1/phv/m/n/10 communication
#
# Underfull \hbox (badness 6725) in paragraph at lines 654--655
# []\OT1/phv/m/n/10 used to de-scribe a sit-u-a-tion in
#
# Underfull \hbox (badness 1205) in paragraph at lines 656--657
# []\OT1/phv/m/n/10 to say that you are an-noyed, un-
#
# Underfull \hbox (badness 10000) in paragraph at lines 658--658
# []\OT1/phv/m/n/10 complete \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 10000) in paragraph at lines 660--660
# []\OT1/phv/m/n/10 completely \OT1/phv/m/sl/10 (ad-
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 636--661
# []
# [13]
# Underfull \hbox (badness 10000) in paragraph at lines 667--667
# []\OT1/phv/m/n/10 concentration
#
# Underfull \hbox (badness 5847) in paragraph at lines 671--671
# []\OT1/phv/m/n/10 concerned \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 1292) in paragraph at lines 671--672
# []\OT1/phv/m/n/10 worried and feel-ing con-cern about
#
# Underfull \hbox (badness 4556) in paragraph at lines 679--680
# \OT1/phv/m/n/10 lieve in and be sure about the
#
# Underfull \hbox (badness 10000) in paragraph at lines 680--680
# []\OT1/phv/m/n/10 confident \OT1/phv/m/sl/10 (ad-jec-
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 661--685
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 685--685
# []\OT1/phv/m/n/10 confused \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 2073) in paragraph at lines 685--686
# \OT1/phv/m/n/10 stand what is hap-pen-ing or what
#
# Underfull \hbox (badness 10000) in paragraph at lines 686--686
# []\OT1/phv/m/n/10 confusing \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 10000) in paragraph at lines 688--688
# []\OT1/phv/m/n/10 connected \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 10000) in paragraph at lines 690--690
# []\OT1/phv/m/n/10 conscious \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 10000) in paragraph at lines 691--691
# []\OT1/phv/m/n/10 consequence
#
# Underfull \hbox (badness 10000) in paragraph at lines 692--692
# []\OT1/phv/m/n/10 conservative \OT1/phv/m/sl/10 (ad-
#
# Underfull \hbox (badness 10000) in paragraph at lines 693--693
# []\OT1/phv/m/n/10 conservative
#
# Underfull \hbox (badness 10000) in paragraph at lines 695--695
# []\OT1/phv/m/n/10 consideration
#
# Underfull \hbox (badness 1400) in paragraph at lines 695--696
# []\OT1/phv/m/n/10 the act of think-ing care-fully about
#
# Underfull \hbox (badness 10000) in paragraph at lines 697--697
# []\OT1/phv/m/n/10 consistent \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 2469) in paragraph at lines 708--708
# []\OT1/phv/m/n/10 contemporary \OT1/phv/m/sl/10 (ad-
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 685--713
# []
# [14]
# Underfull \hbox (badness 2932) in paragraph at lines 715--715
# []\OT1/phv/m/n/10 continuous \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 1072) in paragraph at lines 718--719
# []\OT1/phv/m/n/10 a dif-fer-ence be-tween two or more
#
# Underfull \hbox (badness 3579) in paragraph at lines 724--724
# []\OT1/phv/m/n/10 convenient \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 10000) in paragraph at lines 725--725
# []\OT1/phv/m/n/10 conversation
#
# Underfull \hbox (badness 2065) in paragraph at lines 725--726
# []\OT1/phv/m/n/10 an in-for-mal talk in-volv-ing a small
#
# Underfull \hbox (badness 10000) in paragraph at lines 728--728
# []\OT1/phv/m/n/10 convinced \OT1/phv/m/sl/10 (ad-jec-
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 713--736
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 740--740
# []\OT1/phv/m/n/10 corporate \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 2564) in paragraph at lines 745--746
# \OT1/phv/m/n/10 of money, you need to pay that
#
# Underfull \hbox (badness 1845) in paragraph at lines 748--749
# \OT1/phv/m/n/10 that are used to make cloth and
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 736--763
# []
# [15]
# Underfull \hbox (badness 1675) in paragraph at lines 766--767
# []\OT1/phv/m/n/10 if a ve-hi-cle crashes or the driver
#
# Underfull \hbox (badness 1337) in paragraph at lines 776--777
# []\OT1/phv/m/n/10 all the peo-ple work-ing on a ship,
#
# Underfull \hbox (badness 2951) in paragraph at lines 781--782
# []\OT1/phv/m/n/10 a stan-dard or prin-ci-ple by which
#
# Underfull \hbox (badness 2027) in paragraph at lines 782--783
# []\OT1/phv/m/n/10 a per-son who ex-presses opin-ions
#
# Underfull \hbox (badness 3039) in paragraph at lines 784--785
# []\OT1/phv/m/n/10 the act of ex-press-ing dis-ap-proval
#
# Underfull \hbox (badness 10000) in paragraph at lines 785--786
# []\OT1/phv/m/n/10 to say that you think some-
#
# Underfull \hbox (badness 10000) in paragraph at lines 785--786
# \OT1/phv/m/n/10 body/something is bad; to say
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 763--788
# []
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 788--817
# []
# [16]
# Underfull \hbox (badness 5036) in paragraph at lines 826--826
# []\OT1/phv/m/n/10 dangerous \OT1/phv/m/sl/10 (ad-jec-
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 817--842
# []
#
# Underfull \hbox (badness 2591) in paragraph at lines 843--844
# []\OT1/phv/m/n/10 a pe-riod of ten years, es-pe-cially
#
# Underfull \hbox (badness 10000) in paragraph at lines 843--844
# \OT1/phv/m/n/10 a con-tin-u-ous pe-riod, such as
#
# Underfull \hbox (badness 1721) in paragraph at lines 846--847
# []\OT1/phv/m/n/10 to think care-fully about the dif-fer-
#
# Underfull \hbox (badness 10000) in paragraph at lines 860--861
# []\OT1/phv/m/n/10 the act of pro-tect-ing some-
#
# Underfull \hbox (badness 10000) in paragraph at lines 867--868
# []\OT1/phv/m/n/10 a pe-riod of time when some-
#
# Underfull \hbox (badness 1354) in paragraph at lines 868--869
# \OT1/phv/m/n/10 force them to do some-thing more
#
# Underfull \hbox (badness 10000) in paragraph at lines 869--869
# []\OT1/phv/m/n/10 deliberate \OT1/phv/m/sl/10 (ad-jec-
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 842--870
# []
# [17]
# Underfull \hbox (badness 10000) in paragraph at lines 870--870
# []\OT1/phv/m/n/10 deliberately \OT1/phv/m/sl/10 (ad-
#
# Underfull \hbox (badness 10000) in paragraph at lines 871--871
# []\OT1/phv/m/n/10 delicious \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 10000) in paragraph at lines 874--874
# []\OT1/phv/m/n/10 delighted \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 6542) in paragraph at lines 885--885
# []\OT1/phv/m/n/10 depressed \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 1953) in paragraph at lines 886--886
# []\OT1/phv/m/n/10 depressing \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 1803) in paragraph at lines 895--896
# []\OT1/phv/m/n/10 a per-son whose job is to de-cide
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 870--896
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 899--899
# []\OT1/phv/m/n/10 desperate \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 10000) in paragraph at lines 900--900
# []\OT1/phv/m/n/10 despite \OT1/phv/m/sl/10 (prepo-si-
#
# Underfull \hbox (badness 10000) in paragraph at lines 901--902
# []\OT1/phv/m/n/10 a place to which some-
#
# Underfull \hbox (badness 2521) in paragraph at lines 901--902
# \OT1/phv/m/n/10 body/something is go-ing or be-ing
#
# Underfull \hbox (badness 1448) in paragraph at lines 910--911
# \OT1/phv/m/n/10 more ad-vanced, stronger, etc.; to
#
# Underfull \hbox (badness 10000) in paragraph at lines 911--911
# []\OT1/phv/m/n/10 development
#
# Underfull \hbox (badness 4819) in paragraph at lines 911--912
# \OT1/phv/m/n/10 that it be-comes more ad-vanced,
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 896--916
# []
# [18]
# Underfull \hbox (badness 1675) in paragraph at lines 920--921
# \OT1/phv/m/n/10 are not like each other; the way
#
# Underfull \hbox (badness 1939) in paragraph at lines 920--921
# \OT1/phv/m/n/10 in which some-body/something has
#
# Underfull \hbox (badness 10000) in paragraph at lines 921--922
# []\OT1/phv/m/n/10 not the same as some-
#
# Underfull \hbox (badness 10000) in paragraph at lines 921--922
# \OT1/phv/m/n/10 body/something; not like some-
#
# Underfull \hbox (badness 10000) in paragraph at lines 922--923
# []\OT1/phv/m/n/10 in a dif-fer-ent way from some-
#
# Underfull \hbox (badness 10000) in paragraph at lines 936--936
# []\OT1/phv/m/n/10 disadvantage
#
# Underfull \hbox (badness 1117) in paragraph at lines 936--937
# \OT1/phv/m/n/10 tends to stop some-body/something
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 916--938
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 939--939
# []\OT1/phv/m/n/10 disappointed \OT1/phv/m/sl/10 (ad-
#
# Underfull \hbox (badness 1072) in paragraph at lines 939--940
# \OT1/phv/m/n/10 for has not hap-pened or been as
#
# Underfull \hbox (badness 10000) in paragraph at lines 940--940
# []\OT1/phv/m/n/10 disappointing \OT1/phv/m/sl/10 (ad-
#
# Underfull \hbox (badness 2050) in paragraph at lines 947--948
# \OT1/phv/m/n/10 body/something, or learn-ing about
#
# Underfull \hbox (badness 10000) in paragraph at lines 949--950
# []\OT1/phv/m/n/10 a con-ver-sa-tion about some-
#
# Underfull \hbox (badness 10000) in paragraph at lines 949--950
# \OT1/phv/m/n/10 body/something; the pro-cess of
#
# Underfull \hbox (badness 10000) in paragraph at lines 952--952
# []\OT1/phv/m/n/10 dishonest \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 10000) in paragraph at lines 954--955
# []\OT1/phv/m/n/10 a feel-ing of not lik-ing some-
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 938--961
# []
# [19]
# Underfull \hbox (badness 10000) in paragraph at lines 972--972
# []\OT1/phv/m/n/10 documentary
#
# Underfull \hbox (badness 10000) in paragraph at lines 975--975
# []\OT1/phv/m/n/10 domestic \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 1210) in paragraph at lines 977--978
# []\OT1/phv/m/n/10 to give money, food, clothes, etc.
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 961--984
# []
#
# Underfull \hbox (badness 1062) in paragraph at lines 984--985
# []\OT1/phv/m/n/10 a feel-ing of be-ing un-cer-tain about
#
# Underfull \hbox (badness 4132) in paragraph at lines 990--990
# []\OT1/phv/m/n/10 downstairs \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 10000) in paragraph at lines 991--991
# []\OT1/phv/m/n/10 downstairs \OT1/phv/m/sl/10 (ad-
#
# Underfull \hbox (badness 10000) in paragraph at lines 992--992
# []\OT1/phv/m/n/10 downwards \OT1/phv/m/sl/10 (ad-
#
# Underfull \hbox (badness 1406) in paragraph at lines 996--997
# []\OT1/phv/m/n/10 to write the first rough ver-sion of
#
# Underfull \hbox (badness 2452) in paragraph at lines 997--998
# []\OT1/phv/m/n/10 to pull some-body/something along
#
# Underfull \hbox (badness 1320) in paragraph at lines 1003--1004
# []\OT1/phv/m/n/10 to ex-pe-ri-ence a se-ries of im-ages,
#
# Underfull \hbox (badness 1210) in paragraph at lines 1006--1007
# []\OT1/phv/m/n/10 wearing clothes and not naked or
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 984--1011
# []
# [20]
# Underfull \hbox (badness 3281) in paragraph at lines 1024--1025
# \OT1/phv/m/n/10 in-for-ma-tion, es-pe-cially films, pho-
#
# Underfull \hbox (badness 2521) in paragraph at lines 1033--1034
# []\OT1/phv/m/n/10 a sud-den, vi-o-lent shak-ing of the
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1011--1038
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 1041--1041
# []\OT1/phv/m/n/10 economic \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 10000) in paragraph at lines 1048--1048
# []\OT1/phv/m/n/10 educated \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 5245) in paragraph at lines 1049--1050
# \OT1/phv/m/n/10 leges or uni-ver-si-ties, to im-prove
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1038--1061
# []
# [21]
# Underfull \hbox (badness 10000) in paragraph at lines 1067--1067
# []\OT1/phv/m/n/10 electrical \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 10000) in paragraph at lines 1069--1069
# []\OT1/phv/m/n/10 electronic \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 10000) in paragraph at lines 1077--1077
# []\OT1/phv/m/n/10 embarrassed \OT1/phv/m/sl/10 (ad-
#
# Underfull \hbox (badness 4024) in paragraph at lines 1078--1078
# []\OT1/phv/m/n/10 embarrassing \OT1/phv/m/sl/10 (ad-
#
# Underfull \hbox (badness 2913) in paragraph at lines 1080--1081
# []\OT1/phv/m/n/10 a sud-den se-ri-ous and dan-ger-ous
#
# Underfull \hbox (badness 10000) in paragraph at lines 1082--1082
# []\OT1/phv/m/n/10 emotional \OT1/phv/m/sl/10 (ad-jec-
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1061--1086
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 1091--1092
# []\OT1/phv/m/n/10 to make it pos-si-ble for some-
#
# Underfull \hbox (badness 6510) in paragraph at lines 1093--1094
# \OT1/phv/m/n/10 some-thing un-pleas-ant or dif-fi-cult,
#
# Underfull \hbox (badness 1082) in paragraph at lines 1098--1099
# []\OT1/phv/m/n/10 a per-son who hates some-body or
#
# Underfull \hbox (badness 10000) in paragraph at lines 1101--1101
# []\OT1/phv/m/n/10 engaged \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 6510) in paragraph at lines 1104--1105
# []\OT1/phv/m/n/10 the ac-tiv-ity of ap-ply-ing sci-en-tific
#
# Underfull \hbox (badness 1184) in paragraph at lines 1105--1106
# []\OT1/phv/m/n/10 to in-crease or fur-ther im-prove the
#
# Underfull \hbox (badness 10000) in paragraph at lines 1107--1107
# []\OT1/phv/m/n/10 enormous \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 10000) in paragraph at lines 1109--1109
# []\OT1/phv/m/n/10 enough \OT1/phv/m/sl/10 (de-ter-
#
# Underfull \hbox (badness 1939) in paragraph at lines 1109--1110
# []\OT1/phv/m/n/10 used be-fore plu-ral or un-count-able
#
# Underfull \hbox (badness 1199) in paragraph at lines 1111--1112
# []\OT1/phv/m/n/10 an of-fi-cial pro-cess to find out the
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1086--1112
# []
# [22]
# Underfull \hbox (badness 10000) in paragraph at lines 1115--1115
# []\OT1/phv/m/n/10 entertainment
#
# Underfull \hbox (badness 5077) in paragraph at lines 1117--1118
# []\OT1/phv/m/n/10 feeling or show-ing a lot of ex-
#
# Underfull \hbox (badness 1158) in paragraph at lines 1117--1118
# \OT1/phv/m/n/10 cite-ment and in-ter-est about some-
#
# Underfull \hbox (badness 10000) in paragraph at lines 1135--1135
# []\OT1/phv/m/n/10 essential \OT1/phv/m/sl/10 (ad-jec-
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1112--1137
# []
#
# Underfull \hbox (badness 5161) in paragraph at lines 1146--1147
# []\OT1/phv/m/n/10 a thing that hap-pens, es-pe-cially
#
# Underfull \hbox (badness 10000) in paragraph at lines 1150--1150
# []\OT1/phv/m/n/10 everybody \OT1/phv/m/sl/10 (pro-
#
# Underfull \hbox (badness 10000) in paragraph at lines 1151--1151
# []\OT1/phv/m/n/10 everyday \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 10000) in paragraph at lines 1153--1153
# []\OT1/phv/m/n/10 everything \OT1/phv/m/sl/10 (pro-
#
# Underfull \hbox (badness 10000) in paragraph at lines 1154--1154
# []\OT1/phv/m/n/10 everywhere \OT1/phv/m/sl/10 (ad-
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1137--1162
# []
# [23]
# Underfull \hbox (badness 10000) in paragraph at lines 1164--1164
# []\OT1/phv/m/n/10 excellent \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 10000) in paragraph at lines 1165--1165
# []\OT1/phv/m/n/10 except \OT1/phv/m/sl/10 (con-junc-
#
# Underfull \hbox (badness 1571) in paragraph at lines 1165--1166
# \OT1/phv/m/n/10 that makes a state-ment not com-
#
# Underfull \hbox (badness 10000) in paragraph at lines 1166--1166
# []\OT1/phv/m/n/10 except \OT1/phv/m/sl/10 (prepo-si-
#
# Underfull \hbox (badness 1173) in paragraph at lines 1166--1167
# []\OT1/phv/m/n/10 used be-fore you men-tion the only
#
# Underfull \hbox (badness 10000) in paragraph at lines 1174--1174
# []\OT1/phv/m/n/10 executive \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 1400) in paragraph at lines 1182--1183
# []\OT1/phv/m/n/10 to think or be-lieve that some-thing
#
# Underfull \hbox (badness 10000) in paragraph at lines 1184--1184
# []\OT1/phv/m/n/10 expected \OT1/phv/m/sl/10 (ad-jec-
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1162--1185
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 1187--1187
# []\OT1/phv/m/n/10 expensive \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 10000) in paragraph at lines 1190--1190
# []\OT1/phv/m/n/10 experienced \OT1/phv/m/sl/10 (ad-
#
# Underfull \hbox (badness 1642) in paragraph at lines 1197--1198
# []\OT1/phv/m/n/10 to burst (= break apart) or make
#
# Underfull \hbox (badness 2990) in paragraph at lines 1200--1201
# \OT1/phv/m/n/10 ex-plod-ing; the act of de-lib-er-ately
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1185--1211
# []
# [24]
# Underfull \hbox (badness 10000) in paragraph at lines 1212--1212
# []\OT1/phv/m/n/10 extraordinary \OT1/phv/m/sl/10 (ad-
#
# Underfull \hbox (badness 2005) in paragraph at lines 1223--1224
# []\OT1/phv/m/n/10 to not be suc-cess-ful in achiev-ing
#
# Underfull \hbox (badness 1072) in paragraph at lines 1231--1232
# []\OT1/phv/m/n/10 well known to you; of-ten seen or
#
# Underfull \hbox (badness 10000) in paragraph at lines 1235--1236
# []\OT1/phv/m/n/10 a per-son who ad-mires some-
#
# Underfull \hbox (badness 1540) in paragraph at lines 1237--1238
# []\OT1/phv/m/n/10 to want some-thing or want to do
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1211--1241
# []
#
# Underfull \hbox (badness 4441) in paragraph at lines 1245--1245
# []\OT1/phv/m/n/10 fascinating \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 10000) in paragraph at lines 1260--1261
# []\OT1/phv/m/n/10 to be fright-ened of some-
#
# Underfull \hbox (badness 10000) in paragraph at lines 1260--1261
# \OT1/phv/m/n/10 body/something or fright-ened of
#
# Underfull \hbox (badness 1062) in paragraph at lines 1262--1263
# []\OT1/phv/m/n/10 something im-por-tant, in-ter-est-ing or
#
# Underfull \hbox (badness 1688) in paragraph at lines 1268--1269
# \OT1/phv/m/n/10 how good or use-ful some-thing or
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1241--1269
# []
# [25]
# Underfull \hbox (badness 1642) in paragraph at lines 1280--1281
# []\OT1/phv/m/n/10 a type of lit-er-a-ture that de-scribes
#
# Underfull \hbox (badness 2005) in paragraph at lines 1283--1283
# []\OT1/phv/m/n/10 fifth \OT1/phv/m/sl/10 (or-di-nal num-
#
# Underfull \hbox (badness 10000) in paragraph at lines 1285--1286
# []\OT1/phv/m/n/10 a strug-gle against some-
#
# Underfull \hbox (badness 10000) in paragraph at lines 1285--1286
# \OT1/phv/m/n/10 body/something us-ing phys-i-cal
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1269--1292
# []
#
# Underfull \hbox (badness 2012) in paragraph at lines 1313--1313
# []\OT1/phv/m/n/10 first \OT1/phv/m/sl/10 (or-di-nal num-
#
# Underfull \hbox (badness 1540) in paragraph at lines 1318--1319
# []\OT1/phv/m/n/10 healthy and strong, es-pe-cially be-
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1292--1319
# []
# [26]
# Underfull \hbox (badness 4779) in paragraph at lines 1325--1326
# []\OT1/phv/m/n/10 a piece of cloth with a spe-cial
#
# Underfull \hbox (badness 1990) in paragraph at lines 1337--1338
# \OT1/phv/m/n/10 from grain, es-pe-cially wheat, and
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1319--1343
# []
#
# Underfull \hbox (badness 4819) in paragraph at lines 1356--1356
# []\OT1/phv/m/n/10 following \OT1/phv/m/sl/10 (prepo-si-
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1343--1368
# []
# [27]
# Underfull \hbox (badness 1490) in paragraph at lines 1393--1394
# []\OT1/phv/m/n/10 a piece of elec-tri-cal equip-ment in
#
# Underfull \hbox (badness 2951) in paragraph at lines 1397--1398
# []\OT1/phv/m/n/10 to make some-body sud-denly feel
#
# Underfull \hbox (badness 10000) in paragraph at lines 1398--1398
# []\OT1/phv/m/n/10 frightened \OT1/phv/m/sl/10 (ad-jec-
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1368--1399
# []
#
# Underfull \hbox (badness 6125) in paragraph at lines 1399--1399
# []\OT1/phv/m/n/10 frightening \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 10000) in paragraph at lines 1401--1402
# []\OT1/phv/m/n/10 used to show where some-
#
# Underfull \hbox (badness 10000) in paragraph at lines 1417--1417
# []\OT1/phv/m/n/10 fundamental \OT1/phv/m/sl/10 (ad-
#
# Underfull \hbox (badness 10000) in paragraph at lines 1424--1424
# []\OT1/phv/m/n/10 furthermore \OT1/phv/m/sl/10 (ad-
#
# Underfull \hbox (badness 1286) in paragraph at lines 1424--1425
# []\OT1/phv/m/n/10 in ad-di-tion to what has just been
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1399--1426
# []
# [28]
# Underfull \hbox (badness 2181) in paragraph at lines 1426--1427
# []\OT1/phv/m/n/10 the time that will come af-ter the
#
# Underfull \hbox (badness 10000) in paragraph at lines 1442--1442
# []\OT1/phv/m/n/10 generous \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 2426) in paragraph at lines 1446--1447
# []\OT1/phv/m/n/10 the sci-en-tific study of the earth's
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1426--1452
# []
#
# Underfull \hbox (badness 1038) in paragraph at lines 1465--1466
# \OT1/phv/m/n/10 ground us-ing sticks with a spe-cial
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1452--1480
# []
# [29]
# Underfull \hbox (badness 10000) in paragraph at lines 1482--1482
# []\OT1/phv/m/n/10 grandmother
#
# Underfull \hbox (badness 1694) in paragraph at lines 1486--1487
# []\OT1/phv/m/n/10 a com-mon wild plant with nar-row
#
# Underfull \hbox (badness 1354) in paragraph at lines 1489--1490
# []\OT1/phv/m/n/10 having the colour of grass or the
#
# Underfull \hbox (badness 1142) in paragraph at lines 1497--1498
# []\OT1/phv/m/n/10 the pro-cess in peo-ple, an-i-mals or
#
# Underfull \hbox (badness 1242) in paragraph at lines 1498--1499
# []\OT1/phv/m/n/10 a for-mal promise that you will do
#
# Underfull \hbox (badness 4181) in paragraph at lines 1499--1500
# []\OT1/phv/m/n/10 to promise to do some-thing; to
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1480--1506
# []
#
# Underfull \hbox (badness 1603) in paragraph at lines 1507--1508
# \OT1/phv/m/n/10 done some-thing that you know is
#
# Underfull \hbox (badness 1400) in paragraph at lines 1523--1524
# []\OT1/phv/m/n/10 to at-tach some-thing, or to be at-
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1506--1534
# []
# [30]
# Underfull \hbox (badness 10000) in paragraph at lines 1538--1538
# []\OT1/phv/m/n/10 have \OT1/phv/m/sl/10 (aux-il-iary
#
# Underfull \hbox (badness 10000) in paragraph at lines 1539--1539
# []\OT1/phv/m/n/10 have to \OT1/phv/m/sl/10 (modal
#
# Underfull \hbox (badness 1546) in paragraph at lines 1558--1559
# []\OT1/phv/m/n/10 an air-craft with-out wings that has
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1534--1560
# []
#
# Underfull \hbox (badness 1189) in paragraph at lines 1572--1573
# \OT1/phv/m/n/10 or to ex-press in-ter-est, sur-prise or
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1560--1583
# []
# [31]
# Underfull \hbox (badness 3019) in paragraph at lines 1588--1589
# []\OT1/phv/m/n/10 important in his-tory; likely to be
#
# Underfull \hbox (badness 10000) in paragraph at lines 1589--1589
# []\OT1/phv/m/n/10 historical \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 5756) in paragraph at lines 1592--1593
# []\OT1/phv/m/n/10 to bring your hand, or an ob-
#
# Underfull \hbox (badness 10000) in paragraph at lines 1595--1596
# []\OT1/phv/m/n/10 the ac-tion of hold-ing some-
#
# Underfull \hbox (badness 1953) in paragraph at lines 1595--1596
# \OT1/phv/m/n/10 body/something; the way you are
#
# Underfull \hbox (badness 1107) in paragraph at lines 1609--1610
# []\OT1/phv/m/n/10 to want some-thing to hap-pen and
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1583--1611
# []
#
# Underfull \hbox (badness 1199) in paragraph at lines 1621--1622
# []\OT1/phv/m/n/10 all the peo-ple liv-ing to-gether in a
#
# Underfull \hbox (badness 10000) in paragraph at lines 1628--1628
# []\OT1/phv/m/n/10 humorous \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 10000) in paragraph at lines 1632--1633
# []\OT1/phv/m/n/10 an act of look-ing for some-
#
# Underfull \hbox (badness 3229) in paragraph at lines 1632--1633
# \OT1/phv/m/n/10 body/something that is dif-fi-cult to
#
# Underfull \hbox (badness 3428) in paragraph at lines 1635--1636
# \OT1/phv/m/n/10 es-pe-cially in the west-ern At-lantic
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1611--1636
# []
# [32]
# Underfull \hbox (badness 1838) in paragraph at lines 1639--1640
# []\OT1/phv/m/n/10 a feel-ing of un-hap-pi-ness be-cause
#
# Underfull \hbox (badness 3229) in paragraph at lines 1640--1641
# []\OT1/phv/m/n/10 to cause phys-i-cal pain to some-
#
# Underfull \hbox (badness 10000) in paragraph at lines 1640--1641
# \OT1/phv/m/n/10 body/yourself; to in-jure some-
#
# Underfull \hbox (badness 7613) in paragraph at lines 1648--1649
# []\OT1/phv/m/n/10 to rec-og-nize some-body/something
#
# Underfull \hbox (badness 1472) in paragraph at lines 1655--1656
# []\OT1/phv/m/n/10 to use pic-tures, pho-tographs, di-a-
#
# Underfull \hbox (badness 1072) in paragraph at lines 1656--1657
# \OT1/phv/m/n/10 a-zine, for dec-o-ra-tion or to ex-plain
#
# Underfull \hbox (badness 10000) in paragraph at lines 1658--1658
# []\OT1/phv/m/n/10 imaginary \OT1/phv/m/sl/10 (ad-jec-
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1636--1660
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 1661--1661
# []\OT1/phv/m/n/10 immediate \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 10000) in paragraph at lines 1662--1662
# []\OT1/phv/m/n/10 immediately \OT1/phv/m/sl/10 (ad-
#
# Underfull \hbox (badness 10000) in paragraph at lines 1665--1666
# []\OT1/phv/m/n/10 to have an ef-fect on some-
#
# Underfull \hbox (badness 10000) in paragraph at lines 1666--1666
# []\OT1/phv/m/n/10 impatient \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 10000) in paragraph at lines 1666--1667
# []\OT1/phv/m/n/10 annoyed by some-body/something,
#
# Underfull \hbox (badness 10000) in paragraph at lines 1671--1671
# []\OT1/phv/m/n/10 important \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 5592) in paragraph at lines 1673--1673
# []\OT1/phv/m/n/10 impossible \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 10000) in paragraph at lines 1675--1675
# []\OT1/phv/m/n/10 impressed \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 5563) in paragraph at lines 1675--1676
# []\OT1/phv/m/n/10 admiring some-body/something be-
#
# Underfull \hbox (badness 2302) in paragraph at lines 1676--1677
# \OT1/phv/m/n/10 or that some-body/something gives
#
# Underfull \hbox (badness 4378) in paragraph at lines 1677--1677
# []\OT1/phv/m/n/10 impressive \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 10000) in paragraph at lines 1679--1679
# []\OT1/phv/m/n/10 improvement
#
# Underfull \hbox (badness 2781) in paragraph at lines 1686--1686
# []\OT1/phv/m/n/10 including \OT1/phv/m/sl/10 (prepo-si-
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1660--1687
# []
# [33]
# Underfull \hbox (badness 10000) in paragraph at lines 1690--1690
# []\OT1/phv/m/n/10 increasingly \OT1/phv/m/sl/10 (ad-
#
# Underfull \hbox (badness 10000) in paragraph at lines 1691--1691
# []\OT1/phv/m/n/10 incredible \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 10000) in paragraph at lines 1694--1694
# []\OT1/phv/m/n/10 independent \OT1/phv/m/sl/10 (ad-
#
# Underfull \hbox (badness 10000) in paragraph at lines 1697--1697
# []\OT1/phv/m/n/10 individual \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 10000) in paragraph at lines 1701--1701
# []\OT1/phv/m/n/10 industrial \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 1496) in paragraph at lines 1707--1708
# []\OT1/phv/m/n/10 relaxed and friendly; not fol-low-ing
#
# Underfull \hbox (badness 10000) in paragraph at lines 1708--1709
# []\OT1/phv/m/n/10 facts or de-tails about some-
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1687--1713
# []
#
# Underfull \hbox (badness 1199) in paragraph at lines 1718--1719
# []\OT1/phv/m/n/10 an of-fi-cial pro-cess to find out the
#
# Underfull \hbox (badness 1389) in paragraph at lines 1722--1723
# []\OT1/phv/m/n/10 the in-ner part, side or sur-face of
#
# Underfull \hbox (badness 1478) in paragraph at lines 1723--1724
# []\OT1/phv/m/n/10 on or to the in-ner part of some-
#
# Underfull \hbox (badness 10000) in paragraph at lines 1723--1724
# \OT1/phv/m/n/10 thing/somebody; within some-
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1713--1737
# []
# [34]
# Underfull \hbox (badness 10000) in paragraph at lines 1737--1737
# []\OT1/phv/m/n/10 intelligent \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 10000) in paragraph at lines 1744--1744
# []\OT1/phv/m/n/10 interested \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 10000) in paragraph at lines 1745--1745
# []\OT1/phv/m/n/10 interesting \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 10000) in paragraph at lines 1747--1747
# []\OT1/phv/m/n/10 international \OT1/phv/m/sl/10 (ad-
#
# Underfull \hbox (badness 2894) in paragraph at lines 1748--1749
# []\OT1/phv/m/n/10 an in-ter-na-tional com-puter net-work
#
# Underfull \hbox (badness 1708) in paragraph at lines 1754--1755
# \OT1/phv/m/n/10 not met be-fore what each other's
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1737--1760
# []
#
# Underfull \hbox (badness 1924) in paragraph at lines 1774--1775
# []\OT1/phv/m/n/10 belonging to or con-nected with a
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1760--1780
# []
# [35]
# Underfull \hbox (badness 1394) in paragraph at lines 1785--1786
# []\OT1/phv/m/n/10 to say some-thing to make peo-ple
#
# Underfull \hbox (badness 3780) in paragraph at lines 1791--1792
# []\OT1/phv/m/n/10 to form an opin-ion about some-
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1780--1807
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 1817--1818
# []\OT1/phv/m/n/10 the act of kiss-ing some-
#
# Underfull \hbox (badness 1028) in paragraph at lines 1825--1826
# []\OT1/phv/m/n/10 the in-for-ma-tion, un-der-stand-ing and
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1807--1834
# []
# [36]
# Underfull \hbox (badness 1019) in paragraph at lines 1834--1835
# []\OT1/phv/m/n/10 a large area of wa-ter that is sur-
#
# Underfull \hbox (badness 6188) in paragraph at lines 1839--1840
# []\OT1/phv/m/n/10 the sys-tem of com-mu-ni-ca-tion in
#
# Underfull \hbox (badness 1033) in paragraph at lines 1858--1859
# []\OT1/phv/m/n/10 a rule that deals with a par-tic-u-lar
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1834--1862
# []
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1862--1889
# []
# [37]
# Underfull \hbox (badness 2452) in paragraph at lines 1899--1900
# []\OT1/phv/m/n/10 a build-ing in which col-lec-tions of
#
# Underfull \hbox (badness 4792) in paragraph at lines 1901--1902
# []\OT1/phv/m/n/10 a state-ment made by some-body
#
# Underfull \hbox (badness 2189) in paragraph at lines 1906--1907
# []\OT1/phv/m/n/10 a ma-chine that car-ries peo-ple or
#
# Underfull \hbox (badness 1122) in paragraph at lines 1913--1914
# []\OT1/phv/m/n/10 to find some-body/something pleas-
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1889--1916
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 1928--1929
# []\OT1/phv/m/n/10 to pay at-ten-tion to some-
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1916--1942
# []
# [38]
# Underfull \hbox (badness 10000) in paragraph at lines 1955--1955
# []\OT1/phv/m/n/10 long-term (ad-jec-
#
# Underfull \hbox (badness 10000) in paragraph at lines 1957--1958
# []\OT1/phv/m/n/10 an act of look-ing at some-
#
# Underfull \hbox (badness 1389) in paragraph at lines 1961--1962
# []\OT1/phv/m/n/10 a large ve-hi-cle for car-ry-ing heavy
#
# Underfull \hbox (badness 10000) in paragraph at lines 1962--1963
# []\OT1/phv/m/n/10 to be un-able to find some-
#
# Underfull \hbox (badness 1082) in paragraph at lines 1965--1966
# []\OT1/phv/m/n/10 used with verbs to mean `a great
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 1942--1970
# []
#
# Underfull \hbox (badness 1163) in paragraph at lines 1987--1988
# []\OT1/phv/m/n/10 having or us-ing spe-cial pow-ers to
#
# Underfull \hbox (badness 1127) in paragraph at lines 1987--1988
# \OT1/phv/m/n/10 make im-pos-si-ble things hap-pen or
#
# Underfull \hbox (badness 2096) in paragraph at lines 1988--1989
# []\OT1/phv/m/n/10 the se-cret power of ap-pear-ing to
#
# ...
# []\OT1/phv/m/n/10 concentration
#
# Underfull \hbox (badness 1117) in paragraph at lines 313--314
# []\OT1/phv/m/n/10 to feel sorry about some-thing you
#
# Underfull \hbox (badness 10000) in paragraph at lines 323--323
# []\OT1/phv/m/n/10 administration
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 300--324
# []
# [65]
# Underfull \hbox (badness 10000) in paragraph at lines 328--328
# []\OT1/phv/m/n/10 significant \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 1838) in paragraph at lines 331--332
# []\OT1/phv/m/n/10 a feel-ing of un-hap-pi-ness be-cause
#
# Underfull \hbox (badness 2781) in paragraph at lines 344--344
# []\OT1/phv/m/n/10 whereas \OT1/phv/m/sl/10 (con-junc-
#
# Underfull \hbox (badness 1472) in paragraph at lines 352--353
# []\OT1/phv/m/n/10 to use pic-tures, pho-tographs, di-a-
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 324--354
# []
#
# Underfull \hbox (badness 4819) in paragraph at lines 354--354
# []\OT1/phv/m/n/10 following \OT1/phv/m/sl/10 (prepo-si-
#
# Underfull \hbox (badness 4181) in paragraph at lines 360--361
# []\OT1/phv/m/n/10 to promise to do some-thing; to
#
# Underfull \hbox (badness 10000) in paragraph at lines 363--363
# []\OT1/phv/m/n/10 characteristic
#
# Underfull \hbox (badness 10000) in paragraph at lines 377--377
# []\OT1/phv/m/n/10 long-term (ad-jec-
#
# Underfull \hbox (badness 2426) in paragraph at lines 378--379
# []\OT1/phv/m/n/10 to learn or un-der-stand some-thing
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 354--382
# []
# [66]
# Underfull \hbox (badness 10000) in paragraph at lines 382--383
# []\OT1/phv/m/n/10 the act of mov-ing some-
#
# Underfull \hbox (badness 10000) in paragraph at lines 382--383
# \OT1/phv/m/n/10 body/something from one place,
#
# Underfull \hbox (badness 10000) in paragraph at lines 386--387
# []\OT1/phv/m/n/10 an act of look-ing for some-
#
# Underfull \hbox (badness 3229) in paragraph at lines 386--387
# \OT1/phv/m/n/10 body/something that is dif-fi-cult to
#
# Underfull \hbox (badness 10000) in paragraph at lines 393--393
# []\OT1/phv/m/n/10 corporate \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 10000) in paragraph at lines 394--394
# []\OT1/phv/m/n/10 circumstance
#
# Underfull \hbox (badness 10000) in paragraph at lines 402--402
# []\OT1/phv/m/n/10 additional \OT1/phv/m/sl/10 (ad-jec-
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 382--404
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 404--405
# []\OT1/phv/m/n/10 the ac-tion of hold-ing some-
#
# Underfull \hbox (badness 1953) in paragraph at lines 404--405
# \OT1/phv/m/n/10 body/something; the way you are
#
# Underfull \hbox (badness 3039) in paragraph at lines 406--407
# []\OT1/phv/m/n/10 the act of ex-press-ing dis-ap-proval
#
# Underfull \hbox (badness 4024) in paragraph at lines 408--409
# \OT1/phv/m/n/10 what some-body/something is like,
#
# Underfull \hbox (badness 1199) in paragraph at lines 409--410
# []\OT1/phv/m/n/10 an of-fi-cial pro-cess to find out the
#
# Underfull \hbox (badness 1603) in paragraph at lines 424--425
# []\OT1/phv/m/n/10 to mea-sure how long it takes for
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 404--426
# []
# [67]
# Underfull \hbox (badness 1052) in paragraph at lines 428--429
# []\OT1/phv/m/n/10 a de-scrip-tion of the main facts or
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 426--451
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 453--453
# []\OT1/phv/m/n/10 impatient \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 10000) in paragraph at lines 453--454
# []\OT1/phv/m/n/10 annoyed by some-body/something,
#
# Underfull \hbox (badness 10000) in paragraph at lines 468--468
# []\OT1/phv/m/n/10 minimum \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 2573) in paragraph at lines 470--471
# []\OT1/phv/m/n/10 the dis-tance over which you can
#
# Underfull \hbox (badness 1158) in paragraph at lines 472--473
# []\OT1/phv/m/n/10 closely con-nected with the sub-ject
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 451--475
# []
# [68]
# Underfull \hbox (badness 10000) in paragraph at lines 478--478
# []\OT1/phv/m/n/10 furthermore \OT1/phv/m/sl/10 (ad-
#
# Underfull \hbox (badness 1286) in paragraph at lines 478--479
# []\OT1/phv/m/n/10 in ad-di-tion to what has just been
#
# Underfull \hbox (badness 2134) in paragraph at lines 491--492
# \OT1/phv/m/n/10 give good ad-vice be-cause of the
#
# Underfull \hbox (badness 10000) in paragraph at lines 493--493
# []\OT1/phv/m/n/10 extraordinary \OT1/phv/m/sl/10 (ad-
#
# Underfull \hbox (badness 1675) in paragraph at lines 495--496
# []\OT1/phv/m/n/10 if a ve-hi-cle crashes or the driver
#
# Underfull \hbox (badness 2359) in paragraph at lines 497--498
# \OT1/phv/m/n/10 etc. that are able to have sex
#
# Underfull \hbox (badness 1057) in paragraph at lines 497--498
# \OT1/phv/m/n/10 young are di-vided, smaller than a
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 475--498
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 506--507
# []\OT1/phv/m/n/10 the dark shape that some-
#
# Underfull \hbox (badness 6708) in paragraph at lines 506--507
# \OT1/phv/m/n/10 body/something's form makes on
#
# Underfull \hbox (badness 1178) in paragraph at lines 522--523
# []\OT1/phv/m/n/10 to de-cide that some-thing that has
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 498--524
# []
# [69]
# Underfull \hbox (badness 10000) in paragraph at lines 526--526
# []\OT1/phv/m/n/10 pregnant \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 10000) in paragraph at lines 527--527
# []\OT1/phv/m/n/10 increasingly \OT1/phv/m/sl/10 (ad-
#
# Underfull \hbox (badness 1412) in paragraph at lines 529--530
# []\OT1/phv/m/n/10 to say or write a com-ment about
#
# Underfull \hbox (badness 10000) in paragraph at lines 537--537
# []\OT1/phv/m/n/10 occasionally \OT1/phv/m/sl/10 (ad-
#
# Underfull \hbox (badness 10000) in paragraph at lines 539--539
# []\OT1/phv/m/n/10 representative
#
# Underfull \hbox (badness 2781) in paragraph at lines 544--545
# \OT1/phv/m/n/10 cause they have done some-thing
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 524--552
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 553--553
# []\OT1/phv/m/n/10 desperate \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 10000) in paragraph at lines 562--562
# []\OT1/phv/m/n/10 deliberate \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 5802) in paragraph at lines 569--570
# []\OT1/phv/m/n/10 to have the opin-ion that some-
#
# Underfull \hbox (badness 1242) in paragraph at lines 570--571
# []\OT1/phv/m/n/10 a for-mal promise that you will do
#
# Underfull \hbox (badness 2469) in paragraph at lines 574--574
# []\OT1/phv/m/n/10 contemporary \OT1/phv/m/sl/10 (ad-
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 552--576
# []
# [70]
# Underfull \hbox (badness 10000) in paragraph at lines 583--583
# []\OT1/phv/m/n/10 conservative
#
# Underfull \hbox (badness 10000) in paragraph at lines 587--587
# []\OT1/phv/m/n/10 consistent \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 10000) in paragraph at lines 595--596
# []\OT1/phv/m/n/10 to vary be-tween two par-tic-u-lar
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 576--604
# []
#
# Underfull \hbox (badness 2744) in paragraph at lines 610--611
# []\OT1/phv/m/n/10 a square or rect-an-gu-lar piece of
#
# Underfull \hbox (badness 10000) in paragraph at lines 611--611
# []\OT1/phv/m/n/10 temporary \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 10000) in paragraph at lines 625--626
# []\OT1/phv/m/n/10 the speed at which some-
#
# Underfull \hbox (badness 10000) in paragraph at lines 625--626
# \OT1/phv/m/n/10 body/something walks, runs or
#
# Underfull \hbox (badness 10000) in paragraph at lines 631--631
# []\OT1/phv/m/n/10 impressed \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 5563) in paragraph at lines 631--632
# []\OT1/phv/m/n/10 admiring some-body/something be-
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 604--632
# []
# [71]
# Underfull \hbox (badness 1803) in paragraph at lines 635--636
# []\OT1/phv/m/n/10 the state of be-ing alone and not
#
# Underfull \hbox (badness 10000) in paragraph at lines 637--637
# []\OT1/phv/m/n/10 numerous \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 10000) in paragraph at lines 639--640
# []\OT1/phv/m/n/10 the act of pro-tect-ing some-
#
# Underfull \hbox (badness 10000) in paragraph at lines 646--647
# []\OT1/phv/m/n/10 to make it pos-si-ble for some-
#
# Underfull \hbox (badness 1337) in paragraph at lines 647--648
# \OT1/phv/m/n/10 some-thing has hap-pened that you
#
# Underfull \hbox (badness 10000) in paragraph at lines 648--648
# []\OT1/phv/m/n/10 dishonest \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 1838) in paragraph at lines 653--654
# []\OT1/phv/m/n/10 fine soft thread pro-duced by silk-
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 632--656
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 659--659
# []\OT1/phv/m/n/10 apparent \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 3312) in paragraph at lines 660--660
# []\OT1/phv/m/n/10 permanent \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 10000) in paragraph at lines 667--667
# []\OT1/phv/m/n/10 specialist \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 1337) in paragraph at lines 673--674
# []\OT1/phv/m/n/10 all the peo-ple work-ing on a ship,
#
# Underfull \hbox (badness 10000) in paragraph at lines 676--676
# []\OT1/phv/m/n/10 delighted \OT1/phv/m/sl/10 (ad-jec-
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 656--681
# []
# [72]
# Underfull \hbox (badness 3803) in paragraph at lines 682--682
# []\OT1/phv/m/n/10 associated \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 10000) in paragraph at lines 684--684
# []\OT1/phv/m/n/10 unknown \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 1168) in paragraph at lines 687--688
# \OT1/phv/m/n/10 as an in-sti-tu-tion, a busi-ness or a
#
# Underfull \hbox (badness 5504) in paragraph at lines 692--693
# []\OT1/phv/m/n/10 things that have been made or
#
# Underfull \hbox (badness 1199) in paragraph at lines 697--698
# []\OT1/phv/m/n/10 an of-fi-cial pro-cess to find out the
#
# Underfull \hbox (badness 1184) in paragraph at lines 700--701
# \OT1/phv/m/n/10 which are grow-ing or fas-tened to-
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 681--707
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 710--710
# []\OT1/phv/m/n/10 maximum \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 10000) in paragraph at lines 711--711
# []\OT1/phv/m/n/10 significantly \OT1/phv/m/sl/10 (ad-
#
# Underfull \hbox (badness 1406) in paragraph at lines 722--723
# []\OT1/phv/m/n/10 to write the first rough ver-sion of
#
# Underfull \hbox (badness 10000) in paragraph at lines 728--729
# []\OT1/phv/m/n/10 the act of cap-tur-ing some-
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 707--732
# []
# [73]
# Underfull \hbox (badness 5077) in paragraph at lines 735--736
# []\OT1/phv/m/n/10 feeling or show-ing a lot of ex-
#
# Underfull \hbox (badness 1158) in paragraph at lines 735--736
# \OT1/phv/m/n/10 cite-ment and in-ter-est about some-
#
# Underfull \hbox (badness 1521) in paragraph at lines 736--736
# []\OT1/phv/m/n/10 reasonable \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 2158) in paragraph at lines 739--740
# \OT1/phv/m/n/10 help; to give fi-nan-cial sup-port to
#
# Underfull \hbox (badness 8189) in paragraph at lines 748--748
# []\OT1/phv/m/n/10 characteristic \OT1/phv/m/sl/10 (ad-
#
# Underfull \hbox (badness 1590) in paragraph at lines 750--751
# []\OT1/phv/m/n/10 to fas-ten some-thing with a chain;
#
# Underfull \hbox (badness 1688) in paragraph at lines 755--756
# \OT1/phv/m/n/10 how good or use-ful some-thing or
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 732--758
# []
#
# Underfull \hbox (badness 2547) in paragraph at lines 762--763
# \OT1/phv/m/n/10 high qual-ity, set-ting stan-dards for
#
# Underfull \hbox (badness 10000) in paragraph at lines 763--763
# []\OT1/phv/m/n/10 consideration
#
# Underfull \hbox (badness 1400) in paragraph at lines 763--764
# []\OT1/phv/m/n/10 the act of think-ing care-fully about
#
# Underfull \hbox (badness 10000) in paragraph at lines 768--768
# []\OT1/phv/m/n/10 emotional \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 10000) in paragraph at lines 769--770
# []\OT1/phv/m/n/10 the act of sav-ing some-
#
# Underfull \hbox (badness 2452) in paragraph at lines 769--770
# \OT1/phv/m/n/10 body/something from a dan-ger-ous
#
# Underfull \hbox (badness 4819) in paragraph at lines 770--771
# []\OT1/phv/m/n/10 responsibility for do-ing some-thing
#
# Underfull \hbox (badness 3977) in paragraph at lines 775--776
# []\OT1/phv/m/n/10 connected with the hu-man spirit,
#
# Underfull \hbox (badness 10000) in paragraph at lines 776--776
# []\OT1/phv/m/n/10 conscious \OT1/phv/m/sl/10 (ad-jec-
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 758--784
# []
# [74]
# Underfull \hbox (badness 2027) in paragraph at lines 807--808
# []\OT1/phv/m/n/10 a per-son who ex-presses opin-ions
#
# Underfull \hbox (badness 10000) in paragraph at lines 808--809
# []\OT1/phv/m/n/10 a pe-riod of time when some-
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 784--809
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 813--814
# []\OT1/phv/m/n/10 to send or trans-port some-
#
# Underfull \hbox (badness 10000) in paragraph at lines 814--814
# []\OT1/phv/m/n/10 objective \OT1/phv/m/sl/10 (ad-jec-
#
# Underfull \hbox (badness 1163) in paragraph at lines 820--821
# []\OT1/phv/m/n/10 information, doc-u-ments, etc. that
#
# Underfull \hbox (badness 10000) in paragraph at lines 822--822
# []\OT1/phv/m/n/10 deliberately \OT1/phv/m/sl/10 (ad-
#
# Underfull \hbox (badness 2951) in paragraph at lines 827--828
# []\OT1/phv/m/n/10 a stan-dard or prin-ci-ple by which
#
# Underfull \hbox (badness 10000) in paragraph at lines 829--829
# []\OT1/phv/m/n/10 nevertheless \OT1/phv/m/sl/10 (ad-
#
# Underfull \hbox (badness 10000) in paragraph at lines 831--832
# []\OT1/phv/m/n/10 to have or think that some-
#
# Underfull \hbox (badness 10000) in paragraph at lines 831--832
# \OT1/phv/m/n/10 body/something has a par-tic-u-lar
#
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 809--832
# []
# [75]
# Underfull \hbox (badness 10000) in paragraph at lines 832--833
# []\OT1/phv/m/n/10 the pro-cess of choos-ing some-
#
# Underfull \hbox (badness 5417) in paragraph at lines 832--833
# \OT1/phv/m/n/10 body/something from a group of
#
# Underfull \hbox (badness 10000) in paragraph at lines 838--839
# []\OT1/phv/m/n/10 to think or say that some-
#
# Underfull \hbox (badness 4543) in paragraph at lines 838--839
# \OT1/phv/m/n/10 body/something is re-spon-si-ble for
# )
# Overfull \hbox (11.64378pt too wide) in paragraph at lines 832--33
# []
#
# Underfull \hbox (badness 10000) in paragraph at lines 832--33
#
# No file ../build/oxford_3000_shuffle_C1.tex.
# No file ../build/oxford_3000_shuffle_C2.tex.
#
# (/home/jelle/wd/words/english/output/oxford_3000_two_column_by_cefr_shuffle.aux
# ) )
# (see the transcript file for additional information){/usr/share/texlive/texmf-d
# ist/fonts/enc/dvips/base/8r.enc}</usr/share/texlive/texmf-dist/fonts/type1/urw/
# helvetic/uhvb8a.pfb></usr/share/texlive/texmf-dist/fonts/type1/urw/helvetic/uhv
# r8a.pfb></usr/share/texlive/texmf-dist/fonts/type1/urw/helvetic/uhvro8a.pfb>
# Output written on /home/jelle/wd/words/english/output/oxford_3000_two_column_by
# _cefr_shuffle.pdf (75 pages, 339503 bytes).
# Transcript written on /home/jelle/wd/words/english/output/oxford_3000_two_colum
# n_by_cefr_shuffle.log.
# Latexmk: Examining '/home/jelle/wd/words/english/output/oxford_3000_two_column_by_cefr_shuffle.log'
# === TeX engine is 'pdfTeX'
# Latexmk: All targets (/home/jelle/wd/words/english/output/oxford_3000_two_column_by_cefr_shuffle.pdf) are up-to-date
# Latexmk: Missing input file '../build/oxford_3000_shuffle_C1.tex' (or dependence on it) from following:
#   'No file ../build/oxford_3000_shuffle_C1.tex.'
# Latexmk: Missing input file '../build/oxford_3000_shuffle_C2.tex' (or dependence on it) from following:
#   'No file ../build/oxford_3000_shuffle_C2.tex.'
# Latexmk: Log file says output to '/home/jelle/wd/words/english/output/oxford_3000_two_column_by_cefr_shuffle.pdf'
# Latexmk: Undoing directory change
# 0

# %%
# Clean any build files in output/
files_to_remove = ["*.fls", "*.log", "*.html", "*.toc", "*.synctex*", "*.fdb*", "*.aux"]
cmd_cleanup_output = "rm "+" ".join(f"output/{f}" for f in files_to_remove)
cmd_cleanup_format = "rm "+" ".join(f"format/{f}" for f in files_to_remove+["*.pdf"])
cmd_cleanup_main = "rm "+" ".join(f"./{f}" for f in files_to_remove)
os.system(";".join((cmd_cleanup_format, cmd_cleanup_main, cmd_cleanup_output)))
# Out:
# rm: cannot remove 'format/*.fls': No such file or directory
# rm: cannot remove 'format/*.log': No such file or directory
# rm: cannot remove 'format/*.html': No such file or directory
# rm: cannot remove 'format/*.toc': No such file or directory
# rm: cannot remove 'format/*.synctex*': No such file or directory
# rm: cannot remove 'format/*.fdb*': No such file or directory
# rm: cannot remove 'format/*.aux': No such file or directory
# rm: cannot remove 'format/*.pdf': No such file or directory
# rm: cannot remove './*.fls': No such file or directory
# rm: cannot remove './*.log': No such file or directory
# rm: cannot remove './*.html': No such file or directory
# rm: cannot remove './*.toc': No such file or directory
# rm: cannot remove './*.synctex*': No such file or directory
# rm: cannot remove './*.fdb*': No such file or directory
# rm: cannot remove './*.aux': No such file or directory
# rm: cannot remove 'output/*.synctex*': No such file or directory
# 256
